# %% [markdown]
# <a href="https://colab.research.google.com/github/sanaaria/Hyperparameter-Optimization/blob/main/hyperparameters_optimization.bbbp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dragonfly-opt
# !pip install -U hyperopt
# !pip install hpbandster ConfigSpace
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting dragonfly-opt
#   Downloading dragonfly-opt-0.1.6.tar.gz (252 kB)
#      |████████████████████████████████| 252 kB 7.0 MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (1.7.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (1.15.0)
# Building wheels for collected packages: dragonfly-opt
#   Building wheel for dragonfly-opt (setup.py) ... done
#   Created wheel for dragonfly-opt: filename=dragonfly_opt-0.1.6-cp37-cp37m-linux_x86_64.whl size=411424 sha256=7fa306122e2c130d163cd72329ff276afbfb0cdcba8ed9c3093ec8fb3229cd64
#   Stored in directory: /root/.cache/pip/wheels/bb/79/94/461f622bdd697be30dfe11c2590b574deee78320aa6f5cc2ba
# Successfully built dragonfly-opt
# Installing collected packages: dragonfly-opt
# Successfully installed dragonfly-opt-0.1.6
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.7/dist-packages (0.1.2)
# Collecting hyperopt
#   Downloading hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 7.1 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.21.6)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.7.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from hyperopt) (4.64.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.15.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.7/dist-packages (from hyperopt) (2.6.3)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from hyperopt) (0.16.0)
# Collecting py4j
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 51.4 MB/s
# Installing collected packages: py4j, hyperopt
#   Attempting uninstall: hyperopt
#     Found existing installation: hyperopt 0.1.2
#     Uninstalling hyperopt-0.1.2:
#       Successfully uninstalled hyperopt-0.1.2
# Successfully installed hyperopt-0.2.7 py4j-0.10.9.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting hpbandster
#   Downloading hpbandster-0.7.4.tar.gz (51 kB)
#      |████████████████████████████████| 51 kB 127 kB/s
# Collecting ConfigSpace
#   Downloading ConfigSpace-0.5.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 15.5 MB/s
# Collecting Pyro4
#   Downloading Pyro4-4.82-py2.py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 11.3 MB/s
# Collecting serpent
#   Downloading serpent-1.41-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hpbandster) (1.21.6)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from hpbandster) (0.10.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hpbandster) (1.7.3)
# Collecting netifaces
#   Downloading netifaces-0.11.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (32 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from ConfigSpace) (3.0.9)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from ConfigSpace) (0.29.30)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels->hpbandster) (0.5.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from statsmodels->hpbandster) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->statsmodels->hpbandster) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->statsmodels->hpbandster) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.4.0->statsmodels->hpbandster) (1.15.0)
# Building wheels for collected packages: hpbandster
#   Building wheel for hpbandster (setup.py) ... done
#   Created wheel for hpbandster: filename=hpbandster-0.7.4-py3-none-any.whl size=80006 sha256=73e9f740a211f39120da949fcd313f2e81a43987c42b321c104ef8622913c203
#   Stored in directory: /root/.cache/pip/wheels/d9/88/fc/61ab6b9f386a386839668631c39a6dc3c2fb0ec7000d552faa
# Successfully built hpbandster
# Installing collected packages: serpent, Pyro4, netifaces, ConfigSpace, hpbandster
# Successfully installed ConfigSpace-0.5.0 Pyro4-4.82 hpbandster-0.7.4 netifaces-0.11.0 serpent-1.41
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optuna in /usr/local/lib/python3.7/dist-packages (2.10.1)
# Requirement already satisfied: cliff in /usr/local/lib/python3.7/dist-packages (from optuna) (3.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.21.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (3.13)
# Requirement already satisfied: cmaes>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from optuna) (0.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.3)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.7.3)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.39)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.7/dist-packages (from optuna) (6.6.0)
# Requirement already satisfied: alembic in /usr/local/lib/python3.7/dist-packages (from optuna) (1.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.1.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (4.12.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (1.2.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (5.8.0)
# Requirement already satisfied: autopage>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (0.5.1)
# Requirement already satisfied: stevedore>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.5.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (5.9.0)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.3.0)
# Requirement already satisfied: cmd2>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (2.4.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (4.1.1)
# Requirement already satisfied: pyperclip>=1.6 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (1.8.2)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (21.4.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna) (3.8.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (2.0.1)

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset
from pandas import read_csv
from sklearn.impute import SimpleImputer

#visualizations
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e9f93191-aa9c-495f-adb8-92dcf208c97f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e9f93191-aa9c-495f-adb8-92dcf208c97f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bbbp.csv to bbbp.csv

# %%
import pandas as pd
import io
data = pd.read_csv(io.BytesIO(uploaded['bbbp.csv']))
data.head()
# Out:
#                                               smiles  \
# 0                   [Cl].CC(C)NCC(O)COc1cccc2ccccc12
# 1           C(=O)(OC(C)(C)C)CCCc1ccc(cc1)N(CCCl)CCCl
# 2  c12c3c(N4CCN(C)CC4)c(F)cc1c(c(C(O)=O)cn2C(C)CO...
# 3                   C1CCN(CC1)Cc1cccc(c1)OCCCNC(=O)C
# 4  Cc1onc(c2ccccc2Cl)c1C(=O)N[C@H]3[C@H]4SC(C)(C)...
#
#    ('RDKit2DNormalized_calculated', <class 'bool'>)  \
# 0                                              True
# 1                                              True
# 2                                              True
# 3                                              True
# 4                                              True
#
#    ('BalabanJ', <class 'numpy.float64'>)  \
# 0                               0.000020
# 1                               0.921082
# 2                               0.755549
# 3                               0.519074
# 4                               0.362651
#
#    ('BertzCT', <class 'numpy.float64'>)  ('Chi0', <class 'numpy.float64'>)  \
# 0                              0.111833                           0.106451
# 1                              0.077697                           0.324169
# 2                              0.516673                           0.423380
# 3                              0.068097                           0.166625
# 4                              0.590649                           0.607809
#
#    ('Chi0n', <class 'numpy.float64'>)  ('Chi0v', <class 'numpy.float64'>)  \
# 0                            0.177350                            0.187815
# 1                            0.379878                            0.467164
# 2                            0.415340                            0.360944
# 3                            0.260552                            0.212714
# 4                            0.520746                            0.607038
#
#    ('Chi1', <class 'numpy.float64'>)  ('Chi1n', <class 'numpy.float64'>)  \
# 0                           0.110054                            0.168672
# 1                           0.240353                            0.344156
# 2                           0.400697                            0.428148
# 3                           0.185779                            0.328404
# 4                           0.538488                            0.471718
#
#    ('Chi1v', <class 'numpy.float64'>)  ...  \
# 0                            0.119391  ...
# 1                            0.422452  ...
# 2                            0.348007  ...
# 3                            0.255385  ...
# 4                            0.569018  ...
#
#    ('fr_sulfone', <class 'numpy.float64'>)  \
# 0                             5.770000e-14
# 1                             5.770000e-14
# 2                             5.770000e-14
# 3                             5.770000e-14
# 4                             5.770000e-14
#
#    ('fr_term_acetylene', <class 'numpy.float64'>)  \
# 0                                    2.960000e-11
# 1                                    2.960000e-11
# 2                                    2.960000e-11
# 3                                    2.960000e-11
# 4                                    2.960000e-11
#
#    ('fr_tetrazole', <class 'numpy.float64'>)  \
# 0                                   0.168378
# 1                                   0.168378
# 2                                   0.168378
# 3                                   0.168378
# 4                                   0.168378
#
#    ('fr_thiazole', <class 'numpy.float64'>)  \
# 0                                   0.16738
# 1                                   0.16738
# 2                                   0.16738
# 3                                   0.16738
# 4                                   0.16738
#
#    ('fr_thiocyan', <class 'numpy.float64'>)  \
# 0                              1.480000e-18
# 1                              1.480000e-18
# 2                              1.480000e-18
# 3                              1.480000e-18
# 4                              1.480000e-18
#
#    ('fr_thiophene', <class 'numpy.float64'>)  \
# 0                               2.320000e-16
# 1                               2.320000e-16
# 2                               2.320000e-16
# 3                               2.320000e-16
# 4                               2.320000e-16
#
#    ('fr_unbrch_alkane', <class 'numpy.float64'>)  \
# 0                                   4.700000e-08
# 1                                   4.700000e-08
# 2                                   4.700000e-08
# 3                                   9.991992e-01
# 4                                   4.700000e-08
#
#    ('fr_urea', <class 'numpy.float64'>)  ('qed', <class 'numpy.float64'>)  \
# 0                              0.166633                          0.930688
# 1                              0.166633                          0.322648
# 2                              0.166633                          0.949987
# 3                              0.166633                          0.818175
# 4                              0.166633                          0.689000
#
#    p_np
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#
# [5 rows x 203 columns]

# %%
del data["('RDKit2DNormalized_calculated', <class 'bool'>)"]
del data["smiles"]
#data.insert(0, 'smiles', first_column)
data.head()
# Out:
#    ('BalabanJ', <class 'numpy.float64'>)  \
# 0                               0.000020
# 1                               0.921082
# 2                               0.755549
# 3                               0.519074
# 4                               0.362651
#
#    ('BertzCT', <class 'numpy.float64'>)  ('Chi0', <class 'numpy.float64'>)  \
# 0                              0.111833                           0.106451
# 1                              0.077697                           0.324169
# 2                              0.516673                           0.423380
# 3                              0.068097                           0.166625
# 4                              0.590649                           0.607809
#
#    ('Chi0n', <class 'numpy.float64'>)  ('Chi0v', <class 'numpy.float64'>)  \
# 0                            0.177350                            0.187815
# 1                            0.379878                            0.467164
# 2                            0.415340                            0.360944
# 3                            0.260552                            0.212714
# 4                            0.520746                            0.607038
#
#    ('Chi1', <class 'numpy.float64'>)  ('Chi1n', <class 'numpy.float64'>)  \
# 0                           0.110054                            0.168672
# 1                           0.240353                            0.344156
# 2                           0.400697                            0.428148
# 3                           0.185779                            0.328404
# 4                           0.538488                            0.471718
#
#    ('Chi1v', <class 'numpy.float64'>)  ('Chi2n', <class 'numpy.float64'>)  \
# 0                            0.119391                            0.185866
# 1                            0.422452                            0.438361
# 2                            0.348007                            0.528003
# 3                            0.255385                            0.291954
# 4                            0.569018                            0.615152
#
#    ('Chi2v', <class 'numpy.float64'>)  ...  \
# 0                            0.119537  ...
# 1                            0.462373  ...
# 2                            0.416469  ...
# 3                            0.201587  ...
# 4                            0.792858  ...
#
#    ('fr_sulfone', <class 'numpy.float64'>)  \
# 0                             5.770000e-14
# 1                             5.770000e-14
# 2                             5.770000e-14
# 3                             5.770000e-14
# 4                             5.770000e-14
#
#    ('fr_term_acetylene', <class 'numpy.float64'>)  \
# 0                                    2.960000e-11
# 1                                    2.960000e-11
# 2                                    2.960000e-11
# 3                                    2.960000e-11
# 4                                    2.960000e-11
#
#    ('fr_tetrazole', <class 'numpy.float64'>)  \
# 0                                   0.168378
# 1                                   0.168378
# 2                                   0.168378
# 3                                   0.168378
# 4                                   0.168378
#
#    ('fr_thiazole', <class 'numpy.float64'>)  \
# 0                                   0.16738
# 1                                   0.16738
# 2                                   0.16738
# 3                                   0.16738
# 4                                   0.16738
#
#    ('fr_thiocyan', <class 'numpy.float64'>)  \
# 0                              1.480000e-18
# 1                              1.480000e-18
# 2                              1.480000e-18
# 3                              1.480000e-18
# 4                              1.480000e-18
#
#    ('fr_thiophene', <class 'numpy.float64'>)  \
# 0                               2.320000e-16
# 1                               2.320000e-16
# 2                               2.320000e-16
# 3                               2.320000e-16
# 4                               2.320000e-16
#
#    ('fr_unbrch_alkane', <class 'numpy.float64'>)  \
# 0                                   4.700000e-08
# 1                                   4.700000e-08
# 2                                   4.700000e-08
# 3                                   9.991992e-01
# 4                                   4.700000e-08
#
#    ('fr_urea', <class 'numpy.float64'>)  ('qed', <class 'numpy.float64'>)  \
# 0                              0.166633                          0.930688
# 1                              0.166633                          0.322648
# 2                              0.166633                          0.949987
# 3                              0.166633                          0.818175
# 4                              0.166633                          0.689000
#
#    p_np
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#
# [5 rows x 201 columns]

# %%
data.shape
# Out:
# (2039, 201)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2039 entries, 0 to 2038
# Columns: 201 entries, ('BalabanJ', <class 'numpy.float64'>) to p_np
# dtypes: float64(199), int64(2)
# memory usage: 3.1 MB

# %%
data.describe()
# Out:
#        ('BalabanJ', <class 'numpy.float64'>)  \
# count                            2039.000000
# mean                                0.604334
# std                                 0.312428
# min                                 0.000020
# 25%                                 0.376547
# 50%                                 0.684349
# 75%                                 0.874519
# max                                 0.999343
#
#        ('BertzCT', <class 'numpy.float64'>)  \
# count                           2039.000000
# mean                               0.291380
# std                                0.251739
# min                                0.000577
# 25%                                0.082053
# 50%                                0.230083
# 75%                                0.438195
# max                                1.000000
#
#        ('Chi0', <class 'numpy.float64'>)  ('Chi0n', <class 'numpy.float64'>)  \
# count                        2039.000000                        2.039000e+03
# mean                            0.337879                        3.573345e-01
# std                             0.293971                        2.893572e-01
# min                             0.000002                        1.980000e-08
# 25%                             0.082985                        9.334640e-02
# 50%                             0.243373                        2.944113e-01
# 75%                             0.560798                        5.762799e-01
# max                             0.999913                        9.998828e-01
#
#        ('Chi0v', <class 'numpy.float64'>)  ('Chi1', <class 'numpy.float64'>)  \
# count                        2.039000e+03                        2039.000000
# mean                         3.555512e-01                           0.330076
# std                          2.938552e-01                           0.282478
# min                          4.530000e-07                           0.000001
# 25%                          8.693349e-02                           0.085748
# 50%                          2.866005e-01                           0.256325
# 75%                          5.794196e-01                           0.538452
# max                          9.999034e-01                           0.999915
#
#        ('Chi1n', <class 'numpy.float64'>)  ('Chi1v', <class 'numpy.float64'>)  \
# count                        2.039000e+03                         2039.000000
# mean                         3.722977e-01                            0.364649
# std                          2.921984e-01                            0.292215
# min                          2.680000e-07                            0.000042
# 25%                          1.031724e-01                            0.093407
# 50%                          3.198660e-01                            0.309533
# 75%                          6.049746e-01                            0.595135
# max                          9.998737e-01                            0.999931
#
#        ('Chi2n', <class 'numpy.float64'>)  ('Chi2v', <class 'numpy.float64'>)  \
# count                         2039.000000                        2.039000e+03
# mean                             0.409469                        4.051476e-01
# std                              0.313242                        3.164573e-01
# min                              0.000001                        2.210000e-07
# 25%                              0.112201                        1.007599e-01
# 50%                              0.364833                        3.658837e-01
# 75%                              0.661656                        6.885461e-01
# max                              0.999863                        9.998239e-01
#
#        ...  ('fr_sulfone', <class 'numpy.float64'>)  \
# count  ...                             2.039000e+03
# mean   ...                             9.808730e-03
# std    ...                             9.857629e-02
# min    ...                             5.770000e-14
# 25%    ...                             5.770000e-14
# 50%    ...                             5.770000e-14
# 75%    ...                             5.770000e-14
# max    ...                             1.000000e+00
#
#        ('fr_term_acetylene', <class 'numpy.float64'>)  \
# count                                    2.039000e+03
# mean                                     7.846984e-03
# std                                      8.825661e-02
# min                                      2.960000e-11
# 25%                                      2.960000e-11
# 50%                                      2.960000e-11
# 75%                                      2.960000e-11
# max                                      1.000000e+00
#
#        ('fr_tetrazole', <class 'numpy.float64'>)  \
# count                                2039.000000
# mean                                    0.177759
# std                                     0.087846
# min                                     0.168378
# 25%                                     0.168378
# 50%                                     0.168378
# 75%                                     0.168378
# max                                     1.000000
#
#        ('fr_thiazole', <class 'numpy.float64'>)  \
# count                               2039.000000
# mean                                   0.186164
# std                                    0.123671
# min                                    0.167380
# 25%                                    0.167380
# 50%                                    0.167380
# 75%                                    0.167380
# max                                    1.000000
#
#        ('fr_thiocyan', <class 'numpy.float64'>)  \
# count                              2.039000e+03
# mean                               1.480000e-18
# std                                5.779207e-34
# min                                1.480000e-18
# 25%                                1.480000e-18
# 50%                                1.480000e-18
# 75%                                1.480000e-18
# max                                1.480000e-18
#
#        ('fr_thiophene', <class 'numpy.float64'>)  \
# count                               2.039000e+03
# mean                                1.618440e-02
# std                                 1.262152e-01
# min                                 2.320000e-16
# 25%                                 2.320000e-16
# 50%                                 2.320000e-16
# 75%                                 2.320000e-16
# max                                 1.000000e+00
#
#        ('fr_unbrch_alkane', <class 'numpy.float64'>)  \
# count                                   2.039000e+03
# mean                                    8.005408e-02
# std                                     2.681487e-01
# min                                     4.700000e-08
# 25%                                     4.700000e-08
# 50%                                     4.700000e-08
# 75%                                     4.700000e-08
# max                                     1.000000e+00
#
#        ('fr_urea', <class 'numpy.float64'>)  ('qed', <class 'numpy.float64'>)  \
# count                           2039.000000                       2039.000000
# mean                               0.201374                          0.578456
# std                                0.166608                          0.279008
# min                                0.166633                          0.003427
# 25%                                0.166633                          0.370570
# 50%                                0.166633                          0.631207
# 75%                                0.166633                          0.812874
# max                                1.000000                          0.999021
#
#               p_np
# count  2039.000000
# mean      0.765081
# std       0.424052
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
#
# [8 rows x 201 columns]

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
Xdata = data.iloc[:, 0:200]
Ydata = data.iloc[:, 200:201]

# %%
Ydata.head
# Out:
# <bound method NDFrame.head of       p_np
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ...    ...
# 2034     1
# 2035     1
# 2036     1
# 2037     1
# 2038     1
#
# [2039 rows x 1 columns]>

# %%
# from sklearn.model_selection import train_test_split
# train_data, test_data, train_labels, test_labels = train_test_split(Xdata, Ydata, test_size=0.3, random_state=1)
# print(train_data.shape, train_labels.shape, test_data.shape, test_labels.shape)

from sklearn.model_selection import train_test_split
train_data, test_data, train_labels, test_labels = train_test_split(Xdata, Ydata, stratify = Ydata , test_size = 0.25)

# %%
# train_data = np.array(train_data)
# test_data = np.array(test_data)

# train_labels = np.array(train_labels)
# test_labels = np.array(test_labels)

# %%
train_data.shape
# Out:
# (1529, 200)

# %%
# from sklearn.decomposition import PCA as sklearnPCA
# sklearn_pca = sklearnPCA(n_components=15)
# X_train_pca = sklearn_pca.fit_transform(X_train)
# print(X_train_pca.shape)

# %%
from sklearn import preprocessing

scaler_data = preprocessing.MinMaxScaler()
train_data = scaler_data.fit_transform(train_data)
test_data = scaler_data.transform(test_data)

scaler_labels = preprocessing.MinMaxScaler()
train_labels_before = train_labels.values.reshape(-1, 1)
train_labels = scaler_labels.fit_transform(train_labels.values.reshape(-1, 1))
test_labels = scaler_labels.transform(test_labels.values.reshape(-1, 1))

print(train_data.shape, train_labels.shape, test_data.shape, test_labels.shape)
print("Train labels before scaling: {} {} {}Train labels after scaling: {} {}".format('\n',train_labels_before,'\n', '\n', train_labels))
# Out:
# (1529, 200) (1529, 1) (510, 200) (510, 1)
# Train labels before scaling:
#  [[0]
#  [1]
#  [0]
#  ...
#  [1]
#  [1]
#  [1]]
# Train labels after scaling:
#  [[0.]
#  [1.]
#  [0.]
#  ...
#  [1.]
#  [1.]
#  [1.]]

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# transform to torch tensor

tensor_x = torch.tensor(train_data, dtype=torch.float).to(device) 
tensor_x2 = torch.tensor(test_data, dtype=torch.float).to(device) 

tensor_y = torch.tensor(train_labels, dtype=torch.float).to(device)
tensor_y2 = torch.tensor(test_labels, dtype=torch.float).to(device)

# %%
tensor_x
# Out:
# tensor([[2.3999e-01, 7.1598e-01, 7.5592e-01,  ..., 0.0000e+00, 0.0000e+00,
#          4.1050e-02],
#         [9.6970e-01, 9.1730e-02, 6.1368e-02,  ..., 0.0000e+00, 0.0000e+00,
#          4.3984e-01],
#         [8.0825e-01, 2.3287e-01, 1.5537e-01,  ..., 0.0000e+00, 0.0000e+00,
#          6.2462e-01],
#         ...,
#         [9.6573e-01, 3.8720e-03, 7.7836e-04,  ..., 0.0000e+00, 0.0000e+00,
#          3.7548e-01],
#         [9.9515e-01, 5.6776e-03, 1.0138e-02,  ..., 0.0000e+00, 1.0000e+00,
#          6.2525e-01],
#         [8.7586e-01, 3.0379e-01, 1.7034e-01,  ..., 0.0000e+00, 0.0000e+00,
#          9.1604e-01]])

# %%
# create your dataset

trainset = TensorDataset(tensor_x, tensor_y) 
testset = TensorDataset(tensor_x2,tensor_y2)

# %%
trainset[0]
# Out:
# (tensor([0.2400, 0.7160, 0.7559, 0.6347, 0.7601, 0.7365, 0.5189, 0.7788, 0.4777,
#          0.7888, 0.4781, 0.8668, 0.4738, 0.9009, 0.9177, 0.8229, 0.0000, 0.7151,
#          0.6168, 0.2963, 0.9615, 0.5539, 0.0000, 0.7759, 0.6165, 0.8365, 0.9714,
#          0.9791, 0.9427, 0.5293, 0.3369, 0.7429, 0.8577, 0.0000, 0.7415, 0.6704,
#          0.5504, 0.7624, 0.5567, 0.6826, 0.5567, 0.8874, 0.4728, 0.8971, 0.1496,
#          0.3087, 0.0174, 0.6696, 0.8412, 0.9043, 0.9855, 0.0000, 0.9589, 0.9368,
#          0.0000, 0.9599, 0.3831, 0.9991, 0.8479, 0.9876, 0.0000, 0.6948, 0.0000,
#          0.9800, 0.8847, 0.7846, 0.8094, 0.9687, 0.9954, 0.8074, 0.9943, 0.8996,
#          0.8116, 0.9012, 0.0000, 1.0000, 0.3444, 0.0727, 0.5119, 0.0000, 0.6125,
#          0.8484, 0.9933, 0.0000, 0.9913, 0.9969, 0.3261, 0.7086, 0.0775, 0.0000,
#          0.0000, 0.6385, 0.9813, 0.0000, 0.9971, 0.9425, 0.8797, 0.0000, 0.0669,
#          0.1853, 0.0000, 0.0000, 0.0000, 0.9743, 0.0000, 0.9848, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.6687, 0.9233, 1.0000, 0.0000, 0.0000,
#          1.0000, 0.0000, 0.9845, 0.0000, 0.0000, 1.0000, 1.0000, 0.8707, 0.9265,
#          0.0000, 0.0000, 0.0000, 0.9915, 0.5982, 0.9999, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.8988, 0.0000, 0.9128,
#          0.9996, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.9140, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          1.0000, 0.0000, 0.0000, 0.0000, 1.0000, 1.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0411]), tensor([0.]))

# %%
# %%capture
try:
    import ray
except:
    # !pip install -U ray
    import ray

# %%
from functools import partial
import numpy as np
import os
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
from torchsummary import summary

from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler

# %%
def load_data(data_dir=None):
    return trainset, testset

# %%
class Net(nn.Module):
    def __init__(self, config):
        super().__init__()
        
        self.config = config
        self.hidden_dim1 = int(self.config.get("hidden_dim1", 100))
        self.hidden_dim2 = int(self.config.get("hidden_dim2", 100))
        self.hidden_dim3 = int(self.config.get("hidden_dim3", 100))

        self.act1 = self.config.get("act1", "relu") 
        self.act2 = self.config.get("act2", "relu") 
        self.act3 = self.config.get("act3", "relu")

        self.linear1 = nn.Linear(200, self.hidden_dim1)
        self.linear2 = nn.Linear(self.hidden_dim1, self.hidden_dim2)
        self.linear3 = nn.Linear(self.hidden_dim2, self.hidden_dim3)
        self.linear4 = nn.Linear(self.hidden_dim3, 1)
    
    @staticmethod
    def activation_func(act_str):
        if act_str=="tanh":
            return eval("torch."+act_str)
        elif act_str=="selu" or act_str=="relu":   
            return eval("torch.nn.functional."+act_str)

    def forward(self, x):
        output = self.linear1(x)
        output = self.activation_func(self.act1)(output)
        output = self.linear2(output)
        output = self.activation_func(self.act2)(output)
        output = self.linear3(output)
        output = self.activation_func(self.act3)(output)
        output = self.linear4(output)        
        return output

# %%
model = Net({})

# %%
from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        table.add_row([name, param])
        total_params+=param
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

# %%
summary(model, (1,tensor_x.shape[1]))

count_parameters(model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1               [-1, 1, 100]          20,100
#             Linear-2               [-1, 1, 100]          10,100
#             Linear-3               [-1, 1, 100]          10,100
#             Linear-4                 [-1, 1, 1]             101
# ================================================================
# Total params: 40,401
# Trainable params: 40,401
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.15
# Estimated Total Size (MB): 0.16
# ----------------------------------------------------------------
# +----------------+------------+
# |    Modules     | Parameters |
# +----------------+------------+
# | linear1.weight |   20000    |
# |  linear1.bias  |    100     |
# | linear2.weight |   10000    |
# |  linear2.bias  |    100     |
# | linear3.weight |   10000    |
# |  linear3.bias  |    100     |
# | linear4.weight |    100     |
# |  linear4.bias  |     1      |
# +----------------+------------+
# Total Trainable Params: 40401
# 40401

# %%
def trainable_func(config, checkpoint_dir=None, data_dir=None, epochs=10):

    net = Net(config)

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if torch.cuda.device_count() > 1:
            net = nn.DataParallel(net)
    net.to(device)

    '''
    Define a loss function
    '''
    ## Classification
    criterion = nn.CrossEntropyLoss()

    # Define an optimizer 
    optimizer = optim.Adam(net.parameters(), lr=config.get("lr",0.0003))

    if checkpoint_dir:
        model_state, optimizer_state = torch.load(
            os.path.join(checkpoint_dir, "checkpoint"))
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    # Load data
    trainset, testset = load_data(data_dir)

    # Split the dataset into training and validation sets
    train_size = int(len(trainset) * 0.66)
    train_subset, val_subset = random_split(trainset, [train_size, len(trainset) - train_size])

    # Define data loaders (which combines a dataset and a sampler, and provides an iterable over the given dataset)
    trainloader = torch.utils.data.DataLoader(
        train_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=True,
        num_workers=2)
    valloader = torch.utils.data.DataLoader(
        val_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=True,
        num_workers=2)

    for epoch in range(epochs):  # loop over the dataset multiple times
        epoch_train_loss = 0.0
        # epoch_steps = 0
        net.train() # Prepare model for training
        for i, data in enumerate(trainloader):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            '''
            Compute train loss without scaling to print
            ''' 
            # outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            # labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device)  
            # loss_train = criterion(outputs, labels) 
            # epoch_train_loss += loss_train.detach().item()
        # print("[%d] loss: %.3f" % (epoch + 1, epoch_train_loss / len(train_subset)))

        # Validation loss
        val_loss = 0.0
        net.eval() # Prepare model for evaluation
        for i, data in enumerate(valloader):
            with torch.no_grad():
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = net(inputs)

                # Inverse transform of the labels' scaler  این دو خط رو کامنت کردی!!!!!
                #outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
                #labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

                loss = criterion(outputs, labels)
                val_loss += loss.cpu().numpy()

        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save((net.state_dict(), optimizer.state_dict()), path)

        tune.report(epoch = epoch, loss=(val_loss / len(val_subset)))
    print("Finished Training")

# %%
def test_score(config, net, device="cpu"):
    trainset, testset = load_data()

    testloader = torch.utils.data.DataLoader(
        testset, batch_size=int(config.get("batch_size",32)), shuffle=False, num_workers=2)
    
    criterion = nn.CrossEntropyLoss()

    # Test loss
    test_loss = 0.0
    net.eval() # Prepare model for evaluation
    for i, data in enumerate(testloader):
        with torch.no_grad():
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = net(inputs)

            # Inverse transform of the labels' scaler   این دو خط رو هم کتمنت کردی!!!!
            # outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            # labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

            loss = criterion(outputs, labels)
            test_loss += loss.cpu().numpy()

    return test_loss / len(testset)

# %% [markdown]
# start ray run time

# %%
ray.shutdown()
ray.init() # Here we use ray.init() to evaluate available_resources for Ray
print(ray.available_resources())
  # Restart Ray defensively in case the ray connection is lost. 

# Start Ray runtime with specific resources (not nessesarily all resources)
# You can change this values based on your machine resources)
#ray.init(num_cpus=2, num_gpus=0) 

"""Check Ray Tune is working properly (for trainable class)"""
# from ray.tune.utils import validate_save_restore
# validate_save_restore(Trainable)
# validate_save_restore(Trainable, use_object_store=True)
# print("Success!")
# Out:
# {'object_store_memory': 3941587353.0, 'CPU': 2.0, 'memory': 7883174708.0, 'node:172.28.0.2': 1.0}
# 'Check Ray Tune is working properly (for trainable class)'

# %%
# %%capture
try:
    import optuna
except:
    # %pip install optuna
    import optuna

# %%
def main(num_samples=10, max_num_epochs=10, gpus_per_trial=2):

    # define data directory here if you want to load data from files
    data_dir = os.path.abspath("./bbbp")
    load_data(data_dir)

    # define the search space of hyperparameters
    config = {
        "act1 ": tune.choice(["relu","tanh","selu"]),
        "act2" : tune.choice(["relu","tanh","selu"]),
        "act3" : tune.choice(["relu","tanh","selu"]),
        "lr": tune.quniform(0.0005, 0.001, 0.0001),
        "batch_size": tune.choice([8, 16, 32, 64, 128]),
        "hidden_dim1" : tune.quniform(50, 200, 10),
        "hidden_dim2" : tune.quniform(50, 200, 10),
        "hidden_dim3" : tune.quniform(50, 200, 10),
    }

    # Optuna search algorithm
    from ray.tune.suggest.optuna import OptunaSearch 
    from ray.tune.suggest import ConcurrencyLimiter
    search_alg = OptunaSearch(
        metric="loss", #or accuracy, etc.
        mode="min", #or max
        # seed = 42,
        # points_to_evaluate=[
        # {'lr': 0.0005, 'hidden_size': 150.0, 'readout1_out': 200.0, 'readout2_out': 180.0}
        # ],
        )
    search_alg = ConcurrencyLimiter(search_alg, max_concurrent=10)

    scheduler = ASHAScheduler(
        metric ="loss",
        mode="min",
        max_t=max_num_epochs,
        reduction_factor=2, 
        grace_period=4,
        brackets=5
        )
    
    reporter = CLIReporter(
        # parameter_columns=["l1", "l2", "lr", "batch_size"],
        metric_columns=["loss", "training_iteration"]
        )
    
    # wrap data loading and training for tuning using `partial` 
    # (note that there exist other methods for this purpose)
    result = tune.run(
        partial(trainable_func, data_dir=data_dir, epochs=max_num_epochs),
        scheduler=scheduler,
        search_alg=search_alg,
        num_samples=num_samples,
        config=config,
        verbose=2,
        checkpoint_score_attr="loss",
        checkpoint_freq=0,
        keep_checkpoints_num=1,
        # checkpoint_at_end=True,
        # reuse_actors=reuse_actors_status,
        progress_reporter=reporter,
        resources_per_trial={"cpu": 0.5, "gpu": gpus_per_trial},
        stop={"training_iteration": max_num_epochs},                
        )

    best_trial = result.get_best_trial("loss", "min", "last")
    print("Best trial config: {}".format(best_trial.config))
    print("Best trial final validation score: {}".format(
        best_trial.last_result["loss"]))

    best_trained_model = Net(best_trial.config)
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if gpus_per_trial > 1:
            best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)

    best_checkpoint_dir = best_trial.checkpoint.value
    model_state, optimizer_state = torch.load(os.path.join(
        best_checkpoint_dir, "checkpoint"))
    best_trained_model.load_state_dict(model_state)

    test_score_value = test_score(best_trial.config, best_trained_model, device)
    print("Best trial test set score: {}".format(test_score_value))


if __name__ == "__main__":
    # You can change the number of GPUs per trial here:
    main(num_samples=50, max_num_epochs=10, gpus_per_trial=0)
# Out:
# 2022-07-16 14:45:25,541	INFO logger.py:630 -- pip install "ray[tune]" to see TensorBoard files.
# 2022-07-16 14:45:25,543	WARNING callback.py:106 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# == Status ==
# Current time: 2022-07-16 14:45:26 (running for 00:00:00.47)
# Memory usage on this node: 1.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 8.000: None
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-16_14-45-25
# Number of trials: 1/50 (1 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------|
# | trainable_func_ed86a122 | RUNNING  | 172.28.0.2:426 | tanh    | tanh   | tanh   |          128 |            90 |            50 |           180 | 0.0009 |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+
#
#
# Trial trainable_func_ed86a122 reported epoch=0,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 128, 'hidden_dim1': 90.0, 'hidden_dim2': 50.0, 'hidden_dim3': 180.0}.
# == Status ==
# Current time: 2022-07-16 14:45:31 (running for 00:00:05.55)
# Memory usage on this node: 1.5/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 8.000: None
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-16_14-45-25
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |   loss |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------|
# | trainable_func_ed86a122 | RUNNING  | 172.28.0.2:426 | tanh    | tanh   | tanh   |          128 |            90 |            50 |           180 | 0.0009 |      0 |                    1 |
# | trainable_func_f07e762a | RUNNING  | 172.28.0.2:473 | tanh    | relu   | selu   |            8 |           130 |           170 |           100 | 0.0005 |        |                      |
# | trainable_func_f0903720 | RUNNING  | 172.28.0.2:474 | tanh    | relu   | relu   |           64 |           100 |            70 |           200 | 0.0008 |        |                      |
# | trainable_func_f09c5884 | RUNNING  | 172.28.0.2:537 | selu    | tanh   | relu   |           16 |            90 |           130 |           170 | 0.001  |        |                      |
# | trainable_func_f0afc6bc | PENDING  |                | relu    | tanh   | relu   |           64 |           170 |           140 |           200 | 0.0009 |        |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
#
#
# == Status ==
# Current time: 2022-07-16 14:45:43 (running for 00:00:18.27)
# Memory usage on this node: 2.0/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 8.000: None
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-16_14-45-25
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |   loss |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------|
# | trainable_func_ed86a122 | RUNNING  | 172.28.0.2:426 | tanh    | tanh   | tanh   |          128 |            90 |            50 |           180 | 0.0009 |      0 |                    1 |
# | trainable_func_f07e762a | RUNNING  | 172.28.0.2:473 | tanh    | relu   | selu   |            8 |           130 |           170 |           100 | 0.0005 |        |                      |
# | trainable_func_f0903720 | RUNNING  | 172.28.0.2:474 | tanh    | relu   | relu   |           64 |           100 |            70 |           200 | 0.0008 |        |                      |
# | trainable_func_f09c5884 | RUNNING  | 172.28.0.2:537 | selu    | tanh   | relu   |           16 |            90 |           130 |           170 | 0.001  |        |                      |
# | trainable_func_f0afc6bc | PENDING  |                | relu    | tanh   | relu   |           64 |           170 |           140 |           200 | 0.0009 |        |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
#
#
# Trial trainable_func_f07e762a reported epoch=0,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 130.0, 'hidden_dim2': 170.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_f0903720 reported epoch=0,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 100.0, 'hidden_dim2': 70.0, 'hidden_dim3': 200.0}.
# Trial trainable_func_ed86a122 reported epoch=1,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 128, 'hidden_dim1': 90.0, 'hidden_dim2': 50.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_f09c5884 reported epoch=0,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 90.0, 'hidden_dim2': 130.0, 'hidden_dim3': 170.0}.
# == Status ==
# Current time: 2022-07-16 14:45:48 (running for 00:00:23.33)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: 0.0 | Iter 4.000: -0.0
# Bracket: Iter 8.000: None
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-16_14-45-25
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |   loss |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------|
# | trainable_func_ed86a122 | RUNNING  | 172.28.0.2:426 | tanh    | tanh   | tanh   |          128 |            90 |            50 |           180 | 0.0009 |      0 |                    9 |
# | trainable_func_f07e762a | RUNNING  | 172.28.0.2:473 | tanh    | relu   | selu   |            8 |           130 |           170 |           100 | 0.0005 |      0 |                    2 |
# | trainable_func_f0903720 | RUNNING  | 172.28.0.2:474 | tanh    | relu   | relu   |           64 |           100 |            70 |           200 | 0.0008 |      0 |                    6 |
# | trainable_func_f09c5884 | RUNNING  | 172.28.0.2:537 | selu    | tanh   | relu   |           16 |            90 |           130 |           170 | 0.001  |      0 |                    2 |
# | trainable_func_f0afc6bc | PENDING  |                | relu    | tanh   | relu   |           64 |           170 |           140 |           200 | 0.0009 |        |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
#
#
# Trial trainable_func_f0903720 reported epoch=6,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 100.0, 'hidden_dim2': 70.0, 'hidden_dim3': 200.0}.
# Trial trainable_func_ed86a122 reported epoch=9,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 128, 'hidden_dim1': 90.0, 'hidden_dim2': 50.0, 'hidden_dim3': 180.0}. This trial completed.
# Trial trainable_func_f0afc6bc reported epoch=0,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 64, 'hidden_dim1': 170.0, 'hidden_dim2': 140.0, 'hidden_dim3': 200.0}.
# Trial trainable_func_f09c5884 reported epoch=2,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 90.0, 'hidden_dim2': 130.0, 'hidden_dim3': 170.0}.
# Trial trainable_func_f0903720 reported epoch=9,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 100.0, 'hidden_dim2': 70.0, 'hidden_dim3': 200.0}. This trial completed.
# Trial trainable_func_f07e762a reported epoch=2,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 130.0, 'hidden_dim2': 170.0, 'hidden_dim3': 100.0}.
# == Status ==
# Current time: 2022-07-16 14:45:54 (running for 00:00:29.09)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: -0.0 | Iter 4.000: -0.0
# Bracket: Iter 8.000: None
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-16_14-45-25
# Number of trials: 7/50 (1 PENDING, 4 RUNNING, 2 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |   loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------|
# | trainable_func_f07e762a | RUNNING    | 172.28.0.2:473 | tanh    | relu   | selu   |            8 |           130 |           170 |           100 | 0.0005 |      0 |                    3 |
# | trainable_func_f09c5884 | RUNNING    | 172.28.0.2:537 | selu    | tanh   | relu   |           16 |            90 |           130 |           170 | 0.001  |      0 |                    4 |
# | trainable_func_f0afc6bc | RUNNING    | 172.28.0.2:426 | relu    | tanh   | relu   |           64 |           170 |           140 |           200 | 0.0009 |      0 |                    5 |
# | trainable_func_fbe1a5e6 | RUNNING    | 172.28.0.2:474 | selu    | relu   | selu   |            8 |            90 |            70 |            80 | 0.001  |        |                      |
# | trainable_func_fd337708 | PENDING    |                | relu    | selu   | selu   |          128 |            50 |           130 |           100 | 0.0005 |        |                      |
# | trainable_func_ed86a122 | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | tanh   |          128 |            90 |            50 |           180 | 0.0009 |      0 |                   10 |
# | trainable_func_f0903720 | TERMINATED | 172.28.0.2:474 | tanh    | relu   | relu   |           64 |           100 |            70 |           200 | 0.0008 |      0 |                   10 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
#
#
# Trial trainable_func_fbe1a5e6 reported epoch=0,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 90.0, 'hidden_dim2': 70.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_f0afc6bc reported epoch=5,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 64, 'hidden_dim1': 170.0, 'hidden_dim2': 140.0, 'hidden_dim3': 200.0}.
# Trial trainable_func_f09c5884 reported epoch=5,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 90.0, 'hidden_dim2': 130.0, 'hidden_dim3': 170.0}.
# Trial trainable_func_f0afc6bc reported epoch=9,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 64, 'hidden_dim1': 170.0, 'hidden_dim2': 140.0, 'hidden_dim3': 200.0}. This trial completed.
# == Status ==
# Current time: 2022-07-16 14:45:59 (running for 00:00:34.37)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: -0.0 | Iter 4.000: -0.0
# Bracket: Iter 8.000: 0.0
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-16_14-45-25
# Number of trials: 8/50 (1 PENDING, 4 RUNNING, 3 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |   loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------|
# | trainable_func_f07e762a | RUNNING    | 172.28.0.2:473 | tanh    | relu   | selu   |            8 |           130 |           170 |           100 | 0.0005 |      0 |                    4 |
# | trainable_func_f09c5884 | RUNNING    | 172.28.0.2:537 | selu    | tanh   | relu   |           16 |            90 |           130 |           170 | 0.001  |      0 |                    7 |
# | trainable_func_fbe1a5e6 | RUNNING    | 172.28.0.2:474 | selu    | relu   | selu   |            8 |            90 |            70 |            80 | 0.001  |      0 |                    2 |
# | trainable_func_fd337708 | RUNNING    | 172.28.0.2:426 | relu    | selu   | selu   |          128 |            50 |           130 |           100 | 0.0005 |        |                      |
# | trainable_func_01ae7094 | PENDING    |                | selu    | relu   | selu   |            8 |           160 |           170 |           130 | 0.001  |        |                      |
# | trainable_func_ed86a122 | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | tanh   |          128 |            90 |            50 |           180 | 0.0009 |      0 |                   10 |
# | trainable_func_f0903720 | TERMINATED | 172.28.0.2:474 | tanh    | relu   | relu   |           64 |           100 |            70 |           200 | 0.0008 |      0 |                   10 |
# | trainable_func_f0afc6bc | TERMINATED | 172.28.0.2:426 | relu    | tanh   | relu   |           64 |           170 |           140 |           200 | 0.0009 |      0 |                   10 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
#
#
# Trial trainable_func_fd337708 reported epoch=0,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 128, 'hidden_dim1': 50.0, 'hidden_dim2': 130.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_f07e762a reported epoch=4,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 130.0, 'hidden_dim2': 170.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_fbe1a5e6 reported epoch=2,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 90.0, 'hidden_dim2': 70.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_f09c5884 reported epoch=8,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 90.0, 'hidden_dim2': 130.0, 'hidden_dim3': 170.0}.
# Trial trainable_func_fd337708 reported epoch=9,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 128, 'hidden_dim1': 50.0, 'hidden_dim2': 130.0, 'hidden_dim3': 100.0}. This trial completed.
# == Status ==
# Current time: 2022-07-16 14:46:05 (running for 00:00:40.04)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: 0.0 | Iter 4.000: 0.0
# Bracket: Iter 8.000: 0.0
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-16_14-45-25
# Number of trials: 8/50 (1 PENDING, 4 RUNNING, 3 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |   loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------|
# | trainable_func_f07e762a | RUNNING    | 172.28.0.2:473 | tanh    | relu   | selu   |            8 |           130 |           170 |           100 | 0.0005 |      0 |                    5 |
# | trainable_func_f09c5884 | RUNNING    | 172.28.0.2:537 | selu    | tanh   | relu   |           16 |            90 |           130 |           170 | 0.001  |      0 |                    9 |
# | trainable_func_fbe1a5e6 | RUNNING    | 172.28.0.2:474 | selu    | relu   | selu   |            8 |            90 |            70 |            80 | 0.001  |      0 |                    3 |
# | trainable_func_fd337708 | RUNNING    | 172.28.0.2:426 | relu    | selu   | selu   |          128 |            50 |           130 |           100 | 0.0005 |      0 |                   10 |
# | trainable_func_01ae7094 | PENDING    |                | selu    | relu   | selu   |            8 |           160 |           170 |           130 | 0.001  |        |                      |
# | trainable_func_ed86a122 | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | tanh   |          128 |            90 |            50 |           180 | 0.0009 |      0 |                   10 |
# | trainable_func_f0903720 | TERMINATED | 172.28.0.2:474 | tanh    | relu   | relu   |           64 |           100 |            70 |           200 | 0.0008 |      0 |                   10 |
# | trainable_func_f0afc6bc | TERMINATED | 172.28.0.2:426 | relu    | tanh   | relu   |           64 |           170 |           140 |           200 | 0.0009 |      0 |                   10 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
#
#
# Trial trainable_func_f09c5884 reported epoch=9,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 90.0, 'hidden_dim2': 130.0, 'hidden_dim3': 170.0}. This trial completed.
# Trial trainable_func_05679242 reported epoch=0,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 128, 'hidden_dim1': 100.0, 'hidden_dim2': 140.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_f07e762a reported epoch=6,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 130.0, 'hidden_dim2': 170.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_01ae7094 reported epoch=0,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 160.0, 'hidden_dim2': 170.0, 'hidden_dim3': 130.0}.
# == Status ==
# Current time: 2022-07-16 14:46:10 (running for 00:00:45.15)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: 0.0 | Iter 4.000: 0.0
# Bracket: Iter 8.000: 0.0
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-16_14-45-25
# Number of trials: 10/50 (1 PENDING, 4 RUNNING, 5 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |   loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------|
# | trainable_func_f07e762a | RUNNING    | 172.28.0.2:473 | tanh    | relu   | selu   |            8 |           130 |           170 |           100 | 0.0005 |      0 |                    7 |
# | trainable_func_fbe1a5e6 | RUNNING    | 172.28.0.2:474 | selu    | relu   | selu   |            8 |            90 |            70 |            80 | 0.001  |      0 |                    4 |
# | trainable_func_01ae7094 | RUNNING    | 172.28.0.2:426 | selu    | relu   | selu   |            8 |           160 |           170 |           130 | 0.001  |      0 |                    1 |
# | trainable_func_05679242 | RUNNING    | 172.28.0.2:537 | tanh    | selu   | selu   |          128 |           100 |           140 |           180 | 0.0005 |      0 |                    6 |
# | trainable_func_06325838 | PENDING    |                | relu    | selu   | selu   |           16 |           190 |            50 |           130 | 0.0009 |        |                      |
# | trainable_func_ed86a122 | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | tanh   |          128 |            90 |            50 |           180 | 0.0009 |      0 |                   10 |
# | trainable_func_f0903720 | TERMINATED | 172.28.0.2:474 | tanh    | relu   | relu   |           64 |           100 |            70 |           200 | 0.0008 |      0 |                   10 |
# | trainable_func_f09c5884 | TERMINATED | 172.28.0.2:537 | selu    | tanh   | relu   |           16 |            90 |           130 |           170 | 0.001  |      0 |                   10 |
# | trainable_func_f0afc6bc | TERMINATED | 172.28.0.2:426 | relu    | tanh   | relu   |           64 |           170 |           140 |           200 | 0.0009 |      0 |                   10 |
# | trainable_func_fd337708 | TERMINATED | 172.28.0.2:426 | relu    | selu   | selu   |          128 |            50 |           130 |           100 | 0.0005 |      0 |                   10 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
#
#
# Trial trainable_func_fbe1a5e6 reported epoch=4,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 90.0, 'hidden_dim2': 70.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_05679242 reported epoch=9,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 128, 'hidden_dim1': 100.0, 'hidden_dim2': 140.0, 'hidden_dim3': 180.0}. This trial completed.
# Trial trainable_func_06325838 reported epoch=0,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 190.0, 'hidden_dim2': 50.0, 'hidden_dim3': 130.0}.
# == Status ==
# Current time: 2022-07-16 14:46:17 (running for 00:00:51.94)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: -0.0 | Iter 4.000: 0.0
# Bracket: Iter 8.000: 0.0
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-16_14-45-25
# Number of trials: 11/50 (1 PENDING, 4 RUNNING, 6 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |   loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------|
# | trainable_func_f07e762a | RUNNING    | 172.28.0.2:473 | tanh    | relu   | selu   |            8 |           130 |           170 |           100 | 0.0005 |      0 |                    8 |
# | trainable_func_fbe1a5e6 | RUNNING    | 172.28.0.2:474 | selu    | relu   | selu   |            8 |            90 |            70 |            80 | 0.001  |      0 |                    6 |
# | trainable_func_01ae7094 | RUNNING    | 172.28.0.2:426 | selu    | relu   | selu   |            8 |           160 |           170 |           130 | 0.001  |      0 |                    2 |
# | trainable_func_06325838 | RUNNING    | 172.28.0.2:537 | relu    | selu   | selu   |           16 |           190 |            50 |           130 | 0.0009 |      0 |                    2 |
# | trainable_func_09d33a16 | PENDING    |                | selu    | selu   | relu   |          128 |           180 |           120 |            90 | 0.001  |        |                      |
# | trainable_func_ed86a122 | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | tanh   |          128 |            90 |            50 |           180 | 0.0009 |      0 |                   10 |
# | trainable_func_f0903720 | TERMINATED | 172.28.0.2:474 | tanh    | relu   | relu   |           64 |           100 |            70 |           200 | 0.0008 |      0 |                   10 |
# | trainable_func_f09c5884 | TERMINATED | 172.28.0.2:537 | selu    | tanh   | relu   |           16 |            90 |           130 |           170 | 0.001  |      0 |                   10 |
# | trainable_func_f0afc6bc | TERMINATED | 172.28.0.2:426 | relu    | tanh   | relu   |           64 |           170 |           140 |           200 | 0.0009 |      0 |                   10 |
# | trainable_func_fd337708 | TERMINATED | 172.28.0.2:426 | relu    | selu   | selu   |          128 |            50 |           130 |           100 | 0.0005 |      0 |                   10 |
# | trainable_func_05679242 | TERMINATED | 172.28.0.2:537 | tanh    | selu   | selu   |          128 |           100 |           140 |           180 | 0.0005 |      0 |                   10 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
#
#
# Trial trainable_func_f07e762a reported epoch=8,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 130.0, 'hidden_dim2': 170.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_fbe1a5e6 reported epoch=6,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 90.0, 'hidden_dim2': 70.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_01ae7094 reported epoch=2,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 160.0, 'hidden_dim2': 170.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_06325838 reported epoch=3,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 190.0, 'hidden_dim2': 50.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_f07e762a reported epoch=9,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 130.0, 'hidden_dim2': 170.0, 'hidden_dim3': 100.0}. This trial completed.
# Trial trainable_func_09d33a16 reported epoch=0,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 128, 'hidden_dim1': 180.0, 'hidden_dim2': 120.0, 'hidden_dim3': 90.0}.
# == Status ==
# Current time: 2022-07-16 14:46:22 (running for 00:00:57.39)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: 0.0 | Iter 4.000: -0.0
# Bracket: Iter 8.000: 0.0
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-16_14-45-25
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |   loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------|
# | trainable_func_fbe1a5e6 | RUNNING    | 172.28.0.2:474 | selu    | relu   | selu   |            8 |            90 |            70 |            80 | 0.001  |      0 |                    8 |
# | trainable_func_01ae7094 | RUNNING    | 172.28.0.2:426 | selu    | relu   | selu   |            8 |           160 |           170 |           130 | 0.001  |      0 |                    3 |
# | trainable_func_06325838 | RUNNING    | 172.28.0.2:537 | relu    | selu   | selu   |           16 |           190 |            50 |           130 | 0.0009 |      0 |                    4 |
# | trainable_func_09d33a16 | RUNNING    | 172.28.0.2:473 | selu    | selu   | relu   |          128 |           180 |           120 |            90 | 0.001  |      0 |                    2 |
# | trainable_func_0f0cfd8c | PENDING    |                | selu    | relu   | tanh   |           16 |           140 |            70 |           150 | 0.0008 |        |                      |
# | trainable_func_ed86a122 | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | tanh   |          128 |            90 |            50 |           180 | 0.0009 |      0 |                   10 |
# | trainable_func_f07e762a | TERMINATED | 172.28.0.2:473 | tanh    | relu   | selu   |            8 |           130 |           170 |           100 | 0.0005 |      0 |                   10 |
# | trainable_func_f0903720 | TERMINATED | 172.28.0.2:474 | tanh    | relu   | relu   |           64 |           100 |            70 |           200 | 0.0008 |      0 |                   10 |
# | trainable_func_f09c5884 | TERMINATED | 172.28.0.2:537 | selu    | tanh   | relu   |           16 |            90 |           130 |           170 | 0.001  |      0 |                   10 |
# | trainable_func_f0afc6bc | TERMINATED | 172.28.0.2:426 | relu    | tanh   | relu   |           64 |           170 |           140 |           200 | 0.0009 |      0 |                   10 |
# | trainable_func_fd337708 | TERMINATED | 172.28.0.2:426 | relu    | selu   | selu   |          128 |            50 |           130 |           100 | 0.0005 |      0 |                   10 |
# | trainable_func_05679242 | TERMINATED | 172.28.0.2:537 | tanh    | selu   | selu   |          128 |           100 |           140 |           180 | 0.0005 |      0 |                   10 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
#
#
# Trial trainable_func_fbe1a5e6 reported epoch=8,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 90.0, 'hidden_dim2': 70.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_01ae7094 reported epoch=4,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 160.0, 'hidden_dim2': 170.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_06325838 reported epoch=6,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 190.0, 'hidden_dim2': 50.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_09d33a16 reported epoch=9,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 128, 'hidden_dim1': 180.0, 'hidden_dim2': 120.0, 'hidden_dim3': 90.0}. This trial completed.
# Trial trainable_func_fbe1a5e6 reported epoch=9,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 90.0, 'hidden_dim2': 70.0, 'hidden_dim3': 80.0}. This trial completed.
# == Status ==
# Current time: 2022-07-16 14:46:28 (running for 00:01:02.89)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: -0.0 | Iter 4.000: -0.0
# Bracket: Iter 8.000: -0.0
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-16_14-45-25
# Number of trials: 14/50 (1 PENDING, 4 RUNNING, 9 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |   loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------|
# | trainable_func_01ae7094 | RUNNING    | 172.28.0.2:426 | selu    | relu   | selu   |            8 |           160 |           170 |           130 | 0.001  |      0 |                    5 |
# | trainable_func_06325838 | RUNNING    | 172.28.0.2:537 | relu    | selu   | selu   |           16 |           190 |            50 |           130 | 0.0009 |      0 |                    8 |
# | trainable_func_0f0cfd8c | RUNNING    | 172.28.0.2:473 | selu    | relu   | tanh   |           16 |           140 |            70 |           150 | 0.0008 |        |                      |
# | trainable_func_12461c72 | RUNNING    | 172.28.0.2:474 | tanh    | selu   | relu   |            8 |           180 |           190 |           170 | 0.0006 |        |                      |
# | trainable_func_127f17ac | PENDING    |                | relu    | relu   | selu   |           64 |           170 |            80 |           140 | 0.0007 |        |                      |
# | trainable_func_ed86a122 | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | tanh   |          128 |            90 |            50 |           180 | 0.0009 |      0 |                   10 |
# | trainable_func_f07e762a | TERMINATED | 172.28.0.2:473 | tanh    | relu   | selu   |            8 |           130 |           170 |           100 | 0.0005 |      0 |                   10 |
# | trainable_func_f0903720 | TERMINATED | 172.28.0.2:474 | tanh    | relu   | relu   |           64 |           100 |            70 |           200 | 0.0008 |      0 |                   10 |
# | trainable_func_f09c5884 | TERMINATED | 172.28.0.2:537 | selu    | tanh   | relu   |           16 |            90 |           130 |           170 | 0.001  |      0 |                   10 |
# | trainable_func_f0afc6bc | TERMINATED | 172.28.0.2:426 | relu    | tanh   | relu   |           64 |           170 |           140 |           200 | 0.0009 |      0 |                   10 |
# | trainable_func_fbe1a5e6 | TERMINATED | 172.28.0.2:474 | selu    | relu   | selu   |            8 |            90 |            70 |            80 | 0.001  |      0 |                   10 |
# | trainable_func_fd337708 | TERMINATED | 172.28.0.2:426 | relu    | selu   | selu   |          128 |            50 |           130 |           100 | 0.0005 |      0 |                   10 |
# | trainable_func_05679242 | TERMINATED | 172.28.0.2:537 | tanh    | selu   | selu   |          128 |           100 |           140 |           180 | 0.0005 |      0 |                   10 |
# | trainable_func_09d33a16 | TERMINATED | 172.28.0.2:473 | selu    | selu   | relu   |          128 |           180 |           120 |            90 | 0.001  |      0 |                   10 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
#
#
# Trial trainable_func_0f0cfd8c reported epoch=0,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 16, 'hidden_dim1': 140.0, 'hidden_dim2': 70.0, 'hidden_dim3': 150.0}.
# Trial trainable_func_12461c72 reported epoch=0,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 180.0, 'hidden_dim2': 190.0, 'hidden_dim3': 170.0}.
# Trial trainable_func_06325838 reported epoch=9,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 190.0, 'hidden_dim2': 50.0, 'hidden_dim3': 130.0}. This trial completed.
# Trial trainable_func_127f17ac reported epoch=0,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0007, 'batch_size': 64, 'hidden_dim1': 170.0, 'hidden_dim2': 80.0, 'hidden_dim3': 140.0}.
# Trial trainable_func_01ae7094 reported epoch=6,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 160.0, 'hidden_dim2': 170.0, 'hidden_dim3': 130.0}.
# == Status ==
# Current time: 2022-07-16 14:46:33 (running for 00:01:07.93)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: -0.0 | Iter 4.000: -0.0
# Bracket: Iter 8.000: -0.0
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-16_14-45-25
# Number of trials: 15/50 (1 PENDING, 4 RUNNING, 10 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |   loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------|
# | trainable_func_01ae7094 | RUNNING    | 172.28.0.2:426 | selu    | relu   | selu   |            8 |           160 |           170 |           130 | 0.001  |      0 |                    7 |
# | trainable_func_0f0cfd8c | RUNNING    | 172.28.0.2:473 | selu    | relu   | tanh   |           16 |           140 |            70 |           150 | 0.0008 |      0 |                    3 |
# | trainable_func_12461c72 | RUNNING    | 172.28.0.2:474 | tanh    | selu   | relu   |            8 |           180 |           190 |           170 | 0.0006 |      0 |                    1 |
# | trainable_func_127f17ac | RUNNING    | 172.28.0.2:537 | relu    | relu   | selu   |           64 |           170 |            80 |           140 | 0.0007 |      0 |                    3 |
# | trainable_func_14e9d860 | PENDING    |                | tanh    | tanh   | tanh   |           32 |            50 |            90 |            50 | 0.0007 |        |                      |
# | trainable_func_ed86a122 | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | tanh   |          128 |            90 |            50 |           180 | 0.0009 |      0 |                   10 |
# | trainable_func_f07e762a | TERMINATED | 172.28.0.2:473 | tanh    | relu   | selu   |            8 |           130 |           170 |           100 | 0.0005 |      0 |                   10 |
# | trainable_func_f0903720 | TERMINATED | 172.28.0.2:474 | tanh    | relu   | relu   |           64 |           100 |            70 |           200 | 0.0008 |      0 |                   10 |
# | trainable_func_f09c5884 | TERMINATED | 172.28.0.2:537 | selu    | tanh   | relu   |           16 |            90 |           130 |           170 | 0.001  |      0 |                   10 |
# | trainable_func_f0afc6bc | TERMINATED | 172.28.0.2:426 | relu    | tanh   | relu   |           64 |           170 |           140 |           200 | 0.0009 |      0 |                   10 |
# | trainable_func_fbe1a5e6 | TERMINATED | 172.28.0.2:474 | selu    | relu   | selu   |            8 |            90 |            70 |            80 | 0.001  |      0 |                   10 |
# | trainable_func_fd337708 | TERMINATED | 172.28.0.2:426 | relu    | selu   | selu   |          128 |            50 |           130 |           100 | 0.0005 |      0 |                   10 |
# | trainable_func_05679242 | TERMINATED | 172.28.0.2:537 | tanh    | selu   | selu   |          128 |           100 |           140 |           180 | 0.0005 |      0 |                   10 |
# | trainable_func_06325838 | TERMINATED | 172.28.0.2:537 | relu    | selu   | selu   |           16 |           190 |            50 |           130 | 0.0009 |      0 |                   10 |
# | trainable_func_09d33a16 | TERMINATED | 172.28.0.2:473 | selu    | selu   | relu   |          128 |           180 |           120 |            90 | 0.001  |      0 |                   10 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
#
#
# Trial trainable_func_0f0cfd8c reported epoch=4,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 16, 'hidden_dim1': 140.0, 'hidden_dim2': 70.0, 'hidden_dim3': 150.0}.
# Trial trainable_func_127f17ac reported epoch=8,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0007, 'batch_size': 64, 'hidden_dim1': 170.0, 'hidden_dim2': 80.0, 'hidden_dim3': 140.0}.
# Trial trainable_func_127f17ac reported epoch=9,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0007, 'batch_size': 64, 'hidden_dim1': 170.0, 'hidden_dim2': 80.0, 'hidden_dim3': 140.0}. This trial completed.
# Trial trainable_func_12461c72 reported epoch=2,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 180.0, 'hidden_dim2': 190.0, 'hidden_dim3': 170.0}.
# == Status ==
# Current time: 2022-07-16 14:46:38 (running for 00:01:12.95)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: 0.0 | Iter 4.000: -0.0
# Bracket: Iter 8.000: 0.0
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-16_14-45-25
# Number of trials: 16/50 (1 PENDING, 4 RUNNING, 11 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |   loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------|
# | trainable_func_01ae7094 | RUNNING    | 172.28.0.2:426 | selu    | relu   | selu   |            8 |           160 |           170 |           130 | 0.001  |      0 |                    8 |
# | trainable_func_0f0cfd8c | RUNNING    | 172.28.0.2:473 | selu    | relu   | tanh   |           16 |           140 |            70 |           150 | 0.0008 |      0 |                    7 |
# | trainable_func_12461c72 | RUNNING    | 172.28.0.2:474 | tanh    | selu   | relu   |            8 |           180 |           190 |           170 | 0.0006 |      0 |                    3 |
# | trainable_func_14e9d860 | RUNNING    | 172.28.0.2:537 | tanh    | tanh   | tanh   |           32 |            50 |            90 |            50 | 0.0007 |        |                      |
# | trainable_func_18df2af6 | PENDING    |                | tanh    | tanh   | tanh   |           32 |           140 |           190 |            50 | 0.0007 |        |                      |
# | trainable_func_ed86a122 | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | tanh   |          128 |            90 |            50 |           180 | 0.0009 |      0 |                   10 |
# | trainable_func_f07e762a | TERMINATED | 172.28.0.2:473 | tanh    | relu   | selu   |            8 |           130 |           170 |           100 | 0.0005 |      0 |                   10 |
# ...
# Number of trials: 50/50 (1 RUNNING, 49 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |   loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------|
# | trainable_func_5336948c | RUNNING    | 172.28.0.2:473 | tanh    | tanh   | tanh   |            8 |           100 |           160 |           100 | 0.0005 |      0 |                    9 |
# | trainable_func_01ae7094 | TERMINATED | 172.28.0.2:426 | selu    | relu   | selu   |            8 |           160 |           170 |           130 | 0.001  |      0 |                   10 |
# | trainable_func_05679242 | TERMINATED | 172.28.0.2:537 | tanh    | selu   | selu   |          128 |           100 |           140 |           180 | 0.0005 |      0 |                   10 |
# | trainable_func_06325838 | TERMINATED | 172.28.0.2:537 | relu    | selu   | selu   |           16 |           190 |            50 |           130 | 0.0009 |      0 |                   10 |
# | trainable_func_09d33a16 | TERMINATED | 172.28.0.2:473 | selu    | selu   | relu   |          128 |           180 |           120 |            90 | 0.001  |      0 |                   10 |
# | trainable_func_0f0cfd8c | TERMINATED | 172.28.0.2:473 | selu    | relu   | tanh   |           16 |           140 |            70 |           150 | 0.0008 |      0 |                   10 |
# | trainable_func_12461c72 | TERMINATED | 172.28.0.2:474 | tanh    | selu   | relu   |            8 |           180 |           190 |           170 | 0.0006 |      0 |                   10 |
# | trainable_func_127f17ac | TERMINATED | 172.28.0.2:537 | relu    | relu   | selu   |           64 |           170 |            80 |           140 | 0.0007 |      0 |                   10 |
# | trainable_func_14e9d860 | TERMINATED | 172.28.0.2:537 | tanh    | tanh   | tanh   |           32 |            50 |            90 |            50 | 0.0007 |      0 |                   10 |
# | trainable_func_18df2af6 | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | tanh   |           32 |           140 |           190 |            50 | 0.0007 |      0 |                   10 |
# | trainable_func_1b7df65c | TERMINATED | 172.28.0.2:473 | tanh    | tanh   | tanh   |           32 |           130 |           190 |            50 | 0.0007 |      0 |                   10 |
# | trainable_func_1bf2e048 | TERMINATED | 172.28.0.2:537 | tanh    | tanh   | tanh   |           32 |           120 |           200 |            50 | 0.0006 |      0 |                   10 |
# | trainable_func_1e70a27e | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | tanh   |            8 |           130 |           200 |           110 | 0.0006 |      0 |                   10 |
# | trainable_func_21cd6ac4 | TERMINATED | 172.28.0.2:473 | tanh    | tanh   | tanh   |            8 |           120 |           200 |           110 | 0.0006 |      0 |                   10 |
# | trainable_func_2243253e | TERMINATED | 172.28.0.2:537 | tanh    | relu   | tanh   |            8 |            70 |           170 |           110 | 0.0006 |      0 |                   10 |
# | trainable_func_2483bb4c | TERMINATED | 172.28.0.2:474 | tanh    | tanh   | tanh   |          128 |            80 |           110 |           160 | 0.0009 |      0 |                   10 |
# | trainable_func_272a557c | TERMINATED | 172.28.0.2:474 | tanh    | tanh   | tanh   |           32 |            70 |           100 |            70 | 0.0009 |      0 |                   10 |
# | trainable_func_2a2e6a42 | TERMINATED | 172.28.0.2:474 | tanh    | tanh   | tanh   |           32 |            70 |            50 |            70 | 0.0008 |      0 |                   10 |
# | trainable_func_3077c290 | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | tanh   |           32 |           110 |           160 |            70 | 0.0006 |      0 |                   10 |
# | trainable_func_35a4f13e | TERMINATED | 172.28.0.2:474 | tanh    | tanh   | tanh   |            8 |           110 |           170 |           110 | 0.0006 |      0 |                   10 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
# ... 30 more trials not shown (30 TERMINATED)
# 2022-07-16 14:48:43,925	INFO tune.py:748 -- Total run time: 198.43 seconds (198.21 seconds for the tuning loop).
# Trial trainable_func_5336948c reported epoch=9,loss=0.0,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 100.0, 'hidden_dim2': 160.0, 'hidden_dim3': 100.0}. This trial completed.
# == Status ==
# Current time: 2022-07-16 14:48:43 (running for 00:03:18.24)
# Memory usage on this node: 1.5/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: 0.0 | Iter 4.000: 0.0
# Bracket: Iter 8.000: -0.0
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-16_14-45-25
# Number of trials: 50/50 (50 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |   loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------|
# | trainable_func_ed86a122 | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | tanh   |          128 |            90 |            50 |           180 | 0.0009 |      0 |                   10 |
# | trainable_func_f07e762a | TERMINATED | 172.28.0.2:473 | tanh    | relu   | selu   |            8 |           130 |           170 |           100 | 0.0005 |      0 |                   10 |
# | trainable_func_f0903720 | TERMINATED | 172.28.0.2:474 | tanh    | relu   | relu   |           64 |           100 |            70 |           200 | 0.0008 |      0 |                   10 |
# | trainable_func_f09c5884 | TERMINATED | 172.28.0.2:537 | selu    | tanh   | relu   |           16 |            90 |           130 |           170 | 0.001  |      0 |                   10 |
# | trainable_func_f0afc6bc | TERMINATED | 172.28.0.2:426 | relu    | tanh   | relu   |           64 |           170 |           140 |           200 | 0.0009 |      0 |                   10 |
# | trainable_func_fbe1a5e6 | TERMINATED | 172.28.0.2:474 | selu    | relu   | selu   |            8 |            90 |            70 |            80 | 0.001  |      0 |                   10 |
# | trainable_func_fd337708 | TERMINATED | 172.28.0.2:426 | relu    | selu   | selu   |          128 |            50 |           130 |           100 | 0.0005 |      0 |                   10 |
# | trainable_func_01ae7094 | TERMINATED | 172.28.0.2:426 | selu    | relu   | selu   |            8 |           160 |           170 |           130 | 0.001  |      0 |                   10 |
# | trainable_func_05679242 | TERMINATED | 172.28.0.2:537 | tanh    | selu   | selu   |          128 |           100 |           140 |           180 | 0.0005 |      0 |                   10 |
# | trainable_func_06325838 | TERMINATED | 172.28.0.2:537 | relu    | selu   | selu   |           16 |           190 |            50 |           130 | 0.0009 |      0 |                   10 |
# | trainable_func_09d33a16 | TERMINATED | 172.28.0.2:473 | selu    | selu   | relu   |          128 |           180 |           120 |            90 | 0.001  |      0 |                   10 |
# | trainable_func_0f0cfd8c | TERMINATED | 172.28.0.2:473 | selu    | relu   | tanh   |           16 |           140 |            70 |           150 | 0.0008 |      0 |                   10 |
# | trainable_func_12461c72 | TERMINATED | 172.28.0.2:474 | tanh    | selu   | relu   |            8 |           180 |           190 |           170 | 0.0006 |      0 |                   10 |
# | trainable_func_127f17ac | TERMINATED | 172.28.0.2:537 | relu    | relu   | selu   |           64 |           170 |            80 |           140 | 0.0007 |      0 |                   10 |
# | trainable_func_14e9d860 | TERMINATED | 172.28.0.2:537 | tanh    | tanh   | tanh   |           32 |            50 |            90 |            50 | 0.0007 |      0 |                   10 |
# | trainable_func_18df2af6 | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | tanh   |           32 |           140 |           190 |            50 | 0.0007 |      0 |                   10 |
# | trainable_func_1b7df65c | TERMINATED | 172.28.0.2:473 | tanh    | tanh   | tanh   |           32 |           130 |           190 |            50 | 0.0007 |      0 |                   10 |
# | trainable_func_1bf2e048 | TERMINATED | 172.28.0.2:537 | tanh    | tanh   | tanh   |           32 |           120 |           200 |            50 | 0.0006 |      0 |                   10 |
# | trainable_func_1e70a27e | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | tanh   |            8 |           130 |           200 |           110 | 0.0006 |      0 |                   10 |
# | trainable_func_21cd6ac4 | TERMINATED | 172.28.0.2:473 | tanh    | tanh   | tanh   |            8 |           120 |           200 |           110 | 0.0006 |      0 |                   10 |
# | trainable_func_2243253e | TERMINATED | 172.28.0.2:537 | tanh    | relu   | tanh   |            8 |            70 |           170 |           110 | 0.0006 |      0 |                   10 |
# | trainable_func_2483bb4c | TERMINATED | 172.28.0.2:474 | tanh    | tanh   | tanh   |          128 |            80 |           110 |           160 | 0.0009 |      0 |                   10 |
# | trainable_func_272a557c | TERMINATED | 172.28.0.2:474 | tanh    | tanh   | tanh   |           32 |            70 |           100 |            70 | 0.0009 |      0 |                   10 |
# | trainable_func_2a2e6a42 | TERMINATED | 172.28.0.2:474 | tanh    | tanh   | tanh   |           32 |            70 |            50 |            70 | 0.0008 |      0 |                   10 |
# | trainable_func_3077c290 | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | tanh   |           32 |           110 |           160 |            70 | 0.0006 |      0 |                   10 |
# | trainable_func_35a4f13e | TERMINATED | 172.28.0.2:474 | tanh    | tanh   | tanh   |            8 |           110 |           170 |           110 | 0.0006 |      0 |                   10 |
# | trainable_func_35c09bf0 | TERMINATED | 172.28.0.2:473 | tanh    | tanh   | tanh   |          128 |           110 |           160 |           150 | 0.0009 |      0 |                   10 |
# | trainable_func_362bbb56 | TERMINATED | 172.28.0.2:537 | tanh    | tanh   | tanh   |          128 |           110 |           110 |           150 | 0.0009 |      0 |                   10 |
# | trainable_func_3688a15e | TERMINATED | 172.28.0.2:473 | tanh    | relu   | tanh   |          128 |            70 |           110 |           160 | 0.0009 |      0 |                   10 |
# | trainable_func_39934426 | TERMINATED | 172.28.0.2:537 | tanh    | tanh   | tanh   |          128 |            70 |           100 |           180 | 0.0009 |      0 |                   10 |
# | trainable_func_39bbb668 | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | tanh   |           32 |            70 |            50 |            80 | 0.0008 |      0 |                   10 |
# | trainable_func_3c8a6420 | TERMINATED | 172.28.0.2:473 | tanh    | tanh   | tanh   |           32 |            60 |            50 |            70 | 0.0008 |      0 |                   10 |
# | trainable_func_3ca5823c | TERMINATED | 172.28.0.2:537 | tanh    | tanh   | tanh   |          128 |           110 |           150 |           190 | 0.0008 |      0 |                   10 |
# | trainable_func_3d166876 | TERMINATED | 172.28.0.2:537 | relu    | tanh   | tanh   |          128 |           110 |           150 |           150 | 0.0008 |      0 |                   10 |
# | trainable_func_40822cf2 | TERMINATED | 172.28.0.2:473 | relu    | relu   | tanh   |          128 |            90 |           120 |           160 | 0.001  |      0 |                   10 |
# | trainable_func_420f8286 | TERMINATED | 172.28.0.2:426 | tanh    | relu   | tanh   |          128 |            80 |           110 |           180 | 0.0009 |      0 |                   10 |
# | trainable_func_4267e34a | TERMINATED | 172.28.0.2:537 | tanh    | relu   | tanh   |          128 |            80 |            60 |           180 | 0.0009 |      0 |                   10 |
# | trainable_func_4402ff14 | TERMINATED | 172.28.0.2:473 | tanh    | tanh   | tanh   |           32 |            60 |            60 |           190 | 0.0008 |      0 |                   10 |
# | trainable_func_455b5410 | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | relu   |           32 |            60 |            60 |           190 | 0.0008 |      0 |                   10 |
# | trainable_func_45cf1364 | TERMINATED | 172.28.0.2:537 | tanh    | relu   | relu   |            8 |            80 |           180 |           120 | 0.0005 |      0 |                   10 |
# | trainable_func_471b2032 | TERMINATED | 172.28.0.2:474 | tanh    | relu   | relu   |           64 |            60 |            80 |           120 | 0.001  |      0 |                   10 |
# | trainable_func_4a47c242 | TERMINATED | 172.28.0.2:473 | selu    | relu   | relu   |           64 |            60 |            80 |           200 | 0.001  |      0 |                   10 |
# | trainable_func_4bb9db24 | TERMINATED | 172.28.0.2:426 | selu    | tanh   | relu   |           64 |            90 |            80 |            70 | 0.001  |      0 |                   10 |
# | trainable_func_4c583ee0 | TERMINATED | 172.28.0.2:474 | selu    | tanh   | relu   |           64 |            90 |            90 |            70 | 0.001  |      0 |                   10 |
# | trainable_func_4e5979d4 | TERMINATED | 172.28.0.2:473 | selu    | tanh   | selu   |           32 |            90 |            90 |            60 | 0.0005 |      0 |                   10 |
# | trainable_func_506656ca | TERMINATED | 172.28.0.2:426 | tanh    | tanh   | tanh   |           32 |           100 |           160 |            70 | 0.0005 |      0 |                   10 |
# | trainable_func_51644974 | TERMINATED | 172.28.0.2:474 | tanh    | tanh   | tanh   |           16 |           100 |           160 |            90 | 0.0005 |      0 |                   10 |
# | trainable_func_5336948c | TERMINATED | 172.28.0.2:473 | tanh    | tanh   | tanh   |            8 |           100 |           160 |           100 | 0.0005 |      0 |                   10 |
# | trainable_func_56a522f0 | TERMINATED | 172.28.0.2:426 | tanh    | selu   | tanh   |           16 |           110 |           160 |           140 | 0.0005 |      0 |                   10 |
# | trainable_func_57bb2068 | TERMINATED | 172.28.0.2:537 | tanh    | selu   | tanh   |           16 |           110 |           140 |           140 | 0.0009 |      0 |                   10 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
#
#
# Best trial config: {'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 128, 'hidden_dim1': 90.0, 'hidden_dim2': 50.0, 'hidden_dim3': 180.0}
# Best trial final validation score: 0.0
# Best trial test set score: 0.0

# %%
from ray.tune.suggest.hyperopt import HyperOptSearch
from ray.tune.suggest.optuna import OptunaSearch  
from ray.tune.suggest.dragonfly import DragonflySearch
from ray.tune.suggest.bayesopt import BayesOptSearch
from ray.tune.schedulers.hb_bohb import HyperBandForBOHB
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.schedulers import MedianStoppingRule
from ray.tune.schedulers import PopulationBasedTraining
from ray.tune.suggest.bohb import TuneBOHB
from ray.tune.suggest.basic_variant import BasicVariantGenerator
from ray.tune.suggest import ConcurrencyLimiter

# %%
training_iteration = 50 #max_num_epochs

## ASHA
scheduler = AsyncHyperBandScheduler(
    time_attr="training_iteration",
    max_t=training_iteration,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    reduction_factor=2, 
    grace_period=4,
    brackets=5,
    )

## BOHB
scheduler = HyperBandForBOHB(
    time_attr="training_iteration",
    max_t=training_iteration, 
    reduction_factor=8, 
    stop_last_trials=True,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    )

## Median
scheduler = MedianStoppingRule(
    time_attr="training_iteration",
    grace_period=10,
    min_samples_required=10,
    hard_stop = True,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    )

## PBT
scheduler = PopulationBasedTraining(
    time_attr="training_iteration",
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    perturbation_interval=10,  # every 10 `time_attr` units
                            # (training_iterations in this case)
    # hyperparam_mutations={
    #     "lr": [8e-3, 7e-3, 6e-3, 5e-3, 4e-3],
    #     "dropout": tune.quniform(0.0, 0.4, 0.05),
    #     "dropout1": tune.quniform(0.0, 0.4, 0.05),
    #     "dropout2": tune.quniform(0.0, 0.4, 0.05),
    #     "max_norm_val":tune.choice([2.5, 3, 3.5, 4]),
    #     }
    )

# %%
## BOHB
search_alg = TuneBOHB(
    # space=config_space,  # If you want to set the space manually
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    # seed = 42,
    # points_to_evaluate=[
    # ],
    )

## Hyperopt
search_alg = HyperOptSearch(
    # space=config,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    n_initial_points=60,
    # gamma = 0.1,
    # random_state_seed=42,
    # points_to_evaluate=[{"max_norm_val": 2.5, 'GNN_Layers': 3, 'dropout': 0.25, 'dropout1': 0.35, 'dropout2': 0.15, 'lr': 0.001, 'hidden_size': 80, 'readout1_out': 150, 'readout2_out': 100, 'batch_size': 64}],
    )

## Optuna
search_alg = OptunaSearch(
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    # seed = 42,
    # points_to_evaluate=[
    # {'dropout': 0.2, 'dropout1': 0.1, 'dropout2': 0.25, 'lr': 0.0005, 'hidden_size': 150.0, 'readout1_out': 200.0, 'readout2_out': 180.0, 'max_norm_val': 2.5}
    # ],
    )

## Dragonfly
search_alg = DragonflySearch(
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    optimizer="bandit", #[random, bandit, genetic]
    # points_to_evaluate=[
    # {'max_norm_val': 2.5, 'dropout': 0.3, 'dropout1': 0.1, 'dropout2': 0.0, 'lr': 0.0008, 'hidden_size': 90, 'readout1_out': 150, 'readout2_out': 140}
    # ],
    # domain=euclidean, #[cartesian, euclidean]
    )

## Bayesopt
search_alg = BayesOptSearch(
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    random_search_steps = 60, 
    # points_to_evaluate=[
    # {'max_norm_val': 2.5, 'dropout': 0.3, 'dropout1': 0.1, 'dropout2': 0.0, 'lr': 0.0008, 'hidden_size': 90, 'readout1_out': 150, 'readout2_out': 140}
    # ],
    )
# Out:
# ERROR:root:An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 49))
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-35-b5459d103f61> in <module>()
#       3     # space=config_space,  # If you want to set the space manually
#       4     metric="loss", #or accuracy, etc.
# ----> 5     mode="min", #or max
#       6     # seed = 42,
#       7     # points_to_evaluate=[
#
# /usr/local/lib/python3.7/dist-packages/ray/tune/suggest/bohb.py in __init__(self, space, bohb_config, metric, mode, points_to_evaluate, seed)
#     134         ), """HpBandSter must be installed!
#     135             You can install HpBandSter with the command:
# --> 136             `pip install hpbandster ConfigSpace`."""
#     137         if mode:
#     138             assert mode in ["min", "max"], "`mode` must be 'min' or 'max'."
#
# AssertionError: HpBandSter must be installed!
#             You can install HpBandSter with the command:
#             `pip install hpbandster ConfigSpace`.
