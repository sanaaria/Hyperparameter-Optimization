# %% [markdown]
# <a href="https://colab.research.google.com/github/sanaaria/Hyperparameter-Optimization/blob/main/hyperparameters_optimization.bbbp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dragonfly-opt
# !pip install -U hyperopt
# !pip install hpbandster ConfigSpace
# !pip install optuna

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset
from pandas import read_csv
from sklearn.impute import SimpleImputer

#visualizations
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-428dede6-6602-4893-b91c-b570c4cce0ba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-428dede6-6602-4893-b91c-b570c4cce0ba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bbbp.csv to bbbp.csv

# %%
import pandas as pd
import io
data = pd.read_csv(io.BytesIO(uploaded['bbbp.csv']))
data.head()
# Out:
#                                               smiles  \
# 0                   [Cl].CC(C)NCC(O)COc1cccc2ccccc12
# 1           C(=O)(OC(C)(C)C)CCCc1ccc(cc1)N(CCCl)CCCl
# 2  c12c3c(N4CCN(C)CC4)c(F)cc1c(c(C(O)=O)cn2C(C)CO...
# 3                   C1CCN(CC1)Cc1cccc(c1)OCCCNC(=O)C
# 4  Cc1onc(c2ccccc2Cl)c1C(=O)N[C@H]3[C@H]4SC(C)(C)...
#
#    ('RDKit2DNormalized_calculated', <class 'bool'>)  \
# 0                                              True
# 1                                              True
# 2                                              True
# 3                                              True
# 4                                              True
#
#    ('BalabanJ', <class 'numpy.float64'>)  \
# 0                               0.000020
# 1                               0.921082
# 2                               0.755549
# 3                               0.519074
# 4                               0.362651
#
#    ('BertzCT', <class 'numpy.float64'>)  ('Chi0', <class 'numpy.float64'>)  \
# 0                              0.111833                           0.106451
# 1                              0.077697                           0.324169
# 2                              0.516673                           0.423380
# 3                              0.068097                           0.166625
# 4                              0.590649                           0.607809
#
#    ('Chi0n', <class 'numpy.float64'>)  ('Chi0v', <class 'numpy.float64'>)  \
# 0                            0.177350                            0.187815
# 1                            0.379878                            0.467164
# 2                            0.415340                            0.360944
# 3                            0.260552                            0.212714
# 4                            0.520746                            0.607038
#
#    ('Chi1', <class 'numpy.float64'>)  ('Chi1n', <class 'numpy.float64'>)  \
# 0                           0.110054                            0.168672
# 1                           0.240353                            0.344156
# 2                           0.400697                            0.428148
# 3                           0.185779                            0.328404
# 4                           0.538488                            0.471718
#
#    ('Chi1v', <class 'numpy.float64'>)  ...  \
# 0                            0.119391  ...
# 1                            0.422452  ...
# 2                            0.348007  ...
# 3                            0.255385  ...
# 4                            0.569018  ...
#
#    ('fr_sulfone', <class 'numpy.float64'>)  \
# 0                             5.770000e-14
# 1                             5.770000e-14
# 2                             5.770000e-14
# 3                             5.770000e-14
# 4                             5.770000e-14
#
#    ('fr_term_acetylene', <class 'numpy.float64'>)  \
# 0                                    2.960000e-11
# 1                                    2.960000e-11
# 2                                    2.960000e-11
# 3                                    2.960000e-11
# 4                                    2.960000e-11
#
#    ('fr_tetrazole', <class 'numpy.float64'>)  \
# 0                                   0.168378
# 1                                   0.168378
# 2                                   0.168378
# 3                                   0.168378
# 4                                   0.168378
#
#    ('fr_thiazole', <class 'numpy.float64'>)  \
# 0                                   0.16738
# 1                                   0.16738
# 2                                   0.16738
# 3                                   0.16738
# 4                                   0.16738
#
#    ('fr_thiocyan', <class 'numpy.float64'>)  \
# 0                              1.480000e-18
# 1                              1.480000e-18
# 2                              1.480000e-18
# 3                              1.480000e-18
# 4                              1.480000e-18
#
#    ('fr_thiophene', <class 'numpy.float64'>)  \
# 0                               2.320000e-16
# 1                               2.320000e-16
# 2                               2.320000e-16
# 3                               2.320000e-16
# 4                               2.320000e-16
#
#    ('fr_unbrch_alkane', <class 'numpy.float64'>)  \
# 0                                   4.700000e-08
# 1                                   4.700000e-08
# 2                                   4.700000e-08
# 3                                   9.991992e-01
# 4                                   4.700000e-08
#
#    ('fr_urea', <class 'numpy.float64'>)  ('qed', <class 'numpy.float64'>)  \
# 0                              0.166633                          0.930688
# 1                              0.166633                          0.322648
# 2                              0.166633                          0.949987
# 3                              0.166633                          0.818175
# 4                              0.166633                          0.689000
#
#    p_np
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#
# [5 rows x 203 columns]

# %%
del data["('RDKit2DNormalized_calculated', <class 'bool'>)"]
del data["smiles"]
#data.insert(0, 'smiles', first_column)
data.head()
# Out:
#    ('BalabanJ', <class 'numpy.float64'>)  \
# 0                               0.000020
# 1                               0.921082
# 2                               0.755549
# 3                               0.519074
# 4                               0.362651
#
#    ('BertzCT', <class 'numpy.float64'>)  ('Chi0', <class 'numpy.float64'>)  \
# 0                              0.111833                           0.106451
# 1                              0.077697                           0.324169
# 2                              0.516673                           0.423380
# 3                              0.068097                           0.166625
# 4                              0.590649                           0.607809
#
#    ('Chi0n', <class 'numpy.float64'>)  ('Chi0v', <class 'numpy.float64'>)  \
# 0                            0.177350                            0.187815
# 1                            0.379878                            0.467164
# 2                            0.415340                            0.360944
# 3                            0.260552                            0.212714
# 4                            0.520746                            0.607038
#
#    ('Chi1', <class 'numpy.float64'>)  ('Chi1n', <class 'numpy.float64'>)  \
# 0                           0.110054                            0.168672
# 1                           0.240353                            0.344156
# 2                           0.400697                            0.428148
# 3                           0.185779                            0.328404
# 4                           0.538488                            0.471718
#
#    ('Chi1v', <class 'numpy.float64'>)  ('Chi2n', <class 'numpy.float64'>)  \
# 0                            0.119391                            0.185866
# 1                            0.422452                            0.438361
# 2                            0.348007                            0.528003
# 3                            0.255385                            0.291954
# 4                            0.569018                            0.615152
#
#    ('Chi2v', <class 'numpy.float64'>)  ...  \
# 0                            0.119537  ...
# 1                            0.462373  ...
# 2                            0.416469  ...
# 3                            0.201587  ...
# 4                            0.792858  ...
#
#    ('fr_sulfone', <class 'numpy.float64'>)  \
# 0                             5.770000e-14
# 1                             5.770000e-14
# 2                             5.770000e-14
# 3                             5.770000e-14
# 4                             5.770000e-14
#
#    ('fr_term_acetylene', <class 'numpy.float64'>)  \
# 0                                    2.960000e-11
# 1                                    2.960000e-11
# 2                                    2.960000e-11
# 3                                    2.960000e-11
# 4                                    2.960000e-11
#
#    ('fr_tetrazole', <class 'numpy.float64'>)  \
# 0                                   0.168378
# 1                                   0.168378
# 2                                   0.168378
# 3                                   0.168378
# 4                                   0.168378
#
#    ('fr_thiazole', <class 'numpy.float64'>)  \
# 0                                   0.16738
# 1                                   0.16738
# 2                                   0.16738
# 3                                   0.16738
# 4                                   0.16738
#
#    ('fr_thiocyan', <class 'numpy.float64'>)  \
# 0                              1.480000e-18
# 1                              1.480000e-18
# 2                              1.480000e-18
# 3                              1.480000e-18
# 4                              1.480000e-18
#
#    ('fr_thiophene', <class 'numpy.float64'>)  \
# 0                               2.320000e-16
# 1                               2.320000e-16
# 2                               2.320000e-16
# 3                               2.320000e-16
# 4                               2.320000e-16
#
#    ('fr_unbrch_alkane', <class 'numpy.float64'>)  \
# 0                                   4.700000e-08
# 1                                   4.700000e-08
# 2                                   4.700000e-08
# 3                                   9.991992e-01
# 4                                   4.700000e-08
#
#    ('fr_urea', <class 'numpy.float64'>)  ('qed', <class 'numpy.float64'>)  \
# 0                              0.166633                          0.930688
# 1                              0.166633                          0.322648
# 2                              0.166633                          0.949987
# 3                              0.166633                          0.818175
# 4                              0.166633                          0.689000
#
#    p_np
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#
# [5 rows x 201 columns]

# %%
data.shape
# Out:
# (2039, 201)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2039 entries, 0 to 2038
# Columns: 201 entries, ('BalabanJ', <class 'numpy.float64'>) to p_np
# dtypes: float64(199), int64(2)
# memory usage: 3.1 MB

# %%
data.describe()
# Out:
#        ('BalabanJ', <class 'numpy.float64'>)  \
# count                            2039.000000
# mean                                0.604334
# std                                 0.312428
# min                                 0.000020
# 25%                                 0.376547
# 50%                                 0.684349
# 75%                                 0.874519
# max                                 0.999343
#
#        ('BertzCT', <class 'numpy.float64'>)  \
# count                           2039.000000
# mean                               0.291380
# std                                0.251739
# min                                0.000577
# 25%                                0.082053
# 50%                                0.230083
# 75%                                0.438195
# max                                1.000000
#
#        ('Chi0', <class 'numpy.float64'>)  ('Chi0n', <class 'numpy.float64'>)  \
# count                        2039.000000                        2.039000e+03
# mean                            0.337879                        3.573345e-01
# std                             0.293971                        2.893572e-01
# min                             0.000002                        1.980000e-08
# 25%                             0.082985                        9.334640e-02
# 50%                             0.243373                        2.944113e-01
# 75%                             0.560798                        5.762799e-01
# max                             0.999913                        9.998828e-01
#
#        ('Chi0v', <class 'numpy.float64'>)  ('Chi1', <class 'numpy.float64'>)  \
# count                        2.039000e+03                        2039.000000
# mean                         3.555512e-01                           0.330076
# std                          2.938552e-01                           0.282478
# min                          4.530000e-07                           0.000001
# 25%                          8.693349e-02                           0.085748
# 50%                          2.866005e-01                           0.256325
# 75%                          5.794196e-01                           0.538452
# max                          9.999034e-01                           0.999915
#
#        ('Chi1n', <class 'numpy.float64'>)  ('Chi1v', <class 'numpy.float64'>)  \
# count                        2.039000e+03                         2039.000000
# mean                         3.722977e-01                            0.364649
# std                          2.921984e-01                            0.292215
# min                          2.680000e-07                            0.000042
# 25%                          1.031724e-01                            0.093407
# 50%                          3.198660e-01                            0.309533
# 75%                          6.049746e-01                            0.595135
# max                          9.998737e-01                            0.999931
#
#        ('Chi2n', <class 'numpy.float64'>)  ('Chi2v', <class 'numpy.float64'>)  \
# count                         2039.000000                        2.039000e+03
# mean                             0.409469                        4.051476e-01
# std                              0.313242                        3.164573e-01
# min                              0.000001                        2.210000e-07
# 25%                              0.112201                        1.007599e-01
# 50%                              0.364833                        3.658837e-01
# 75%                              0.661656                        6.885461e-01
# max                              0.999863                        9.998239e-01
#
#        ...  ('fr_sulfone', <class 'numpy.float64'>)  \
# count  ...                             2.039000e+03
# mean   ...                             9.808730e-03
# std    ...                             9.857629e-02
# min    ...                             5.770000e-14
# 25%    ...                             5.770000e-14
# 50%    ...                             5.770000e-14
# 75%    ...                             5.770000e-14
# max    ...                             1.000000e+00
#
#        ('fr_term_acetylene', <class 'numpy.float64'>)  \
# count                                    2.039000e+03
# mean                                     7.846984e-03
# std                                      8.825661e-02
# min                                      2.960000e-11
# 25%                                      2.960000e-11
# 50%                                      2.960000e-11
# 75%                                      2.960000e-11
# max                                      1.000000e+00
#
#        ('fr_tetrazole', <class 'numpy.float64'>)  \
# count                                2039.000000
# mean                                    0.177759
# std                                     0.087846
# min                                     0.168378
# 25%                                     0.168378
# 50%                                     0.168378
# 75%                                     0.168378
# max                                     1.000000
#
#        ('fr_thiazole', <class 'numpy.float64'>)  \
# count                               2039.000000
# mean                                   0.186164
# std                                    0.123671
# min                                    0.167380
# 25%                                    0.167380
# 50%                                    0.167380
# 75%                                    0.167380
# max                                    1.000000
#
#        ('fr_thiocyan', <class 'numpy.float64'>)  \
# count                              2.039000e+03
# mean                               1.480000e-18
# std                                5.779207e-34
# min                                1.480000e-18
# 25%                                1.480000e-18
# 50%                                1.480000e-18
# 75%                                1.480000e-18
# max                                1.480000e-18
#
#        ('fr_thiophene', <class 'numpy.float64'>)  \
# count                               2.039000e+03
# mean                                1.618440e-02
# std                                 1.262152e-01
# min                                 2.320000e-16
# 25%                                 2.320000e-16
# 50%                                 2.320000e-16
# 75%                                 2.320000e-16
# max                                 1.000000e+00
#
#        ('fr_unbrch_alkane', <class 'numpy.float64'>)  \
# count                                   2.039000e+03
# mean                                    8.005408e-02
# std                                     2.681487e-01
# min                                     4.700000e-08
# 25%                                     4.700000e-08
# 50%                                     4.700000e-08
# 75%                                     4.700000e-08
# max                                     1.000000e+00
#
#        ('fr_urea', <class 'numpy.float64'>)  ('qed', <class 'numpy.float64'>)  \
# count                           2039.000000                       2039.000000
# mean                               0.201374                          0.578456
# std                                0.166608                          0.279008
# min                                0.166633                          0.003427
# 25%                                0.166633                          0.370570
# 50%                                0.166633                          0.631207
# 75%                                0.166633                          0.812874
# max                                1.000000                          0.999021
#
#               p_np
# count  2039.000000
# mean      0.765081
# std       0.424052
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
#
# [8 rows x 201 columns]

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
Xdata = data.iloc[:, 0:200]
Ydata = data.iloc[:, 200:201]

# %%
Ydata.head
# Out:
# <bound method NDFrame.head of       p_np
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ...    ...
# 2034     1
# 2035     1
# 2036     1
# 2037     1
# 2038     1
#
# [2039 rows x 1 columns]>

# %%
# from sklearn.model_selection import train_test_split
# train_data, test_data, train_labels, test_labels = train_test_split(Xdata, Ydata, test_size=0.3, random_state=1)
# print(train_data.shape, train_labels.shape, test_data.shape, test_labels.shape)

from sklearn.model_selection import train_test_split
train_data, test_data, train_labels, test_labels = train_test_split(Xdata, Ydata, stratify = Ydata , test_size = 0.25)

# %%
train_data = np.array(train_data)
test_data = np.array(test_data)

train_labels = np.array(train_labels)
test_labels = np.array(test_labels)

# %%
train_data.shape
# Out:
# (1529, 200)

# %%
# from sklearn.decomposition import PCA as sklearnPCA
# sklearn_pca = sklearnPCA(n_components=15)
# X_train_pca = sklearn_pca.fit_transform(X_train)
# print(X_train_pca.shape)

# %%
# from sklearn import preprocessing

# scaler_data = preprocessing.MinMaxScaler()
# train_data = scaler_data.fit_transform(train_data)
# test_data = scaler_data.transform(test_data)

# scaler_labels = preprocessing.MinMaxScaler()
# train_labels_before = train_labels.values.reshape(-1, 1)
# train_labels = scaler_labels.fit_transform(train_labels.values.reshape(-1, 1))
# test_labels = scaler_labels.transform(test_labels.values.reshape(-1, 1))

# print(train_data.shape, train_labels.shape, test_data.shape, test_labels.shape)
# print("Train labels before scaling: {} {} {}Train labels after scaling: {} {}".format('\n',train_labels_before,'\n', '\n', train_labels))

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# transform to torch tensor

tensor_x = torch.tensor(train_data, dtype=torch.float).to(device) 
tensor_x2 = torch.tensor(test_data, dtype=torch.float).to(device) 

tensor_y = torch.tensor(train_labels, dtype=torch.float).to(device)
tensor_y2 = torch.tensor(test_labels, dtype=torch.float).to(device)

# %%
tensor_x
# Out:
# tensor([[9.0873e-01, 6.9586e-02, 1.4914e-01,  ..., 4.7000e-08, 1.6663e-01,
#          8.2732e-01],
#         [4.6031e-01, 9.7198e-02, 2.2618e-01,  ..., 4.7000e-08, 1.6663e-01,
#          3.3268e-01],
#         [2.9321e-01, 3.4814e-01, 3.8537e-01,  ..., 4.7000e-08, 1.6663e-01,
#          8.4398e-01],
#         ...,
#         [7.9097e-01, 3.4212e-01, 3.8409e-01,  ..., 4.7000e-08, 1.0000e+00,
#          4.2708e-01],
#         [9.0245e-01, 3.3775e-02, 7.0925e-02,  ..., 4.7000e-08, 1.6663e-01,
#          5.1217e-01],
#         [5.0259e-02, 7.5932e-01, 6.8568e-01,  ..., 9.9920e-01, 1.6663e-01,
#          1.7538e-01]])

# %%
# create your dataset

trainset = TensorDataset(tensor_x, tensor_y) 
testset = TensorDataset(tensor_x2,tensor_y2)

# %%
trainset[0]
# Out:
# (tensor([9.0873e-01, 6.9586e-02, 1.4914e-01, 2.4628e-01, 1.9968e-01, 1.3904e-01,
#          2.7932e-01, 2.1188e-01, 2.9744e-01, 2.0607e-01, 4.1594e-01, 3.0242e-01,
#          4.7760e-01, 3.5333e-01, 5.8402e-01, 2.6487e-01, 6.8900e-07, 2.2029e-01,
#          3.3990e-01, 7.0831e-01, 9.2600e-11, 5.8600e-17, 6.2666e-01, 7.7487e-01,
#          3.4911e-01, 1.1022e-01, 9.0775e-01, 8.5173e-01, 7.0729e-01, 8.4676e-01,
#          9.0475e-01, 1.3706e-01, 9.1711e-02, 1.0000e+00, 2.1414e-01, 2.4493e-01,
#          3.7419e-01, 1.4707e-01, 2.1531e-01, 5.0796e-01, 2.1531e-01, 7.6741e-01,
#          5.1543e-01, 7.6653e-01, 4.6933e-01, 4.8029e-01, 4.4516e-01, 1.6787e-01,
#          1.0716e-01, 6.1316e-02, 1.2405e-01, 9.9400e-22, 9.1873e-01, 5.0000e-01,
#          3.5821e-01, 4.8300e-15, 8.3758e-02, 1.6844e-01, 5.5287e-02, 3.3458e-02,
#          5.7000e-08, 2.1430e-01, 0.0000e+00, 9.8000e-01, 8.8066e-01, 1.8301e-01,
#          3.3645e-01, 4.5831e-01, 3.6100e-15, 1.4598e-01, 1.7400e-22, 8.9828e-01,
#          3.1226e-01, 9.0500e-08, 4.6100e-10, 1.5707e-01, 7.2997e-01, 1.2177e-01,
#          7.6170e-01, 2.7501e-02, 1.2027e-01, 3.1121e-01, 1.3599e-01, 1.6710e-01,
#          1.9057e-01, 9.8764e-01, 7.1378e-01, 6.3325e-01, 2.1106e-01, 5.3000e-05,
#          1.4300e-16, 3.7316e-02, 6.9500e-13, 0.0000e+00, 9.8000e-13, 4.1261e-01,
#          6.5896e-01, 9.3953e-01, 7.1134e-01, 2.5614e-01, 2.9900e-06, 2.7764e-01,
#          5.3000e-05, 4.3578e-02, 5.3000e-05, 5.0000e-01, 3.8471e-01, 5.3000e-05,
#          5.3000e-05, 1.6466e-01, 5.3000e-05, 9.9865e-01, 3.9982e-01, 2.3966e-01,
#          5.7100e-19, 3.3200e-10, 9.6400e-10, 7.1100e-15, 5.8400e-13, 1.2000e-20,
#          1.6508e-01, 1.6704e-01, 1.6650e-01, 1.6649e-01, 5.0000e-01, 5.0000e-01,
#          7.1100e-15, 1.6835e-01, 1.6798e-01, 2.7743e-01, 1.1816e-03, 1.6433e-01,
#          8.3778e-04, 1.6633e-01, 9.9962e-01, 1.6508e-01, 9.5700e-08, 3.5000e-08,
#          1.6821e-01, 1.6581e-01, 1.6735e-01, 7.1400e-07, 2.6400e-12, 9.9913e-02,
#          2.8700e-10, 3.7774e-01, 4.5062e-03, 1.3325e-01, 3.5823e-01, 1.6100e-09,
#          1.8800e-18, 2.0900e-07, 7.1100e-15, 4.9926e-01, 9.9997e-01, 7.6084e-01,
#          2.1100e-16, 1.1700e-09, 3.2600e-22, 6.2500e-10, 1.6815e-01, 1.6545e-01,
#          1.1700e-13, 0.0000e+00, 1.6467e-01, 1.6692e-01, 0.0000e+00, 5.1000e-08,
#          7.1100e-15, 1.5465e-01, 2.7900e-22, 0.0000e+00, 1.6764e-01, 6.3100e-25,
#          1.6819e-01, 9.0885e-03, 1.6836e-01, 8.2700e-11, 1.5635e-01, 0.0000e+00,
#          0.0000e+00, 2.1135e-02, 2.1135e-02, 9.9998e-01, 0.0000e+00, 8.3400e-25,
#          5.3000e-05, 1.5695e-01, 4.0300e-08, 1.5500e-23, 1.5900e-17, 5.7700e-14,
#          2.9600e-11, 1.6838e-01, 1.6738e-01, 1.4800e-18, 2.3200e-16, 4.7000e-08,
#          1.6663e-01, 8.2732e-01]), tensor([1.]))

# %%
# %%capture
try:
    import ray
except:
    # !pip install -U ray
    import ray

# %%
from functools import partial
import numpy as np
import os
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
from torchsummary import summary

from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler

# %%
def load_data(data_dir=None):
    return trainset, testset

# %%
from sklearn.metrics import roc_auc_score

def compute_score(model, data_loader, device="cpu"):
    model.eval()
    metric = roc_auc_score
    with torch.no_grad():
        prediction_all= torch.empty(0, device=device)
        labels_all= torch.empty(0, device=device)
        for i, (feats, labels) in enumerate(data_loader):
            feats=feats.to(device)
            labels=labels.to(device)
            prediction = model(feats).to(device)
            prediction = torch.sigmoid(prediction).to(device)
            prediction_all = torch.cat((prediction_all, prediction), 0)
            labels_all = torch.cat((labels_all, labels), 0)                
        try:
            t = metric(labels_all.int().cpu(), prediction_all.cpu()).item()
        except ValueError:
            t = 0
    return t

# %%
class Net(nn.Module):
    def __init__(self, config):
        super().__init__()
        
        self.config = config
        self.hidden_dim1 = int(self.config.get("hidden_dim1", 100))
        self.hidden_dim2 = int(self.config.get("hidden_dim2", 100))
        self.hidden_dim3 = int(self.config.get("hidden_dim3", 100))

        self.act1 = self.config.get("act1", "relu") 
        self.act2 = self.config.get("act2", "relu") 
        self.act3 = self.config.get("act3", "relu")

        self.linear1 = nn.Linear(200, self.hidden_dim1)
        self.linear2 = nn.Linear(self.hidden_dim1, self.hidden_dim2)
        self.linear3 = nn.Linear(self.hidden_dim2, self.hidden_dim3)
        self.linear4 = nn.Linear(self.hidden_dim3, 1)
    
    @staticmethod
    def activation_func(act_str):
        if act_str=="tanh":
            return eval("torch."+act_str)
        elif act_str=="selu" or act_str=="relu":   
            return eval("torch.nn.functional."+act_str)

    def forward(self, x):
        output = self.linear1(x)
        output = self.activation_func(self.act1)(output)
        output = self.linear2(output)
        output = self.activation_func(self.act2)(output)
        output = self.linear3(output)
        output = self.activation_func(self.act3)(output)
        output = self.linear4(output)        
        return output

# %%
model = Net({})

# %%
from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        table.add_row([name, param])
        total_params+=param
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

# %%
summary(model, (1,tensor_x.shape[1]))

count_parameters(model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1               [-1, 1, 100]          20,100
#             Linear-2               [-1, 1, 100]          10,100
#             Linear-3               [-1, 1, 100]          10,100
#             Linear-4                 [-1, 1, 1]             101
# ================================================================
# Total params: 40,401
# Trainable params: 40,401
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.15
# Estimated Total Size (MB): 0.16
# ----------------------------------------------------------------
# +----------------+------------+
# |    Modules     | Parameters |
# +----------------+------------+
# | linear1.weight |   20000    |
# |  linear1.bias  |    100     |
# | linear2.weight |   10000    |
# |  linear2.bias  |    100     |
# | linear3.weight |   10000    |
# |  linear3.bias  |    100     |
# | linear4.weight |    100     |
# |  linear4.bias  |     1      |
# +----------------+------------+
# Total Trainable Params: 40401
# 40401

# %%
def trainable_func(config, checkpoint_dir=None, data_dir=None, epochs=10):

    net = Net(config)

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if torch.cuda.device_count() > 1:
            net = nn.DataParallel(net)
    net.to(device)

    '''
    Define a loss function
    '''
    ## Classification
    criterion = nn.CrossEntropyLoss()

    # Define an optimizer 
    optimizer = optim.Adam(net.parameters(), lr=config.get("lr",0.0003))

    if checkpoint_dir:
        model_state, optimizer_state = torch.load(
            os.path.join(checkpoint_dir, "checkpoint"))
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    # Load data
    trainset, testset = load_data(data_dir)

    # Split the dataset into training and validation sets
    train_size = int(len(trainset) * 0.66)
    train_subset, val_subset = random_split(trainset, [train_size, len(trainset) - train_size])

    # Define data loaders (which combines a dataset and a sampler, and provides an iterable over the given dataset)
    trainloader = torch.utils.data.DataLoader(
        train_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=True,
        num_workers=2)
    valloader = torch.utils.data.DataLoader(
        val_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=True,
        num_workers=2)

    for epoch in range(epochs):  # loop over the dataset multiple times
        epoch_train_loss = 0.0
        # epoch_steps = 0
        net.train() # Prepare model for training
        for i, data in enumerate(trainloader):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            '''
            Compute train loss without scaling to print
            ''' 
            # outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            # labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device)  
            # loss_train = criterion(outputs, labels) 
            # epoch_train_loss += loss_train.detach().item()
        # print("[%d] loss: %.3f" % (epoch + 1, epoch_train_loss / len(train_subset)))

        # Validation loss
        # val_loss = 0.0
        # net.eval() # Prepare model for evaluation
        # for i, data in enumerate(valloader):
        #     with torch.no_grad():
        #         inputs, labels = data
        #         inputs, labels = inputs.to(device), labels.to(device)

        #         outputs = net(inputs)

        # Validation score
        score = compute_score(net, valloader, device="cpu")

        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save((net.state_dict(), optimizer.state_dict()), path)
        tune.report(score=score)

                # Inverse transform of the labels' scaler  این دو خط رو کامنت کردی!!!!!
                #outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
                #labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

                # loss = criterion(outputs, labels)
                # val_loss += loss.cpu().numpy()

    #     with tune.checkpoint_dir(epoch) as checkpoint_dir:
    #         path = os.path.join(checkpoint_dir, "checkpoint")
    #         torch.save((net.state_dict(), optimizer.state_dict()), path)

    #     tune.report(epoch = epoch, loss=(val_loss / len(val_subset)))
    print("Finished Training")

# %%
def test_score(config, net, device="cpu"):
    trainset, testset = load_data()

    testloader = torch.utils.data.DataLoader(
        testset, batch_size=int(config.get("batch_size",32)), shuffle=False, num_workers=2)
    
    criterion = nn.CrossEntropyLoss()

    # Test loss
    # test_loss = 0.0
    # net.eval() # Prepare model for evaluation
    # for i, data in enumerate(testloader):
    #     with torch.no_grad():
    #         inputs, labels = data
    #         inputs, labels = inputs.to(device), labels.to(device)

    #         outputs = net(inputs)

    test_score = compute_score(best_trained_model, testloader, device)
    print("Best trial test set score: {}".format(test_score))

            # Inverse transform of the labels' scaler   این دو خط رو هم کامنت کردی!!!!
            # outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            # labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

    #         loss = criterion(outputs, labels)
    #         test_loss += loss.cpu().numpy()

    # return test_loss / len(testset)

# %% [markdown]
# start ray run time

# %%
ray.shutdown()
ray.init() # Here we use ray.init() to evaluate available_resources for Ray
print(ray.available_resources())
  # Restart Ray defensively in case the ray connection is lost. 

# Start Ray runtime with specific resources (not nessesarily all resources)
# You can change this values based on your machine resources)
#ray.init(num_cpus=2, num_gpus=0) 

"""Check Ray Tune is working properly (for trainable class)"""
# from ray.tune.utils import validate_save_restore
# validate_save_restore(Trainable)
# validate_save_restore(Trainable, use_object_store=True)
# print("Success!")
# Out:
# {'object_store_memory': 3947876352.0, 'node:172.28.0.2': 1.0, 'CPU': 2.0, 'memory': 7895752704.0}
# 'Check Ray Tune is working properly (for trainable class)'

# %%
# %%capture
try:
    import optuna
except:
    # %pip install optuna
    import optuna

# %%
def main(num_samples=10, max_num_epochs=10, gpus_per_trial=2):

    # define data directory here if you want to load data from files
    data_dir = os.path.abspath("./bbbp")
    load_data(data_dir)

    # define the search space of hyperparameters
    config = {
        "act1 ": tune.choice(["relu","tanh","selu"]),
        "act2" : tune.choice(["relu","tanh","selu"]),
        "act3" : tune.choice(["relu","tanh","selu"]),
        "lr": tune.quniform(0.0005, 0.001, 0.0001),
        "batch_size": tune.choice([8, 16, 32]),
        "hidden_dim1" : tune.quniform(50, 200, 10),
        "hidden_dim2" : tune.quniform(50, 200, 10),
        "hidden_dim3" : tune.quniform(50, 200, 10),
    }

    # Optuna search algorithm
    from ray.tune.suggest.optuna import OptunaSearch 
    from ray.tune.suggest import ConcurrencyLimiter
    search_alg = OptunaSearch(
        metric="score", #or accuracy, etc.
        mode="max", #or max
        # seed = 42,
        # points_to_evaluate=[
        # {'lr': 0.0005, 'hidden_size': 150.0, 'readout1_out': 200.0, 'readout2_out': 180.0}
        # ],
        )
    search_alg = ConcurrencyLimiter(search_alg, max_concurrent=10)

    scheduler = ASHAScheduler(
        metric ="score",
        mode="max",
        max_t=max_num_epochs,
        reduction_factor=2, 
        grace_period=4,
        brackets=5
        )
    
    reporter = CLIReporter(
        # parameter_columns=["l1", "l2", "lr", "batch_size"],
        metric_columns=["score", "training_iteration"]
        )
    
    # wrap data loading and training for tuning using `partial` 
    # (note that there exist other methods for this purpose)
    result = tune.run(
        partial(trainable_func, data_dir=data_dir, epochs=max_num_epochs),
        scheduler=scheduler,
        search_alg=search_alg,
        num_samples=num_samples,
        config=config,
        verbose=2,
        checkpoint_score_attr="score",
        checkpoint_freq=0,
        keep_checkpoints_num=1,
        # checkpoint_at_end=True,
        # reuse_actors=reuse_actors_status,
        progress_reporter=reporter,
        resources_per_trial={"cpu": 0.5, "gpu": gpus_per_trial},
        stop={"training_iteration": max_num_epochs},                
        )

    best_trial = result.get_best_trial("score", "max", "last")
    print("Best trial config: {}".format(best_trial.config))
    print("Best trial final validation score: {}".format(
        best_trial.last_result["score"]))

    best_trained_model = Net(best_trial.config)
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if gpus_per_trial > 1:
            best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)

    best_checkpoint_dir = best_trial.checkpoint.value
    model_state, optimizer_state = torch.load(os.path.join(
        best_checkpoint_dir, "checkpoint"))
    best_trained_model.load_state_dict(model_state)

    test_score_value = test_score(best_trial.config, best_trained_model, device)
    print("Best trial test set score: {}".format(test_score_value))


if __name__ == "__main__":
    # You can change the number of GPUs per trial here:
    main(num_samples=50, max_num_epochs=50, gpus_per_trial=0)
# Out:
# 2022-07-17 15:08:52,624	INFO logger.py:630 -- pip install "ray[tune]" to see TensorBoard files.
# 2022-07-17 15:08:52,628	WARNING callback.py:106 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# == Status ==
# Current time: 2022-07-17 15:08:53 (running for 00:00:00.60)
# Memory usage on this node: 1.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-17_15-08-52
# Number of trials: 1/50 (1 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------|
# | trainable_func_5ea17d2e | RUNNING  | 172.28.0.2:421 | tanh    | tanh   | selu   |           16 |           100 |           140 |            80 | 0.0006 |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+
#
#
# == Status ==
# Current time: 2022-07-17 15:08:59 (running for 00:00:06.67)
# Memory usage on this node: 1.5/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 1.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-17_15-08-52
# Number of trials: 2/50 (2 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------|
# | trainable_func_5ea17d2e | RUNNING  | 172.28.0.2:421 | tanh    | tanh   | selu   |           16 |           100 |           140 |            80 | 0.0006 |
# | trainable_func_62894cbe | RUNNING  | 172.28.0.2:464 | relu    | tanh   | tanh   |           32 |           180 |            50 |            80 | 0.0008 |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+
#
#
# Trial trainable_func_5ea17d2e reported score=0.4522921986984101,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 140.0, 'hidden_dim3': 80.0}.
# == Status ==
# Current time: 2022-07-17 15:09:06 (running for 00:00:13.99)
# Memory usage on this node: 1.7/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 1.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-17_15-08-52
# Number of trials: 3/50 (1 PENDING, 2 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    score |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_5ea17d2e | RUNNING  | 172.28.0.2:421 | tanh    | tanh   | selu   |           16 |           100 |           140 |            80 | 0.0006 | 0.452292 |                    1 |
# | trainable_func_62894cbe | RUNNING  | 172.28.0.2:464 | relu    | tanh   | tanh   |           32 |           180 |            50 |            80 | 0.0008 |          |                      |
# | trainable_func_66e0990c | PENDING  |                | tanh    | relu   | selu   |           16 |           130 |            60 |            90 | 0.0006 |          |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_62894cbe reported score=0.45625432217774886,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 50.0, 'hidden_dim3': 80.0}.
# == Status ==
# Current time: 2022-07-17 15:09:12 (running for 00:00:19.55)
# Memory usage on this node: 1.9/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-17_15-08-52
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    score |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_5ea17d2e | RUNNING  | 172.28.0.2:421 | tanh    | tanh   | selu   |           16 |           100 |           140 |            80 | 0.0006 | 0.452292 |                    3 |
# | trainable_func_62894cbe | RUNNING  | 172.28.0.2:464 | relu    | tanh   | tanh   |           32 |           180 |            50 |            80 | 0.0008 | 0.456254 |                    5 |
# | trainable_func_66e0990c | RUNNING  | 172.28.0.2:654 | tanh    | relu   | selu   |           16 |           130 |            60 |            90 | 0.0006 |          |                      |
# | trainable_func_68f33894 | RUNNING  | 172.28.0.2:655 | relu    | tanh   | tanh   |           16 |           180 |           130 |            80 | 0.001  |          |                      |
# | trainable_func_690e97a6 | PENDING  |                | selu    | tanh   | relu   |            8 |           150 |           180 |            60 | 0.0008 |          |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_5ea17d2e reported score=0.4522921986984101,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 140.0, 'hidden_dim3': 80.0}.
# == Status ==
# Current time: 2022-07-17 15:09:23 (running for 00:00:31.05)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: 0.4522921986984101
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-17_15-08-52
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    score |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_5ea17d2e | RUNNING  | 172.28.0.2:421 | tanh    | tanh   | selu   |           16 |           100 |           140 |            80 | 0.0006 | 0.452292 |                    4 |
# | trainable_func_62894cbe | RUNNING  | 172.28.0.2:464 | relu    | tanh   | tanh   |           32 |           180 |            50 |            80 | 0.0008 | 0.456254 |                    5 |
# | trainable_func_66e0990c | RUNNING  | 172.28.0.2:654 | tanh    | relu   | selu   |           16 |           130 |            60 |            90 | 0.0006 |          |                      |
# | trainable_func_68f33894 | RUNNING  | 172.28.0.2:655 | relu    | tanh   | tanh   |           16 |           180 |           130 |            80 | 0.001  |          |                      |
# | trainable_func_690e97a6 | PENDING  |                | selu    | tanh   | relu   |            8 |           150 |           180 |            60 | 0.0008 |          |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_62894cbe reported score=0.45625432217774886,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 50.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_66e0990c reported score=0.5927916666666667,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 60.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_68f33894 reported score=0.568881239242685,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 180.0, 'hidden_dim2': 130.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_5ea17d2e reported score=0.4522921986984101,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 140.0, 'hidden_dim3': 80.0}.
# == Status ==
# Current time: 2022-07-17 15:09:29 (running for 00:00:36.48)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: 0.4522921986984101
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: 0.45625432217774886
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-17_15-08-52
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    score |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_5ea17d2e | RUNNING  | 172.28.0.2:421 | tanh    | tanh   | selu   |           16 |           100 |           140 |            80 | 0.0006 | 0.452292 |                    6 |
# | trainable_func_62894cbe | RUNNING  | 172.28.0.2:464 | relu    | tanh   | tanh   |           32 |           180 |            50 |            80 | 0.0008 | 0.456254 |                    8 |
# | trainable_func_66e0990c | RUNNING  | 172.28.0.2:654 | tanh    | relu   | selu   |           16 |           130 |            60 |            90 | 0.0006 | 0.592792 |                    2 |
# | trainable_func_68f33894 | RUNNING  | 172.28.0.2:655 | relu    | tanh   | tanh   |           16 |           180 |           130 |            80 | 0.001  | 0.568881 |                    2 |
# | trainable_func_690e97a6 | PENDING  |                | selu    | tanh   | relu   |            8 |           150 |           180 |            60 | 0.0008 |          |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_66e0990c reported score=0.5927916666666667,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 60.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_62894cbe reported score=0.45625432217774886,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 50.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_68f33894 reported score=0.568881239242685,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 180.0, 'hidden_dim2': 130.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_5ea17d2e reported score=0.4522921986984101,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 140.0, 'hidden_dim3': 80.0}.
# == Status ==
# Current time: 2022-07-17 15:09:34 (running for 00:00:41.71)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: 0.4522921986984101 | Iter 4.000: 0.4522921986984101
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: 0.45625432217774886
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-17_15-08-52
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    score |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_5ea17d2e | RUNNING  | 172.28.0.2:421 | tanh    | tanh   | selu   |           16 |           100 |           140 |            80 | 0.0006 | 0.452292 |                    8 |
# | trainable_func_62894cbe | RUNNING  | 172.28.0.2:464 | relu    | tanh   | tanh   |           32 |           180 |            50 |            80 | 0.0008 | 0.456254 |                   11 |
# | trainable_func_66e0990c | RUNNING  | 172.28.0.2:654 | tanh    | relu   | selu   |           16 |           130 |            60 |            90 | 0.0006 | 0.592792 |                    4 |
# | trainable_func_68f33894 | RUNNING  | 172.28.0.2:655 | relu    | tanh   | tanh   |           16 |           180 |           130 |            80 | 0.001  | 0.568881 |                    3 |
# | trainable_func_690e97a6 | PENDING  |                | selu    | tanh   | relu   |            8 |           150 |           180 |            60 | 0.0008 |          |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_66e0990c reported score=0.5927916666666667,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 60.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_68f33894 reported score=0.568881239242685,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 180.0, 'hidden_dim2': 130.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_62894cbe reported score=0.45625432217774886,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 50.0, 'hidden_dim3': 80.0}.
# == Status ==
# Current time: 2022-07-17 15:09:39 (running for 00:00:46.87)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: 0.4522921986984101 | Iter 4.000: 0.4522921986984101
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: 0.45625432217774886
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-17_15-08-52
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    score |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_5ea17d2e | RUNNING  | 172.28.0.2:421 | tanh    | tanh   | selu   |           16 |           100 |           140 |            80 | 0.0006 | 0.452292 |                   10 |
# | trainable_func_62894cbe | RUNNING  | 172.28.0.2:464 | relu    | tanh   | tanh   |           32 |           180 |            50 |            80 | 0.0008 | 0.456254 |                   15 |
# | trainable_func_66e0990c | RUNNING  | 172.28.0.2:654 | tanh    | relu   | selu   |           16 |           130 |            60 |            90 | 0.0006 | 0.592792 |                    6 |
# | trainable_func_68f33894 | RUNNING  | 172.28.0.2:655 | relu    | tanh   | tanh   |           16 |           180 |           130 |            80 | 0.001  | 0.568881 |                    6 |
# | trainable_func_690e97a6 | PENDING  |                | selu    | tanh   | relu   |            8 |           150 |           180 |            60 | 0.0008 |          |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_5ea17d2e reported score=0.4522921986984101,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 140.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_68f33894 reported score=0.568881239242685,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 180.0, 'hidden_dim2': 130.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_66e0990c reported score=0.5927916666666667,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 60.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_62894cbe reported score=0.45625432217774886,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 50.0, 'hidden_dim3': 80.0}.
# == Status ==
# Current time: 2022-07-17 15:09:44 (running for 00:00:51.88)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: 0.4522921986984101 | Iter 4.000: 0.4522921986984101
# Bracket: Iter 32.000: None | Iter 16.000: 0.45625432217774886 | Iter 8.000: 0.5245229944222078
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-17_15-08-52
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    score |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_5ea17d2e | RUNNING  | 172.28.0.2:421 | tanh    | tanh   | selu   |           16 |           100 |           140 |            80 | 0.0006 | 0.452292 |                   12 |
# | trainable_func_62894cbe | RUNNING  | 172.28.0.2:464 | relu    | tanh   | tanh   |           32 |           180 |            50 |            80 | 0.0008 | 0.456254 |                   19 |
# | trainable_func_66e0990c | RUNNING  | 172.28.0.2:654 | tanh    | relu   | selu   |           16 |           130 |            60 |            90 | 0.0006 | 0.592792 |                    8 |
# | trainable_func_68f33894 | RUNNING  | 172.28.0.2:655 | relu    | tanh   | tanh   |           16 |           180 |           130 |            80 | 0.001  | 0.568881 |                    7 |
# | trainable_func_690e97a6 | PENDING  |                | selu    | tanh   | relu   |            8 |           150 |           180 |            60 | 0.0008 |          |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_5ea17d2e reported score=0.4522921986984101,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 140.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_68f33894 reported score=0.568881239242685,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 180.0, 'hidden_dim2': 130.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_62894cbe reported score=0.45625432217774886,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 50.0, 'hidden_dim3': 80.0}.
# == Status ==
# Current time: 2022-07-17 15:09:49 (running for 00:00:56.95)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: 0.4522921986984101 | Iter 4.000: 0.4522921986984101
# Bracket: Iter 32.000: None | Iter 16.000: 0.45625432217774886 | Iter 8.000: 0.568881239242685
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-17_15-08-52
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    score |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_5ea17d2e | RUNNING  | 172.28.0.2:421 | tanh    | tanh   | selu   |           16 |           100 |           140 |            80 | 0.0006 | 0.452292 |                   14 |
# | trainable_func_62894cbe | RUNNING  | 172.28.0.2:464 | relu    | tanh   | tanh   |           32 |           180 |            50 |            80 | 0.0008 | 0.456254 |                   23 |
# | trainable_func_66e0990c | RUNNING  | 172.28.0.2:654 | tanh    | relu   | selu   |           16 |           130 |            60 |            90 | 0.0006 | 0.592792 |                   10 |
# | trainable_func_68f33894 | RUNNING  | 172.28.0.2:655 | relu    | tanh   | tanh   |           16 |           180 |           130 |            80 | 0.001  | 0.568881 |                   10 |
# | trainable_func_690e97a6 | PENDING  |                | selu    | tanh   | relu   |            8 |           150 |           180 |            60 | 0.0008 |          |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_66e0990c reported score=0.5927916666666667,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 60.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_5ea17d2e reported score=0.4522921986984101,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 140.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_68f33894 reported score=0.568881239242685,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 180.0, 'hidden_dim2': 130.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_62894cbe reported score=0.45625432217774886,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 50.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_66e0990c reported score=0.5927916666666667,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 60.0, 'hidden_dim3': 90.0}.
# == Status ==
# Current time: 2022-07-17 15:09:55 (running for 00:01:02.39)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: 0.4522921986984101 | Iter 8.000: 0.4522921986984101 | Iter 4.000: 0.4522921986984101
# Bracket: Iter 32.000: None | Iter 16.000: 0.45625432217774886 | Iter 8.000: 0.568881239242685
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-17_15-08-52
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    score |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_5ea17d2e | RUNNING  | 172.28.0.2:421 | tanh    | tanh   | selu   |           16 |           100 |           140 |            80 | 0.0006 | 0.452292 |                   17 |
# | trainable_func_62894cbe | RUNNING  | 172.28.0.2:464 | relu    | tanh   | tanh   |           32 |           180 |            50 |            80 | 0.0008 | 0.456254 |                   27 |
# | trainable_func_66e0990c | RUNNING  | 172.28.0.2:654 | tanh    | relu   | selu   |           16 |           130 |            60 |            90 | 0.0006 | 0.592792 |                   14 |
# | trainable_func_68f33894 | RUNNING  | 172.28.0.2:655 | relu    | tanh   | tanh   |           16 |           180 |           130 |            80 | 0.001  | 0.568881 |                   12 |
# | trainable_func_690e97a6 | PENDING  |                | selu    | tanh   | relu   |            8 |           150 |           180 |            60 | 0.0008 |          |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_5ea17d2e reported score=0.4522921986984101,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 140.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_68f33894 reported score=0.568881239242685,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 180.0, 'hidden_dim2': 130.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_62894cbe reported score=0.45625432217774886,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 50.0, 'hidden_dim3': 80.0}.
# == Status ==
# Current time: 2022-07-17 15:10:00 (running for 00:01:07.90)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: 0.4522921986984101 | Iter 8.000: 0.4522921986984101 | Iter 4.000: 0.4522921986984101
# Bracket: Iter 32.000: 0.45625432217774886 | Iter 16.000: 0.5245229944222078 | Iter 8.000: 0.568881239242685
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-17_15-08-52
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    score |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_5ea17d2e | RUNNING  | 172.28.0.2:421 | tanh    | tanh   | selu   |           16 |           100 |           140 |            80 | 0.0006 | 0.452292 |                   20 |
# | trainable_func_62894cbe | RUNNING  | 172.28.0.2:464 | relu    | tanh   | tanh   |           32 |           180 |            50 |            80 | 0.0008 | 0.456254 |                   33 |
# | trainable_func_66e0990c | RUNNING  | 172.28.0.2:654 | tanh    | relu   | selu   |           16 |           130 |            60 |            90 | 0.0006 | 0.592792 |                   16 |
# | trainable_func_68f33894 | RUNNING  | 172.28.0.2:655 | relu    | tanh   | tanh   |           16 |           180 |           130 |            80 | 0.001  | 0.568881 |                   15 |
# | trainable_func_690e97a6 | PENDING  |                | selu    | tanh   | relu   |            8 |           150 |           180 |            60 | 0.0008 |          |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_66e0990c reported score=0.5927916666666667,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 60.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_5ea17d2e reported score=0.4522921986984101,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 140.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_62894cbe reported score=0.45625432217774886,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 50.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_68f33894 reported score=0.568881239242685,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 180.0, 'hidden_dim2': 130.0, 'hidden_dim3': 80.0}.
# == Status ==
# Current time: 2022-07-17 15:10:05 (running for 00:01:12.97)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: 0.4522921986984101 | Iter 8.000: 0.4522921986984101 | Iter 4.000: 0.4522921986984101
# Bracket: Iter 32.000: 0.45625432217774886 | Iter 16.000: 0.568881239242685 | Iter 8.000: 0.568881239242685
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-17_15-08-52
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    score |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_5ea17d2e | RUNNING  | 172.28.0.2:421 | tanh    | tanh   | selu   |           16 |           100 |           140 |            80 | 0.0006 | 0.452292 |                   23 |
# | trainable_func_62894cbe | RUNNING  | 172.28.0.2:464 | relu    | tanh   | tanh   |           32 |           180 |            50 |            80 | 0.0008 | 0.456254 |                   37 |
# | trainable_func_66e0990c | RUNNING  | 172.28.0.2:654 | tanh    | relu   | selu   |           16 |           130 |            60 |            90 | 0.0006 | 0.592792 |                   19 |
# | trainable_func_68f33894 | RUNNING  | 172.28.0.2:655 | relu    | tanh   | tanh   |           16 |           180 |           130 |            80 | 0.001  | 0.568881 |                   18 |
# | trainable_func_690e97a6 | PENDING  |                | selu    | tanh   | relu   |            8 |           150 |           180 |            60 | 0.0008 |          |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_66e0990c reported score=0.5927916666666667,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 60.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_5ea17d2e reported score=0.4522921986984101,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 140.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_62894cbe reported score=0.45625432217774886,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 50.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_66e0990c reported score=0.5927916666666667,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 60.0, 'hidden_dim3': 90.0}.
# == Status ==
# Current time: 2022-07-17 15:10:11 (running for 00:01:18.37)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: 0.4522921986984101 | Iter 8.000: 0.4522921986984101 | Iter 4.000: 0.4522921986984101
# Bracket: Iter 32.000: 0.45625432217774886 | Iter 16.000: 0.568881239242685 | Iter 8.000: 0.568881239242685
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-17_15-08-52
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    score |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_5ea17d2e | RUNNING  | 172.28.0.2:421 | tanh    | tanh   | selu   |           16 |           100 |           140 |            80 | 0.0006 | 0.452292 |                   25 |
# | trainable_func_62894cbe | RUNNING  | 172.28.0.2:464 | relu    | tanh   | tanh   |           32 |           180 |            50 |            80 | 0.0008 | 0.456254 |                   42 |
# | trainable_func_66e0990c | RUNNING  | 172.28.0.2:654 | tanh    | relu   | selu   |           16 |           130 |            60 |            90 | 0.0006 | 0.592792 |                   23 |
# | trainable_func_68f33894 | RUNNING  | 172.28.0.2:655 | relu    | tanh   | tanh   |           16 |           180 |           130 |            80 | 0.001  | 0.568881 |                   20 |
# | trainable_func_690e97a6 | PENDING  |                | selu    | tanh   | relu   |            8 |           150 |           180 |            60 | 0.0008 |          |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_68f33894 reported score=0.568881239242685,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 180.0, 'hidden_dim2': 130.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_5ea17d2e reported score=0.4522921986984101,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 140.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_62894cbe reported score=0.45625432217774886,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 50.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_66e0990c reported score=0.5927916666666667,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 60.0, 'hidden_dim3': 90.0}.
# == Status ==
# Current time: 2022-07-17 15:10:16 (running for 00:01:23.95)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: 0.4522921986984101 | Iter 8.000: 0.4522921986984101 | Iter 4.000: 0.4522921986984101
# Bracket: Iter 32.000: 0.45625432217774886 | Iter 16.000: 0.568881239242685 | Iter 8.000: 0.568881239242685
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-17_15-08-52
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    score |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_5ea17d2e | RUNNING  | 172.28.0.2:421 | tanh    | tanh   | selu   |           16 |           100 |           140 |            80 | 0.0006 | 0.452292 |                   28 |
# | trainable_func_62894cbe | RUNNING  | 172.28.0.2:464 | relu    | tanh   | tanh   |           32 |           180 |            50 |            80 | 0.0008 | 0.456254 |                   47 |
# | trainable_func_66e0990c | RUNNING  | 172.28.0.2:654 | tanh    | relu   | selu   |           16 |           130 |            60 |            90 | 0.0006 | 0.592792 |                   26 |
# | trainable_func_68f33894 | RUNNING  | 172.28.0.2:655 | relu    | tanh   | tanh   |           16 |           180 |           130 |            80 | 0.001  | 0.568881 |                   23 |
# | trainable_func_690e97a6 | PENDING  |                | selu    | tanh   | relu   |            8 |           150 |           180 |            60 | 0.0008 |          |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_68f33894 reported score=0.568881239242685,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 180.0, 'hidden_dim2': 130.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_62894cbe reported score=0.45625432217774886,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 50.0, 'hidden_dim3': 80.0}. This trial completed.
# Trial trainable_func_5ea17d2e reported score=0.4522921986984101,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 140.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_66e0990c reported score=0.5927916666666667,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 60.0, 'hidden_dim3': 90.0}.
# == Status ==
# Current time: 2022-07-17 15:10:21 (running for 00:01:29.33)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: 0.4522921986984101 | Iter 8.000: 0.4522921986984101 | Iter 4.000: 0.4522921986984101
# Bracket: Iter 32.000: 0.45625432217774886 | Iter 16.000: 0.568881239242685 | Iter 8.000: 0.568881239242685
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-17_15-08-52
# Number of trials: 6/50 (1 PENDING, 4 RUNNING, 1 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    score |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_5ea17d2e | RUNNING    | 172.28.0.2:421 | tanh    | tanh   | selu   |           16 |           100 |           140 |            80 | 0.0006 | 0.452292 |                   31 |
# | trainable_func_66e0990c | RUNNING    | 172.28.0.2:654 | tanh    | relu   | selu   |           16 |           130 |            60 |            90 | 0.0006 | 0.592792 |                   29 |
# | trainable_func_68f33894 | RUNNING    | 172.28.0.2:655 | relu    | tanh   | tanh   |           16 |           180 |           130 |            80 | 0.001  | 0.568881 |                   26 |
# | trainable_func_690e97a6 | RUNNING    | 172.28.0.2:464 | selu    | tanh   | relu   |            8 |           150 |           180 |            60 | 0.0008 |          |                      |
# | trainable_func_920538ea | PENDING    |                | selu    | tanh   | selu   |            8 |            50 |           170 |           120 | 0.0006 |          |                      |
# | trainable_func_62894cbe | TERMINATED | 172.28.0.2:464 | relu    | tanh   | tanh   |           32 |           180 |            50 |            80 | 0.0008 | 0.456254 |                   50 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_690e97a6 reported score=0.7384101265822784,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 150.0, 'hidden_dim2': 180.0, 'hidden_dim3': 60.0}.
# ...
# | trainable_func_259aeba4 | TERMINATED | 172.28.0.2:464 | selu    | relu   | relu   |            8 |           120 |           120 |           190 | 0.0007 | 0.675572 |                   16 |
# | trainable_func_2653979e | TERMINATED | 172.28.0.2:421 | selu    | relu   | relu   |            8 |            80 |           120 |           190 | 0.0007 | 0.711902 |                   50 |
# | trainable_func_336297dc | TERMINATED | 172.28.0.2:654 | selu    | relu   | relu   |            8 |            70 |           130 |           190 | 0.0007 | 0.399304 |                    8 |
# | trainable_func_359fbd90 | TERMINATED | 172.28.0.2:654 | selu    | relu   | relu   |           16 |           190 |           140 |           160 | 0.0007 | 0.41255  |                    4 |
# | trainable_func_44e09928 | TERMINATED | 172.28.0.2:464 | selu    | tanh   | relu   |           16 |           190 |           140 |            70 | 0.0008 | 0.50572  |                    8 |
# | trainable_func_4500a0a6 | TERMINATED | 172.28.0.2:655 | selu    | tanh   | relu   |           16 |           190 |           140 |            60 | 0.0008 | 0.330013 |                    4 |
# | trainable_func_45979b32 | TERMINATED | 172.28.0.2:654 | selu    | tanh   | relu   |           16 |           190 |           150 |           200 | 0.0008 | 0.569165 |                    8 |
# | trainable_func_499e6f1c | TERMINATED | 172.28.0.2:655 | relu    | tanh   | tanh   |           16 |           190 |           100 |           200 | 0.0008 | 0.718442 |                   50 |
# | trainable_func_4a41f0b0 | TERMINATED | 172.28.0.2:464 | relu    | tanh   | tanh   |           16 |           180 |            90 |           200 | 0.0008 | 0.365831 |                    4 |
# | trainable_func_4e100b32 | TERMINATED | 172.28.0.2:464 | relu    | tanh   | tanh   |           16 |           180 |            90 |           200 | 0.0008 | 0.631354 |                    8 |
# | trainable_func_52c0fa6a | TERMINATED | 172.28.0.2:654 | relu    | tanh   | selu   |           16 |           200 |            70 |           180 | 0.0008 | 0.60491  |                   32 |
# | trainable_func_5385def2 | TERMINATED | 172.28.0.2:464 | relu    | selu   | selu   |           16 |           180 |            60 |           180 | 0.0006 | 0.43837  |                    4 |
# | trainable_func_5b93944a | TERMINATED | 172.28.0.2:464 | relu    | selu   | selu   |           16 |           170 |            50 |           180 | 0.0006 | 0.515678 |                    8 |
# | trainable_func_5ea17d2e | TERMINATED | 172.28.0.2:421 | tanh    | tanh   | selu   |           16 |           100 |           140 |            80 | 0.0006 | 0.452292 |                   50 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# ... 30 more trials not shown (30 TERMINATED)
#
#
# Trial trainable_func_92920706 reported score=0.6455765047135607,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 150.0, 'hidden_dim2': 100.0, 'hidden_dim3': 90.0}.
# 2022-07-17 15:17:50,323	INFO tune.py:748 -- Total run time: 537.75 seconds (537.53 seconds for the tuning loop).
# Trial trainable_func_92920706 reported score=0.6455765047135607,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 150.0, 'hidden_dim2': 100.0, 'hidden_dim3': 90.0}. This trial completed.
# == Status ==
# Current time: 2022-07-17 15:17:50 (running for 00:08:57.57)
# Memory usage on this node: 1.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=38
# Bracket: Iter 32.000: 0.7119020513850756 | Iter 16.000: 0.6835101581197789 | Iter 8.000: 0.631353809781411 | Iter 4.000: 0.5148573651983371
# Bracket: Iter 32.000: 0.6049099522021167 | Iter 16.000: 0.5988508094343917 | Iter 8.000: 0.5219455326757176
# Bracket: Iter 32.000: 0.6086807928913192 | Iter 16.000: 0.6086704364216327
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-17_15-08-52
# Number of trials: 50/50 (50 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    score |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_5ea17d2e | TERMINATED | 172.28.0.2:421 | tanh    | tanh   | selu   |           16 |           100 |           140 |            80 | 0.0006 | 0.452292 |                   50 |
# | trainable_func_62894cbe | TERMINATED | 172.28.0.2:464 | relu    | tanh   | tanh   |           32 |           180 |            50 |            80 | 0.0008 | 0.456254 |                   50 |
# | trainable_func_66e0990c | TERMINATED | 172.28.0.2:654 | tanh    | relu   | selu   |           16 |           130 |            60 |            90 | 0.0006 | 0.592792 |                   50 |
# | trainable_func_68f33894 | TERMINATED | 172.28.0.2:655 | relu    | tanh   | tanh   |           16 |           180 |           130 |            80 | 0.001  | 0.568881 |                   50 |
# | trainable_func_690e97a6 | TERMINATED | 172.28.0.2:464 | selu    | tanh   | relu   |            8 |           150 |           180 |            60 | 0.0008 | 0.73841  |                   50 |
# | trainable_func_920538ea | TERMINATED | 172.28.0.2:421 | selu    | tanh   | selu   |            8 |            50 |           170 |           120 | 0.0006 | 0.382572 |                    8 |
# | trainable_func_a74edac6 | TERMINATED | 172.28.0.2:654 | relu    | selu   | selu   |           16 |           180 |           200 |           190 | 0.0009 | 0.691448 |                   50 |
# | trainable_func_a988d594 | TERMINATED | 172.28.0.2:655 | tanh    | tanh   | selu   |            8 |            50 |           190 |            50 | 0.0008 | 0.52433  |                   16 |
# | trainable_func_adeea280 | TERMINATED | 172.28.0.2:421 | selu    | selu   | relu   |           32 |           180 |           140 |           150 | 0.0006 | 0.389268 |                    4 |
# | trainable_func_b64f58fc | TERMINATED | 172.28.0.2:421 | selu    | tanh   | relu   |           16 |           190 |           190 |           140 | 0.0005 | 0.665631 |                    8 |
# | trainable_func_b939c692 | TERMINATED | 172.28.0.2:421 | selu    | selu   | tanh   |           32 |           150 |           190 |           180 | 0.001  | 0.440148 |                    4 |
# | trainable_func_c396a7b8 | TERMINATED | 172.28.0.2:421 | tanh    | selu   | relu   |           32 |           100 |           160 |           160 | 0.0006 | 0.322197 |                    8 |
# | trainable_func_c77ad994 | TERMINATED | 172.28.0.2:655 | relu    | selu   | tanh   |            8 |           140 |           180 |            60 | 0.001  | 0.345676 |                    4 |
# | trainable_func_ccad39c0 | TERMINATED | 172.28.0.2:421 | relu    | tanh   | relu   |           32 |            50 |           190 |           110 | 0.0005 | 0.488443 |                    4 |
# | trainable_func_cdda4e00 | TERMINATED | 172.28.0.2:421 | selu    | relu   | relu   |           16 |           200 |            90 |           130 | 0.0005 | 0.670101 |                    8 |
# | trainable_func_d05c763a | TERMINATED | 172.28.0.2:655 | tanh    | relu   | selu   |           16 |           140 |            80 |           140 | 0.0005 | 0.458937 |                    4 |
# | trainable_func_d4d94526 | TERMINATED | 172.28.0.2:655 | tanh    | relu   | selu   |           16 |           200 |            80 |           140 | 0.0005 | 0.338688 |                    4 |
# | trainable_func_d91e6ad0 | TERMINATED | 172.28.0.2:421 | selu    | relu   | relu   |           16 |           100 |            90 |           200 | 0.0007 | 0.367658 |                    4 |
# | trainable_func_d999534e | TERMINATED | 172.28.0.2:655 | selu    | relu   | relu   |           16 |           200 |           100 |           200 | 0.0007 | 0.721406 |                   50 |
# | trainable_func_dde409f8 | TERMINATED | 172.28.0.2:421 | selu    | relu   | relu   |           16 |           200 |           110 |           200 | 0.0007 | 0.459909 |                    8 |
# | trainable_func_de010df0 | TERMINATED | 172.28.0.2:421 | selu    | relu   | relu   |           16 |           200 |           110 |           170 | 0.0007 | 0.721784 |                   50 |
# | trainable_func_e79dfb5c | TERMINATED | 172.28.0.2:654 | selu    | relu   | relu   |           16 |           160 |           110 |           170 | 0.0005 | 0.662603 |                   50 |
# | trainable_func_eb61171a | TERMINATED | 172.28.0.2:464 | relu    | selu   | selu   |           16 |           160 |           110 |           170 | 0.0009 | 0.362796 |                    8 |
# | trainable_func_fa683a54 | TERMINATED | 172.28.0.2:464 | relu    | selu   | selu   |            8 |           160 |           160 |           170 | 0.0009 | 0.51954  |                    8 |
# | trainable_func_037d9b3e | TERMINATED | 172.28.0.2:464 | relu    | selu   | selu   |            8 |           160 |           160 |           100 | 0.0009 | 0.552006 |                    8 |
# | trainable_func_14d71f7c | TERMINATED | 172.28.0.2:655 | selu    | relu   | relu   |            8 |           170 |           200 |           100 | 0.0009 | 0.42874  |                    4 |
# | trainable_func_18c385ee | TERMINATED | 172.28.0.2:655 | selu    | relu   | relu   |            8 |           170 |           200 |           190 | 0.0009 | 0.667022 |                   16 |
# | trainable_func_2217a8d2 | TERMINATED | 172.28.0.2:421 | selu    | selu   | relu   |            8 |           120 |           110 |           190 | 0.0008 | 0.656312 |                    8 |
# | trainable_func_238b0c5e | TERMINATED | 172.28.0.2:654 | selu    | relu   | relu   |            8 |           120 |           120 |           180 | 0.0007 | 0.382923 |                    8 |
# | trainable_func_259aeba4 | TERMINATED | 172.28.0.2:464 | selu    | relu   | relu   |            8 |           120 |           120 |           190 | 0.0007 | 0.675572 |                   16 |
# | trainable_func_2653979e | TERMINATED | 172.28.0.2:421 | selu    | relu   | relu   |            8 |            80 |           120 |           190 | 0.0007 | 0.711902 |                   50 |
# | trainable_func_336297dc | TERMINATED | 172.28.0.2:654 | selu    | relu   | relu   |            8 |            70 |           130 |           190 | 0.0007 | 0.399304 |                    8 |
# | trainable_func_359fbd90 | TERMINATED | 172.28.0.2:654 | selu    | relu   | relu   |           16 |           190 |           140 |           160 | 0.0007 | 0.41255  |                    4 |
# | trainable_func_44e09928 | TERMINATED | 172.28.0.2:464 | selu    | tanh   | relu   |           16 |           190 |           140 |            70 | 0.0008 | 0.50572  |                    8 |
# | trainable_func_4500a0a6 | TERMINATED | 172.28.0.2:655 | selu    | tanh   | relu   |           16 |           190 |           140 |            60 | 0.0008 | 0.330013 |                    4 |
# | trainable_func_45979b32 | TERMINATED | 172.28.0.2:654 | selu    | tanh   | relu   |           16 |           190 |           150 |           200 | 0.0008 | 0.569165 |                    8 |
# | trainable_func_499e6f1c | TERMINATED | 172.28.0.2:655 | relu    | tanh   | tanh   |           16 |           190 |           100 |           200 | 0.0008 | 0.718442 |                   50 |
# | trainable_func_4a41f0b0 | TERMINATED | 172.28.0.2:464 | relu    | tanh   | tanh   |           16 |           180 |            90 |           200 | 0.0008 | 0.365831 |                    4 |
# | trainable_func_4e100b32 | TERMINATED | 172.28.0.2:464 | relu    | tanh   | tanh   |           16 |           180 |            90 |           200 | 0.0008 | 0.631354 |                    8 |
# | trainable_func_52c0fa6a | TERMINATED | 172.28.0.2:654 | relu    | tanh   | selu   |           16 |           200 |            70 |           180 | 0.0008 | 0.60491  |                   32 |
# | trainable_func_5385def2 | TERMINATED | 172.28.0.2:464 | relu    | selu   | selu   |           16 |           180 |            60 |           180 | 0.0006 | 0.43837  |                    4 |
# | trainable_func_5b93944a | TERMINATED | 172.28.0.2:464 | relu    | selu   | selu   |           16 |           170 |            50 |           180 | 0.0006 | 0.515678 |                    8 |
# | trainable_func_6017457a | TERMINATED | 172.28.0.2:464 | tanh    | relu   | selu   |           32 |           170 |           180 |           160 | 0.0007 | 0.60867  |                   50 |
# | trainable_func_68a53292 | TERMINATED | 172.28.0.2:654 | tanh    | relu   | selu   |           32 |           200 |           180 |           160 | 0.0009 | 0.486958 |                    4 |
# | trainable_func_792d843e | TERMINATED | 172.28.0.2:654 | tanh    | relu   | tanh   |           32 |           140 |           180 |           160 | 0.0009 | 0.514857 |                    8 |
# | trainable_func_7e4f4bb4 | TERMINATED | 172.28.0.2:654 | selu    | relu   | relu   |            8 |           130 |           100 |           190 | 0.0007 | 0.547194 |                    8 |
# | trainable_func_85b0d6ac | TERMINATED | 172.28.0.2:655 | selu    | relu   | relu   |            8 |            90 |           120 |           190 | 0.0007 | 0.354126 |                    4 |
# | trainable_func_8a66ae74 | TERMINATED | 172.28.0.2:655 | relu    | tanh   | tanh   |           16 |           170 |           100 |           190 | 0.0007 | 0.552282 |                    8 |
# | trainable_func_92387b28 | TERMINATED | 172.28.0.2:464 | relu    | tanh   | tanh   |           16 |           170 |           100 |           130 | 0.001  | 0.624742 |                    8 |
# | trainable_func_92920706 | TERMINATED | 172.28.0.2:654 | relu    | tanh   | tanh   |           16 |           150 |           100 |            90 | 0.001  | 0.645577 |                   16 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Best trial config: {'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 150.0, 'hidden_dim2': 180.0, 'hidden_dim3': 60.0}
# Best trial final validation score: 0.7384101265822784
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-348a7fa13ffb> in <module>()
#      87 if __name__ == "__main__":
#      88     # You can change the number of GPUs per trial here:
# ---> 89     main(num_samples=50, max_num_epochs=50, gpus_per_trial=0)
#
# <ipython-input-33-348a7fa13ffb> in main(num_samples, max_num_epochs, gpus_per_trial)
#      81     best_trained_model.load_state_dict(model_state)
#      82
# ---> 83     test_score_value = test_score(best_trial.config, best_trained_model, device)
#      84     print("Best trial test set score: {}".format(test_score_value))
#      85
#
# <ipython-input-30-218b3babab19> in test_score(config, net, device)
#      17     #         outputs = net(inputs)
#      18
# ---> 19     test_score = compute_score(best_trained_model, testloader, device)
#      20     print("Best trial test set score: {}".format(test_score))
#      21
#
# NameError: name 'best_trained_model' is not defined

# %%
from ray.tune.suggest.hyperopt import HyperOptSearch
from ray.tune.suggest.optuna import OptunaSearch  
from ray.tune.suggest.dragonfly import DragonflySearch
from ray.tune.suggest.bayesopt import BayesOptSearch
from ray.tune.schedulers.hb_bohb import HyperBandForBOHB
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.schedulers import MedianStoppingRule
from ray.tune.schedulers import PopulationBasedTraining
from ray.tune.suggest.bohb import TuneBOHB
from ray.tune.suggest.basic_variant import BasicVariantGenerator
from ray.tune.suggest import ConcurrencyLimiter

# %%
training_iteration = 50 #max_num_epochs

## ASHA
scheduler = AsyncHyperBandScheduler(
    time_attr="training_iteration",
    max_t=training_iteration,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    reduction_factor=2, 
    grace_period=4,
    brackets=5,
    )

## BOHB
scheduler = HyperBandForBOHB(
    time_attr="training_iteration",
    max_t=training_iteration, 
    reduction_factor=8, 
    stop_last_trials=True,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    )

## Median
scheduler = MedianStoppingRule(
    time_attr="training_iteration",
    grace_period=10,
    min_samples_required=10,
    hard_stop = True,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    )

## PBT
scheduler = PopulationBasedTraining(
    time_attr="training_iteration",
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    perturbation_interval=10,  # every 10 `time_attr` units
                            # (training_iterations in this case)
    # hyperparam_mutations={
    #     "lr": [8e-3, 7e-3, 6e-3, 5e-3, 4e-3],
    #     "dropout": tune.quniform(0.0, 0.4, 0.05),
    #     "dropout1": tune.quniform(0.0, 0.4, 0.05),
    #     "dropout2": tune.quniform(0.0, 0.4, 0.05),
    #     "max_norm_val":tune.choice([2.5, 3, 3.5, 4]),
    #     }
    )

# %%
## BOHB
search_alg = TuneBOHB(
    # space=config_space,  # If you want to set the space manually
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    # seed = 42,
    # points_to_evaluate=[
    # ],
    )

## Hyperopt
search_alg = HyperOptSearch(
    # space=config,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    n_initial_points=60,
    # gamma = 0.1,
    # random_state_seed=42,
    # points_to_evaluate=[{"max_norm_val": 2.5, 'GNN_Layers': 3, 'dropout': 0.25, 'dropout1': 0.35, 'dropout2': 0.15, 'lr': 0.001, 'hidden_size': 80, 'readout1_out': 150, 'readout2_out': 100, 'batch_size': 64}],
    )

## Optuna
search_alg = OptunaSearch(
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    # seed = 42,
    # points_to_evaluate=[
    # {'dropout': 0.2, 'dropout1': 0.1, 'dropout2': 0.25, 'lr': 0.0005, 'hidden_size': 150.0, 'readout1_out': 200.0, 'readout2_out': 180.0, 'max_norm_val': 2.5}
    # ],
    )

## Dragonfly
search_alg = DragonflySearch(
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    optimizer="bandit", #[random, bandit, genetic]
    # points_to_evaluate=[
    # {'max_norm_val': 2.5, 'dropout': 0.3, 'dropout1': 0.1, 'dropout2': 0.0, 'lr': 0.0008, 'hidden_size': 90, 'readout1_out': 150, 'readout2_out': 140}
    # ],
    # domain=euclidean, #[cartesian, euclidean]
    )

## Bayesopt
search_alg = BayesOptSearch(
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    random_search_steps = 60, 
    # points_to_evaluate=[
    # {'max_norm_val': 2.5, 'dropout': 0.3, 'dropout1': 0.1, 'dropout2': 0.0, 'lr': 0.0008, 'hidden_size': 90, 'readout1_out': 150, 'readout2_out': 140}
    # ],
    )
# Out:
# ERROR:root:An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 49))
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-35-b5459d103f61> in <module>()
#       3     # space=config_space,  # If you want to set the space manually
#       4     metric="loss", #or accuracy, etc.
# ----> 5     mode="min", #or max
#       6     # seed = 42,
#       7     # points_to_evaluate=[
#
# /usr/local/lib/python3.7/dist-packages/ray/tune/suggest/bohb.py in __init__(self, space, bohb_config, metric, mode, points_to_evaluate, seed)
#     134         ), """HpBandSter must be installed!
#     135             You can install HpBandSter with the command:
# --> 136             `pip install hpbandster ConfigSpace`."""
#     137         if mode:
#     138             assert mode in ["min", "max"], "`mode` must be 'min' or 'max'."
#
# AssertionError: HpBandSter must be installed!
#             You can install HpBandSter with the command:
#             `pip install hpbandster ConfigSpace`.
