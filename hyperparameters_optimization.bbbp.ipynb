# %% [markdown]
# <a href="https://colab.research.google.com/github/sanaaria/Hyperparameter-Optimization/blob/main/hyperparameters_optimization.bbbp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dragonfly-opt
# !pip install -U hyperopt
# !pip install hpbandster ConfigSpace
# !pip install optuna

# %%
#pip install bayesian-optimization

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset
from pandas import read_csv
from sklearn.impute import SimpleImputer

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a7a22d0c-6566-4240-8818-f57611655824" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a7a22d0c-6566-4240-8818-f57611655824">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bbbp.csv to bbbp (1).csv

# %%
import pandas as pd
import io
data = pd.read_csv(io.BytesIO(uploaded['bbbp.csv']))
data.head()
# Out:
#                                               smiles  \
# 0                   [Cl].CC(C)NCC(O)COc1cccc2ccccc12
# 1           C(=O)(OC(C)(C)C)CCCc1ccc(cc1)N(CCCl)CCCl
# 2  c12c3c(N4CCN(C)CC4)c(F)cc1c(c(C(O)=O)cn2C(C)CO...
# 3                   C1CCN(CC1)Cc1cccc(c1)OCCCNC(=O)C
# 4  Cc1onc(c2ccccc2Cl)c1C(=O)N[C@H]3[C@H]4SC(C)(C)...
#
#    ('RDKit2DNormalized_calculated', <class 'bool'>)  \
# 0                                              True
# 1                                              True
# 2                                              True
# 3                                              True
# 4                                              True
#
#    ('BalabanJ', <class 'numpy.float64'>)  \
# 0                               0.000020
# 1                               0.921082
# 2                               0.755549
# 3                               0.519074
# 4                               0.362651
#
#    ('BertzCT', <class 'numpy.float64'>)  ('Chi0', <class 'numpy.float64'>)  \
# 0                              0.111833                           0.106451
# 1                              0.077697                           0.324169
# 2                              0.516673                           0.423380
# 3                              0.068097                           0.166625
# 4                              0.590649                           0.607809
#
#    ('Chi0n', <class 'numpy.float64'>)  ('Chi0v', <class 'numpy.float64'>)  \
# 0                            0.177350                            0.187815
# 1                            0.379878                            0.467164
# 2                            0.415340                            0.360944
# 3                            0.260552                            0.212714
# 4                            0.520746                            0.607038
#
#    ('Chi1', <class 'numpy.float64'>)  ('Chi1n', <class 'numpy.float64'>)  \
# 0                           0.110054                            0.168672
# 1                           0.240353                            0.344156
# 2                           0.400697                            0.428148
# 3                           0.185779                            0.328404
# 4                           0.538488                            0.471718
#
#    ('Chi1v', <class 'numpy.float64'>)  ...  \
# 0                            0.119391  ...
# 1                            0.422452  ...
# 2                            0.348007  ...
# 3                            0.255385  ...
# 4                            0.569018  ...
#
#    ('fr_sulfone', <class 'numpy.float64'>)  \
# 0                             5.770000e-14
# 1                             5.770000e-14
# 2                             5.770000e-14
# 3                             5.770000e-14
# 4                             5.770000e-14
#
#    ('fr_term_acetylene', <class 'numpy.float64'>)  \
# 0                                    2.960000e-11
# 1                                    2.960000e-11
# 2                                    2.960000e-11
# 3                                    2.960000e-11
# 4                                    2.960000e-11
#
#    ('fr_tetrazole', <class 'numpy.float64'>)  \
# 0                                   0.168378
# 1                                   0.168378
# 2                                   0.168378
# 3                                   0.168378
# 4                                   0.168378
#
#    ('fr_thiazole', <class 'numpy.float64'>)  \
# 0                                   0.16738
# 1                                   0.16738
# 2                                   0.16738
# 3                                   0.16738
# 4                                   0.16738
#
#    ('fr_thiocyan', <class 'numpy.float64'>)  \
# 0                              1.480000e-18
# 1                              1.480000e-18
# 2                              1.480000e-18
# 3                              1.480000e-18
# 4                              1.480000e-18
#
#    ('fr_thiophene', <class 'numpy.float64'>)  \
# 0                               2.320000e-16
# 1                               2.320000e-16
# 2                               2.320000e-16
# 3                               2.320000e-16
# 4                               2.320000e-16
#
#    ('fr_unbrch_alkane', <class 'numpy.float64'>)  \
# 0                                   4.700000e-08
# 1                                   4.700000e-08
# 2                                   4.700000e-08
# 3                                   9.991992e-01
# 4                                   4.700000e-08
#
#    ('fr_urea', <class 'numpy.float64'>)  ('qed', <class 'numpy.float64'>)  \
# 0                              0.166633                          0.930688
# 1                              0.166633                          0.322648
# 2                              0.166633                          0.949987
# 3                              0.166633                          0.818175
# 4                              0.166633                          0.689000
#
#    p_np
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#
# [5 rows x 203 columns]

# %%
del data["('RDKit2DNormalized_calculated', <class 'bool'>)"]
del data["smiles"]
#data.insert(0, 'smiles', first_column)
data.head()
# Out:
#    ('BalabanJ', <class 'numpy.float64'>)  \
# 0                               0.000020
# 1                               0.921082
# 2                               0.755549
# 3                               0.519074
# 4                               0.362651
#
#    ('BertzCT', <class 'numpy.float64'>)  ('Chi0', <class 'numpy.float64'>)  \
# 0                              0.111833                           0.106451
# 1                              0.077697                           0.324169
# 2                              0.516673                           0.423380
# 3                              0.068097                           0.166625
# 4                              0.590649                           0.607809
#
#    ('Chi0n', <class 'numpy.float64'>)  ('Chi0v', <class 'numpy.float64'>)  \
# 0                            0.177350                            0.187815
# 1                            0.379878                            0.467164
# 2                            0.415340                            0.360944
# 3                            0.260552                            0.212714
# 4                            0.520746                            0.607038
#
#    ('Chi1', <class 'numpy.float64'>)  ('Chi1n', <class 'numpy.float64'>)  \
# 0                           0.110054                            0.168672
# 1                           0.240353                            0.344156
# 2                           0.400697                            0.428148
# 3                           0.185779                            0.328404
# 4                           0.538488                            0.471718
#
#    ('Chi1v', <class 'numpy.float64'>)  ('Chi2n', <class 'numpy.float64'>)  \
# 0                            0.119391                            0.185866
# 1                            0.422452                            0.438361
# 2                            0.348007                            0.528003
# 3                            0.255385                            0.291954
# 4                            0.569018                            0.615152
#
#    ('Chi2v', <class 'numpy.float64'>)  ...  \
# 0                            0.119537  ...
# 1                            0.462373  ...
# 2                            0.416469  ...
# 3                            0.201587  ...
# 4                            0.792858  ...
#
#    ('fr_sulfone', <class 'numpy.float64'>)  \
# 0                             5.770000e-14
# 1                             5.770000e-14
# 2                             5.770000e-14
# 3                             5.770000e-14
# 4                             5.770000e-14
#
#    ('fr_term_acetylene', <class 'numpy.float64'>)  \
# 0                                    2.960000e-11
# 1                                    2.960000e-11
# 2                                    2.960000e-11
# 3                                    2.960000e-11
# 4                                    2.960000e-11
#
#    ('fr_tetrazole', <class 'numpy.float64'>)  \
# 0                                   0.168378
# 1                                   0.168378
# 2                                   0.168378
# 3                                   0.168378
# 4                                   0.168378
#
#    ('fr_thiazole', <class 'numpy.float64'>)  \
# 0                                   0.16738
# 1                                   0.16738
# 2                                   0.16738
# 3                                   0.16738
# 4                                   0.16738
#
#    ('fr_thiocyan', <class 'numpy.float64'>)  \
# 0                              1.480000e-18
# 1                              1.480000e-18
# 2                              1.480000e-18
# 3                              1.480000e-18
# 4                              1.480000e-18
#
#    ('fr_thiophene', <class 'numpy.float64'>)  \
# 0                               2.320000e-16
# 1                               2.320000e-16
# 2                               2.320000e-16
# 3                               2.320000e-16
# 4                               2.320000e-16
#
#    ('fr_unbrch_alkane', <class 'numpy.float64'>)  \
# 0                                   4.700000e-08
# 1                                   4.700000e-08
# 2                                   4.700000e-08
# 3                                   9.991992e-01
# 4                                   4.700000e-08
#
#    ('fr_urea', <class 'numpy.float64'>)  ('qed', <class 'numpy.float64'>)  \
# 0                              0.166633                          0.930688
# 1                              0.166633                          0.322648
# 2                              0.166633                          0.949987
# 3                              0.166633                          0.818175
# 4                              0.166633                          0.689000
#
#    p_np
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#
# [5 rows x 201 columns]

# %%
data.shape
# Out:
# (2039, 201)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2039 entries, 0 to 2038
# Columns: 201 entries, ('BalabanJ', <class 'numpy.float64'>) to p_np
# dtypes: float64(199), int64(2)
# memory usage: 3.1 MB

# %%
data.describe()
# Out:
#        ('BalabanJ', <class 'numpy.float64'>)  \
# count                            2039.000000
# mean                                0.604334
# std                                 0.312428
# min                                 0.000020
# 25%                                 0.376547
# 50%                                 0.684349
# 75%                                 0.874519
# max                                 0.999343
#
#        ('BertzCT', <class 'numpy.float64'>)  \
# count                           2039.000000
# mean                               0.291380
# std                                0.251739
# min                                0.000577
# 25%                                0.082053
# 50%                                0.230083
# 75%                                0.438195
# max                                1.000000
#
#        ('Chi0', <class 'numpy.float64'>)  ('Chi0n', <class 'numpy.float64'>)  \
# count                        2039.000000                        2.039000e+03
# mean                            0.337879                        3.573345e-01
# std                             0.293971                        2.893572e-01
# min                             0.000002                        1.980000e-08
# 25%                             0.082985                        9.334640e-02
# 50%                             0.243373                        2.944113e-01
# 75%                             0.560798                        5.762799e-01
# max                             0.999913                        9.998828e-01
#
#        ('Chi0v', <class 'numpy.float64'>)  ('Chi1', <class 'numpy.float64'>)  \
# count                        2.039000e+03                        2039.000000
# mean                         3.555512e-01                           0.330076
# std                          2.938552e-01                           0.282478
# min                          4.530000e-07                           0.000001
# 25%                          8.693349e-02                           0.085748
# 50%                          2.866005e-01                           0.256325
# 75%                          5.794196e-01                           0.538452
# max                          9.999034e-01                           0.999915
#
#        ('Chi1n', <class 'numpy.float64'>)  ('Chi1v', <class 'numpy.float64'>)  \
# count                        2.039000e+03                         2039.000000
# mean                         3.722977e-01                            0.364649
# std                          2.921984e-01                            0.292215
# min                          2.680000e-07                            0.000042
# 25%                          1.031724e-01                            0.093407
# 50%                          3.198660e-01                            0.309533
# 75%                          6.049746e-01                            0.595135
# max                          9.998737e-01                            0.999931
#
#        ('Chi2n', <class 'numpy.float64'>)  ('Chi2v', <class 'numpy.float64'>)  \
# count                         2039.000000                        2.039000e+03
# mean                             0.409469                        4.051476e-01
# std                              0.313242                        3.164573e-01
# min                              0.000001                        2.210000e-07
# 25%                              0.112201                        1.007599e-01
# 50%                              0.364833                        3.658837e-01
# 75%                              0.661656                        6.885461e-01
# max                              0.999863                        9.998239e-01
#
#        ...  ('fr_sulfone', <class 'numpy.float64'>)  \
# count  ...                             2.039000e+03
# mean   ...                             9.808730e-03
# std    ...                             9.857629e-02
# min    ...                             5.770000e-14
# 25%    ...                             5.770000e-14
# 50%    ...                             5.770000e-14
# 75%    ...                             5.770000e-14
# max    ...                             1.000000e+00
#
#        ('fr_term_acetylene', <class 'numpy.float64'>)  \
# count                                    2.039000e+03
# mean                                     7.846984e-03
# std                                      8.825661e-02
# min                                      2.960000e-11
# 25%                                      2.960000e-11
# 50%                                      2.960000e-11
# 75%                                      2.960000e-11
# max                                      1.000000e+00
#
#        ('fr_tetrazole', <class 'numpy.float64'>)  \
# count                                2039.000000
# mean                                    0.177759
# std                                     0.087846
# min                                     0.168378
# 25%                                     0.168378
# 50%                                     0.168378
# 75%                                     0.168378
# max                                     1.000000
#
#        ('fr_thiazole', <class 'numpy.float64'>)  \
# count                               2039.000000
# mean                                   0.186164
# std                                    0.123671
# min                                    0.167380
# 25%                                    0.167380
# 50%                                    0.167380
# 75%                                    0.167380
# max                                    1.000000
#
#        ('fr_thiocyan', <class 'numpy.float64'>)  \
# count                              2.039000e+03
# mean                               1.480000e-18
# std                                5.779207e-34
# min                                1.480000e-18
# 25%                                1.480000e-18
# 50%                                1.480000e-18
# 75%                                1.480000e-18
# max                                1.480000e-18
#
#        ('fr_thiophene', <class 'numpy.float64'>)  \
# count                               2.039000e+03
# mean                                1.618440e-02
# std                                 1.262152e-01
# min                                 2.320000e-16
# 25%                                 2.320000e-16
# 50%                                 2.320000e-16
# 75%                                 2.320000e-16
# max                                 1.000000e+00
#
#        ('fr_unbrch_alkane', <class 'numpy.float64'>)  \
# count                                   2.039000e+03
# mean                                    8.005408e-02
# std                                     2.681487e-01
# min                                     4.700000e-08
# 25%                                     4.700000e-08
# 50%                                     4.700000e-08
# 75%                                     4.700000e-08
# max                                     1.000000e+00
#
#        ('fr_urea', <class 'numpy.float64'>)  ('qed', <class 'numpy.float64'>)  \
# count                           2039.000000                       2039.000000
# mean                               0.201374                          0.578456
# std                                0.166608                          0.279008
# min                                0.166633                          0.003427
# 25%                                0.166633                          0.370570
# 50%                                0.166633                          0.631207
# 75%                                0.166633                          0.812874
# max                                1.000000                          0.999021
#
#               p_np
# count  2039.000000
# mean      0.765081
# std       0.424052
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
#
# [8 rows x 201 columns]

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
Xdata = data.iloc[:, 0:200]
Ydata = data.iloc[:, 200:201]

# %%
Ydata.head
# Out:
# <bound method NDFrame.head of       p_np
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ...    ...
# 2034     1
# 2035     1
# 2036     1
# 2037     1
# 2038     1
#
# [2039 rows x 1 columns]>

# %%
# from sklearn.model_selection import train_test_split
# train_data, test_data, train_labels, test_labels = train_test_split(Xdata, Ydata, test_size=0.3, random_state=1)
# print(train_data.shape, train_labels.shape, test_data.shape, test_labels.shape)

from sklearn.model_selection import train_test_split
train_data, test_data, train_labels, test_labels = train_test_split(Xdata, Ydata, stratify = Ydata , test_size = 0.25)

# %%
train_data = np.array(train_data)
test_data = np.array(test_data)

train_labels = np.array(train_labels)
test_labels = np.array(test_labels)

# %%
train_data.shape
# Out:
# (1529, 200)

# %%
# from sklearn.decomposition import PCA as sklearnPCA
# sklearn_pca = sklearnPCA(n_components=15)
# X_train_pca = sklearn_pca.fit_transform(X_train)
# print(X_train_pca.shape)

# %%
# from sklearn import preprocessing

# scaler_data = preprocessing.MinMaxScaler()
# train_data = scaler_data.fit_transform(train_data)
# test_data = scaler_data.transform(test_data)

# scaler_labels = preprocessing.MinMaxScaler()
# train_labels_before = train_labels.values.reshape(-1, 1)
# train_labels = scaler_labels.fit_transform(train_labels.values.reshape(-1, 1))
# test_labels = scaler_labels.transform(test_labels.values.reshape(-1, 1))

# print(train_data.shape, train_labels.shape, test_data.shape, test_labels.shape)
# print("Train labels before scaling: {} {} {}Train labels after scaling: {} {}".format('\n',train_labels_before,'\n', '\n', train_labels))

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# transform to torch tensor

tensor_x = torch.tensor(train_data, dtype=torch.float).to(device) 
tensor_x2 = torch.tensor(test_data, dtype=torch.float).to(device) 

tensor_y = torch.tensor(train_labels, dtype=torch.float).to(device)
tensor_y2 = torch.tensor(test_labels, dtype=torch.float).to(device)

# %%
# create your dataset

trainset = TensorDataset(tensor_x, tensor_y) 
testset = TensorDataset(tensor_x2,tensor_y2)

# %%
# %%capture
try:
    import ray
except:
    # !pip install -U ray
    import ray

# %%
from functools import partial
import numpy as np
import os
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
from torchsummary import summary

from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler

# %%
from ray.tune.suggest.hyperopt import HyperOptSearch
from ray.tune.suggest.optuna import OptunaSearch  
from ray.tune.suggest.dragonfly import DragonflySearch
from ray.tune.suggest.bayesopt import BayesOptSearch
from ray.tune.schedulers.hb_bohb import HyperBandForBOHB
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.schedulers import MedianStoppingRule
from ray.tune.schedulers import PopulationBasedTraining
from ray.tune.suggest.bohb import TuneBOHB
from ray.tune.suggest.basic_variant import BasicVariantGenerator
from ray.tune.suggest import ConcurrencyLimiter

# %%
def load_data(data_dir=None):
    return trainset, testset

# %%
from sklearn.metrics import roc_auc_score

def compute_score(model, data_loader, device="cpu"):
    model.eval()
    metric = roc_auc_score
    with torch.no_grad():
        prediction_all= torch.empty(0, device=device)
        labels_all= torch.empty(0, device=device)
        for i, (feats, labels) in enumerate(data_loader):
            feats=feats.to(device)
            labels=labels.to(device)
            prediction = model(feats).to(device)
            prediction = torch.sigmoid(prediction).to(device)
            prediction_all = torch.cat((prediction_all, prediction), 0)
            labels_all = torch.cat((labels_all, labels), 0)                
        try:
            t = metric(labels_all.int().cpu(), prediction_all.cpu()).item()
        except ValueError:
            t = 0
    return t

# %%
class Net(nn.Module):
    def __init__(self, config):
        super().__init__()
        
        self.config = config
        self.hidden_dim1 = int(self.config.get("hidden_dim1", 100))
        self.hidden_dim2 = int(self.config.get("hidden_dim2", 100))
        self.hidden_dim3 = int(self.config.get("hidden_dim3", 100))

        self.act1 = self.config.get("act1", "relu") 
        self.act2 = self.config.get("act2", "relu") 
        self.act3 = self.config.get("act3", "relu")

        self.linear1 = nn.Linear(200, self.hidden_dim1)
        self.linear2 = nn.Linear(self.hidden_dim1, self.hidden_dim2)
        self.linear3 = nn.Linear(self.hidden_dim2, self.hidden_dim3)
        self.linear4 = nn.Linear(self.hidden_dim3, 1)
    
    @staticmethod
    def activation_func(act_str):
        if act_str=="tanh":
            return eval("torch."+act_str)
        elif act_str=="selu" or act_str=="relu":   
            return eval("torch.nn.functional."+act_str)

    def forward(self, x):
        output = self.linear1(x)
        output = self.activation_func(self.act1)(output)
        output = self.linear2(output)
        output = self.activation_func(self.act2)(output)
        output = self.linear3(output)
        output = self.activation_func(self.act3)(output)
        output = self.linear4(output)        
        return output

# %%
model = Net({})

# %%
from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        table.add_row([name, param])
        total_params+=param
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

# %%
summary(model, (1,tensor_x.shape[1]))

count_parameters(model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1               [-1, 1, 100]          20,100
#             Linear-2               [-1, 1, 100]          10,100
#             Linear-3               [-1, 1, 100]          10,100
#             Linear-4                 [-1, 1, 1]             101
# ================================================================
# Total params: 40,401
# Trainable params: 40,401
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.15
# Estimated Total Size (MB): 0.16
# ----------------------------------------------------------------
# +----------------+------------+
# |    Modules     | Parameters |
# +----------------+------------+
# | linear1.weight |   20000    |
# |  linear1.bias  |    100     |
# | linear2.weight |   10000    |
# |  linear2.bias  |    100     |
# | linear3.weight |   10000    |
# |  linear3.bias  |    100     |
# | linear4.weight |    100     |
# |  linear4.bias  |     1      |
# +----------------+------------+
# Total Trainable Params: 40401
# 40401

# %%
def trainable_func(config, checkpoint_dir=None, data_dir=None, epochs=10):

    net = Net(config)

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if torch.cuda.device_count() > 1:
            net = nn.DataParallel(net)
    net.to(device)

    '''
    Define a loss function
    '''
    ## Classification
    criterion = nn.CrossEntropyLoss()

    # Define an optimizer 
    optimizer = optim.Adam(net.parameters(), lr=config.get("lr",0.0003))

    if checkpoint_dir:
        model_state, optimizer_state = torch.load(
            os.path.join(checkpoint_dir, "checkpoint"))
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    # Load data
    trainset, testset = load_data(data_dir)

    # Split the dataset into training and validation sets
    train_size = int(len(trainset) * 0.66)
    train_subset, val_subset = random_split(trainset, [train_size, len(trainset) - train_size])

    # Define data loaders (which combines a dataset and a sampler, and provides an iterable over the given dataset)
    trainloader = torch.utils.data.DataLoader(
        train_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=True,
        num_workers=2)
    valloader = torch.utils.data.DataLoader(
        val_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=True,
        num_workers=2)

    for epoch in range(epochs):  # loop over the dataset multiple times
        epoch_train_loss = 0.0
        # epoch_steps = 0
        net.train() # Prepare model for training
        for i, data in enumerate(trainloader):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            '''
            Compute train loss without scaling to print
            ''' 
            # outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            # labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device)  
            # loss_train = criterion(outputs, labels) 
            # epoch_train_loss += loss_train.detach().item()
        # print("[%d] loss: %.3f" % (epoch + 1, epoch_train_loss / len(train_subset)))

        # Validation loss
        # val_loss = 0.0
        # net.eval() # Prepare model for evaluation
        # for i, data in enumerate(valloader):
        #     with torch.no_grad():
        #         inputs, labels = data
        #         inputs, labels = inputs.to(device), labels.to(device)

        #         outputs = net(inputs)

        # Validation score
        score = compute_score(net, valloader, device="cpu")

        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save((net.state_dict(), optimizer.state_dict()), path)
        tune.report(score=score)

                # Inverse transform of the labels' scaler  این دو خط رو کامنت کردی!!!!!
                #outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
                #labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

                # loss = criterion(outputs, labels)
                # val_loss += loss.cpu().numpy()

    #     with tune.checkpoint_dir(epoch) as checkpoint_dir:
    #         path = os.path.join(checkpoint_dir, "checkpoint")
    #         torch.save((net.state_dict(), optimizer.state_dict()), path)

    #     tune.report(epoch = epoch, loss=(val_loss / len(val_subset)))
    print("Finished Training")

# %%
# def test_score(config, net, device="cpu"):
#     trainset, testset = load_data()

#     testloader = torch.utils.data.DataLoader(
#         testset, batch_size=int(config.get("batch_size",32)), shuffle=False, num_workers=2)
    
#     criterion = nn.CrossEntropyLoss()

#     # Test loss
#     # test_loss = 0.0
#     # net.eval() # Prepare model for evaluation
#     # for i, data in enumerate(testloader):
#     #     with torch.no_grad():
#     #         inputs, labels = data
#     #         inputs, labels = inputs.to(device), labels.to(device)

#     #         outputs = net(inputs)

#     test_score = compute_score(best_trained_model, testloader, device)
#     print("Best trial test set score: {}".format(test_score))

#             # Inverse transform of the labels' scaler
#             # outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
#             # labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

#     #         loss = criterion(outputs, labels)
#     #         test_loss += loss.cpu().numpy()

#     # return test_loss / len(testset)

def test_score(config, net, device="cpu"):
    trainset, testset = load_data()
    best_trial=config
    testloader = torch.utils.data.DataLoader(
            testset, 
            batch_size=int(best_trial["batch_size"]), 
            shuffle=False, 
            num_workers=2)
    test_score = compute_score(net, testloader, device)
    print("Best trial test set score: {}".format(test_score))

# %% [markdown]
# start ray run time

# %%
ray.shutdown()
ray.init() # Here we use ray.init() to evaluate available_resources for Ray
print(ray.available_resources())
  # Restart Ray defensively in case the ray connection is lost. 

# Start Ray runtime with specific resources (not nessesarily all resources)
# You can change this values based on your machine resources)
#ray.init(num_cpus=2, num_gpus=0) 

"""Check Ray Tune is working properly (for trainable class)"""
# from ray.tune.utils import validate_save_restore
# validate_save_restore(Trainable)
# validate_save_restore(Trainable, use_object_store=True)
# print("Success!")
# Out:
# {'object_store_memory': 3941207654.0, 'node:172.28.0.2': 1.0, 'memory': 7882415310.0, 'CPU': 2.0}
# 'Check Ray Tune is working properly (for trainable class)'

# %%
# %%capture
try:
    import optuna
except:
    # %pip install optuna
    import optuna

# %%
def main(num_samples=10, max_num_epochs=10, gpus_per_trial=2):

    # define data directory here if you want to load data from files
    data_dir = os.path.abspath("./bbbp")
    load_data(data_dir)

    # define the search space of hyperparameters
    config = {
        "act1 ": tune.choice(["relu","tanh","selu"]),
        "act2" : tune.choice(["relu","tanh","selu"]),
        "act3" : tune.choice(["relu","tanh","selu"]),
        "lr": tune.quniform(0.0005, 0.001, 0.0001),
        "batch_size": tune.choice([8, 16, 32]),
        "hidden_dim1" : tune.quniform(50, 200, 10),
        "hidden_dim2" : tune.quniform(50, 200, 10),
        "hidden_dim3" : tune.quniform(50, 200, 10),
    }

    # Optuna search algorithm
    from ray.tune.suggest.optuna import OptunaSearch 
    from ray.tune.suggest import ConcurrencyLimiter
    search_alg = OptunaSearch(
        metric="score", #or accuracy, etc.
        mode="max", #or max
        #seed = 42,
        # points_to_evaluate=[
        # {'lr': 0.0005, 'hidden_size': 150.0, 'readout1_out': 200.0, 'readout2_out': 180.0}
        # ],
        )
    

    # ## Hyperopt
    # search_alg = HyperOptSearch(
    #     # space=config,
    #     metric="score", #or accuracy, etc.
    #     mode="max", #or max
    #     n_initial_points=60,
    #     # gamma = 0.1,
    #     # random_state_seed=42,
    #     # points_to_evaluate=[{"max_norm_val": 2.5, 'GNN_Layers': 3, 'dropout': 0.25, 'dropout1': 0.35, 'dropout2': 0.15, 'lr': 0.001, 'hidden_size': 80, 'readout1_out': 150, 'readout2_out': 100, 'batch_size': 64}],
    #     )

    

    search_alg = ConcurrencyLimiter(search_alg, max_concurrent=10)

    scheduler = ASHAScheduler(
        metric ="score",
        mode="max",
        max_t=max_num_epochs,
        reduction_factor=2, 
        grace_period=4,
        brackets=5
        )
    
    # ## ASHA
    # scheduler = AsyncHyperBandScheduler(
    #     time_attr="training_iteration",
    #     #max_t=training_iteration,
    #     metric="score", #or accuracy, etc.
    #     mode="max", #or max
    #     reduction_factor=2, 
    #     grace_period=4,
    #     brackets=5,
    #     )

    # ## BOHB
    # scheduler = HyperBandForBOHB(
    #     time_attr="training_iteration",
    #     #max_t=training_iteration, 
    #     reduction_factor=8, 
    #     stop_last_trials=True,
    #     metric="score", #or accuracy, etc.
    #     mode="max", #or max
    #     )

    # ## Median
    # scheduler = MedianStoppingRule(
    #     time_attr="training_iteration",
    #     grace_period=10,
    #     min_samples_required=10,
    #     hard_stop = True,
    #     metric="score", #or accuracy, etc.
    #     mode="max", #or max
    #     )


    # ## PBT
    # scheduler = PopulationBasedTraining(
    #     time_attr="training_iteration",
    #     metric="score", #or accuracy, etc.
    #     mode="max", #or max
    #     perturbation_interval=10,  # every 10 `time_attr` units
    #                             # (training_iterations in this case)
    #     # hyperparam_mutations={
    #     #     "lr": [8e-3, 7e-3, 6e-3, 5e-3, 4e-3],
    #     #     "dropout": tune.quniform(0.0, 0.4, 0.05),
    #     #     "dropout1": tune.quniform(0.0, 0.4, 0.05),
    #     #     "dropout2": tune.quniform(0.0, 0.4, 0.05),
    #     #     "max_norm_val":tune.choice([2.5, 3, 3.5, 4]),
    #     #     }
    #     )

    reporter = CLIReporter(
        # parameter_columns=["l1", "l2", "lr", "batch_size"],
        metric_columns=["score", "training_iteration"]
        )
    
    # wrap data loading and training for tuning using `partial` 
    # (note that there exist other methods for this purpose)
    result = tune.run(
        partial(trainable_func, data_dir=data_dir, epochs=max_num_epochs),
        scheduler=scheduler,
        search_alg=search_alg,
        num_samples=num_samples,
        config=config,
        verbose=2,
        checkpoint_score_attr="score",
        checkpoint_freq=0,
        keep_checkpoints_num=1,
        # checkpoint_at_end=True,
        # reuse_actors=reuse_actors_status,
        progress_reporter=reporter,
        resources_per_trial={"cpu": 0.5, "gpu": gpus_per_trial},
        stop={"training_iteration": max_num_epochs},                
        )

    best_trial = result.get_best_trial("score", "max", "last")
    print("Best trial config: {}".format(best_trial.config))
    print("Best trial final validation score: {}".format(
        best_trial.last_result["score"]))

    best_trained_model = Net(best_trial.config)
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if gpus_per_trial > 1:
            best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)

    best_checkpoint_dir = best_trial.checkpoint.value
    model_state, optimizer_state = torch.load(os.path.join(
        best_checkpoint_dir, "checkpoint"))
    best_trained_model.load_state_dict(model_state)

    test_score_value = test_score(best_trial.config, best_trained_model, device)
    print("Best trial test set score: {}".format(test_score_value))


if __name__ == "__main__":
    # You can change the number of GPUs per trial here:
    main(num_samples=50, max_num_epochs=10, gpus_per_trial=0)
# Out:
# [I 2022-07-18 13:13:47,055] A new study created in memory with name: optuna
# 2022-07-18 13:13:47,060	WARNING callback.py:106 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# == Status ==
# Current time: 2022-07-18 13:13:47 (running for 00:00:00.23)
# Memory usage on this node: 1.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 8.000: None
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 1/50 (1 RUNNING)
#
#
# == Status ==
# Current time: 2022-07-18 13:13:52 (running for 00:00:05.45)
# Memory usage on this node: 1.9/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 8.000: None
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_751e9334 reported score=0.23603381398094275,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 32, 'hidden_dim1': 150.0, 'hidden_dim2': 150.0, 'hidden_dim3': 140.0}.
# Trial trainable_func_74fab87e reported score=0.4037395833333333,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 70.0, 'hidden_dim2': 170.0, 'hidden_dim3': 170.0}.
# == Status ==
# Current time: 2022-07-18 13:13:57 (running for 00:00:10.84)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: 0.23603381398094275
# Bracket: Iter 8.000: None
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_751e9334 reported score=0.23603381398094275,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 32, 'hidden_dim1': 150.0, 'hidden_dim2': 150.0, 'hidden_dim3': 140.0}.
# Trial trainable_func_752495d6 reported score=0.31264701418924046,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 120.0, 'hidden_dim2': 100.0, 'hidden_dim3': 160.0}.
# Trial trainable_func_752d36fa reported score=0.38858167538218036,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 150.0, 'hidden_dim2': 70.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_751e9334 reported score=0.23603381398094275,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 32, 'hidden_dim1': 150.0, 'hidden_dim2': 150.0, 'hidden_dim3': 140.0}. This trial completed.
# == Status ==
# Current time: 2022-07-18 13:14:03 (running for 00:00:16.14)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: 0.23603381398094275 | Iter 4.000: 0.23603381398094275
# Bracket: Iter 8.000: None
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_753942e2 reported score=0.6537547869181463,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 80.0, 'hidden_dim2': 170.0, 'hidden_dim3': 160.0}.
# Trial trainable_func_74fab87e reported score=0.4037395833333333,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 70.0, 'hidden_dim2': 170.0, 'hidden_dim3': 170.0}.
# Trial trainable_func_752495d6 reported score=0.31264701418924046,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 120.0, 'hidden_dim2': 100.0, 'hidden_dim3': 160.0}.
# Trial trainable_func_752d36fa reported score=0.38858167538218036,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 150.0, 'hidden_dim2': 70.0, 'hidden_dim3': 80.0}.
# == Status ==
# Current time: 2022-07-18 13:14:08 (running for 00:00:21.71)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: 0.23603381398094275 | Iter 4.000: 0.4448943004495445
# Bracket: Iter 8.000: None
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 6/50 (1 PENDING, 4 RUNNING, 1 TERMINATED)
#
#
# Trial trainable_func_753942e2 reported score=0.6537547869181463,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 80.0, 'hidden_dim2': 170.0, 'hidden_dim3': 160.0}.
# Trial trainable_func_752d36fa reported score=0.38858167538218036,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 150.0, 'hidden_dim2': 70.0, 'hidden_dim3': 80.0}. This trial completed.
# Trial trainable_func_74fab87e reported score=0.4037395833333333,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 70.0, 'hidden_dim2': 170.0, 'hidden_dim3': 170.0}.
# Trial trainable_func_7e9c0db0 reported score=0.3489689578713968,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 70.0, 'hidden_dim2': 100.0, 'hidden_dim3': 110.0}.
# Trial trainable_func_752495d6 reported score=0.31264701418924046,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 120.0, 'hidden_dim2': 100.0, 'hidden_dim3': 160.0}.
# Trial trainable_func_753942e2 reported score=0.6537547869181463,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 80.0, 'hidden_dim2': 170.0, 'hidden_dim3': 160.0}. This trial completed.
# Trial trainable_func_7e9c0db0 reported score=0.3489689578713968,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 70.0, 'hidden_dim2': 100.0, 'hidden_dim3': 110.0}. This trial completed.
# Trial trainable_func_8293cd40 reported score=0.6570592352230069,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 150.0, 'hidden_dim3': 50.0}.
# == Status ==
# Current time: 2022-07-18 13:14:14 (running for 00:00:27.12)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 8.000: 0.4448943004495445 | Iter 4.000: 0.3687753166267886
# Bracket: Iter 8.000: None
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 9/50 (1 PENDING, 4 RUNNING, 4 TERMINATED)
#
#
# Trial trainable_func_8437de70 reported score=0.605314444979987,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 170.0, 'hidden_dim2': 60.0, 'hidden_dim3': 170.0}.
# Trial trainable_func_74fab87e reported score=0.4037395833333333,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 70.0, 'hidden_dim2': 170.0, 'hidden_dim3': 170.0}.
# Trial trainable_func_752495d6 reported score=0.31264701418924046,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 120.0, 'hidden_dim2': 100.0, 'hidden_dim3': 160.0}.
# == Status ==
# Current time: 2022-07-18 13:14:19 (running for 00:00:32.34)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 8.000: 0.4448943004495445 | Iter 4.000: 0.38858167538218036
# Bracket: Iter 8.000: 0.4037395833333333
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 9/50 (1 PENDING, 4 RUNNING, 4 TERMINATED)
#
#
# Trial trainable_func_8293cd40 reported score=0.6570592352230069,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 150.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_74fab87e reported score=0.4037395833333333,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 70.0, 'hidden_dim2': 170.0, 'hidden_dim3': 170.0}. This trial completed.
# Trial trainable_func_8437de70 reported score=0.605314444979987,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 170.0, 'hidden_dim2': 60.0, 'hidden_dim3': 170.0}.
# Trial trainable_func_84beffe0 reported score=0.4350674291567088,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 110.0, 'hidden_dim2': 70.0, 'hidden_dim3': 190.0}.
# Trial trainable_func_752495d6 reported score=0.31264701418924046,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 120.0, 'hidden_dim2': 100.0, 'hidden_dim3': 160.0}.
# == Status ==
# Current time: 2022-07-18 13:14:24 (running for 00:00:37.48)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 8.000: 0.4448943004495445 | Iter 4.000: 0.38858167538218036
# Bracket: Iter 8.000: 0.4037395833333333
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 10/50 (1 PENDING, 4 RUNNING, 5 TERMINATED)
#
#
# Trial trainable_func_752495d6 reported score=0.31264701418924046,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 120.0, 'hidden_dim2': 100.0, 'hidden_dim3': 160.0}. This trial completed.
# Trial trainable_func_8293cd40 reported score=0.6570592352230069,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 150.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_892aa782 reported score=0.5868749472974112,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 200.0, 'hidden_dim2': 120.0, 'hidden_dim3': 140.0}.
# Trial trainable_func_8437de70 reported score=0.605314444979987,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 170.0, 'hidden_dim2': 60.0, 'hidden_dim3': 170.0}.
# Trial trainable_func_84beffe0 reported score=0.4350674291567088,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 110.0, 'hidden_dim2': 70.0, 'hidden_dim3': 190.0}.
# Trial trainable_func_8293cd40 reported score=0.6570592352230069,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 150.0, 'hidden_dim3': 50.0}. This trial completed.
# Trial trainable_func_8437de70 reported score=0.605314444979987,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 170.0, 'hidden_dim2': 60.0, 'hidden_dim3': 170.0}. This trial completed.
# Trial trainable_func_8bc0f3a2 reported score=0.5380811377004271,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 110.0, 'hidden_dim2': 180.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_8d449580 reported score=0.6841979166666666,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 50.0, 'hidden_dim2': 190.0, 'hidden_dim3': 90.0}.
# == Status ==
# Current time: 2022-07-18 13:14:29 (running for 00:00:42.72)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 8.000: 0.605314444979987 | Iter 4.000: 0.38858167538218036
# Bracket: Iter 8.000: 0.4194035062450211
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 13/50 (1 PENDING, 4 RUNNING, 8 TERMINATED)
#
#
# Trial trainable_func_84beffe0 reported score=0.4350674291567088,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 110.0, 'hidden_dim2': 70.0, 'hidden_dim3': 190.0}. This trial completed.
# Trial trainable_func_892aa782 reported score=0.5868749472974112,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 200.0, 'hidden_dim2': 120.0, 'hidden_dim3': 140.0}.
# Trial trainable_func_8dca22fe reported score=0.6421430802874102,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 140.0, 'hidden_dim2': 200.0, 'hidden_dim3': 140.0}.
# Trial trainable_func_8bc0f3a2 reported score=0.5380811377004271,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 110.0, 'hidden_dim2': 180.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_8d449580 reported score=0.6841979166666666,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 50.0, 'hidden_dim2': 190.0, 'hidden_dim3': 90.0}.
# == Status ==
# Current time: 2022-07-18 13:14:34 (running for 00:00:47.89)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 8.000: 0.605314444979987 | Iter 4.000: 0.38858167538218036
# Bracket: Iter 8.000: 0.4194035062450211
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 14/50 (1 PENDING, 4 RUNNING, 9 TERMINATED)
#
#
# Trial trainable_func_8d449580 reported score=0.6841979166666666,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 50.0, 'hidden_dim2': 190.0, 'hidden_dim3': 90.0}. This trial completed.
# Trial trainable_func_8bc0f3a2 reported score=0.5380811377004271,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 110.0, 'hidden_dim2': 180.0, 'hidden_dim3': 130.0}. This trial completed.
# Trial trainable_func_892aa782 reported score=0.5868749472974112,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 200.0, 'hidden_dim2': 120.0, 'hidden_dim3': 140.0}.
# Trial trainable_func_931155c0 reported score=0.7494220344387756,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 50.0, 'hidden_dim2': 200.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_8dca22fe reported score=0.6421430802874102,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 140.0, 'hidden_dim2': 200.0, 'hidden_dim3': 140.0}.
# == Status ==
# Current time: 2022-07-18 13:14:40 (running for 00:00:52.97)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 8.000: 0.605314444979987 | Iter 4.000: 0.38858167538218036
# Bracket: Iter 8.000: 0.4194035062450211
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 16/50 (1 PENDING, 4 RUNNING, 11 TERMINATED)
#
#
# Trial trainable_func_8ea119b2 reported score=0.5110228630105409,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 50.0, 'hidden_dim2': 130.0, 'hidden_dim3': 190.0}.
# Trial trainable_func_892aa782 reported score=0.5868749472974112,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 200.0, 'hidden_dim2': 120.0, 'hidden_dim3': 140.0}. This trial completed.
# Trial trainable_func_9357c622 reported score=0.5299995678852303,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 50.0, 'hidden_dim2': 200.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_931155c0 reported score=0.7494220344387756,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 50.0, 'hidden_dim2': 200.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_8dca22fe reported score=0.6421430802874102,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 140.0, 'hidden_dim2': 200.0, 'hidden_dim3': 140.0}.
# == Status ==
# Current time: 2022-07-18 13:14:45 (running for 00:00:58.09)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 8.000: 0.605314444979987 | Iter 4.000: 0.605314444979987
# Bracket: Iter 8.000: 0.4194035062450211
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 17/50 (1 PENDING, 4 RUNNING, 12 TERMINATED)
#
#
# Trial trainable_func_8ea119b2 reported score=0.5110228630105409,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 50.0, 'hidden_dim2': 130.0, 'hidden_dim3': 190.0}.
# Trial trainable_func_931155c0 reported score=0.7494220344387756,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 50.0, 'hidden_dim2': 200.0, 'hidden_dim3': 100.0}. This trial completed.
# Trial trainable_func_8ea119b2 reported score=0.5110228630105409,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 50.0, 'hidden_dim2': 130.0, 'hidden_dim3': 190.0}. This trial completed.
# Trial trainable_func_9357c622 reported score=0.5299995678852303,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 50.0, 'hidden_dim2': 200.0, 'hidden_dim3': 50.0}. This trial completed.
# Trial trainable_func_98bf274a reported score=0.4823435972629521,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 50.0, 'hidden_dim2': 200.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_95a16276 reported score=0.5882352941176471,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 50.0, 'hidden_dim2': 200.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_99096652 reported score=0.5096710568174587,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 50.0, 'hidden_dim2': 200.0, 'hidden_dim3': 100.0}.
# == Status ==
# Current time: 2022-07-18 13:14:50 (running for 00:01:03.37)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 8.000: 0.6295346159490667 | Iter 4.000: 0.5299995678852303
# Bracket: Iter 8.000: 0.4194035062450211
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 20/50 (1 PENDING, 4 RUNNING, 15 TERMINATED)
#
#
# Trial trainable_func_8dca22fe reported score=0.6421430802874102,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 140.0, 'hidden_dim2': 200.0, 'hidden_dim3': 140.0}.
# Trial trainable_func_99096652 reported score=0.5096710568174587,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 50.0, 'hidden_dim2': 200.0, 'hidden_dim3': 100.0}. This trial completed.
# Trial trainable_func_994b806e reported score=0.31170576735092864,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 90.0, 'hidden_dim2': 200.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_95a16276 reported score=0.5882352941176471,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 50.0, 'hidden_dim2': 200.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_98bf274a reported score=0.4823435972629521,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 50.0, 'hidden_dim2': 200.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_994b806e reported score=0.3116955848810688,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 90.0, 'hidden_dim2': 200.0, 'hidden_dim3': 100.0}. This trial completed.
# == Status ==
# Current time: 2022-07-18 13:14:55 (running for 00:01:08.58)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=6
# Bracket: Iter 8.000: 0.6421430802874102 | Iter 4.000: 0.5205112154478856
# Bracket: Iter 8.000: 0.4194035062450211
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 21/50 (1 PENDING, 4 RUNNING, 16 TERMINATED)
#
#
# Trial trainable_func_9b883d0e reported score=0.41684239300218684,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 90.0, 'hidden_dim2': 190.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_98bf274a reported score=0.4823435972629521,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 50.0, 'hidden_dim2': 200.0, 'hidden_dim3': 100.0}. This trial completed.
# Trial trainable_func_8dca22fe reported score=0.6421430802874102,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 140.0, 'hidden_dim2': 200.0, 'hidden_dim3': 140.0}.
# Trial trainable_func_9ddd2484 reported score=0.4810557639514659,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 90.0, 'hidden_dim2': 180.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_95a16276 reported score=0.5882352941176471,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 50.0, 'hidden_dim2': 200.0, 'hidden_dim3': 50.0}. This trial completed.
# Trial trainable_func_9b883d0e reported score=0.4168423930021868,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 90.0, 'hidden_dim2': 190.0, 'hidden_dim3': 80.0}. This trial completed.
# Trial trainable_func_9e9b283a reported score=0.508340884751627,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 90.0, 'hidden_dim2': 180.0, 'hidden_dim3': 70.0}.
# Trial trainable_func_9fc64640 reported score=0.6321504878962092,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 90.0, 'hidden_dim2': 180.0, 'hidden_dim3': 80.0}.
# == Status ==
# Current time: 2022-07-18 13:15:00 (running for 00:01:13.59)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=8
# Bracket: Iter 8.000: 0.6237287626336986 | Iter 4.000: 0.5110228630105409
# Bracket: Iter 8.000: 0.4194035062450211
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 25/50 (1 PENDING, 4 RUNNING, 20 TERMINATED)
#
#
# Trial trainable_func_8dca22fe reported score=0.6421430802874102,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 140.0, 'hidden_dim2': 200.0, 'hidden_dim3': 140.0}. This trial completed.
# Trial trainable_func_a0206e7c reported score=0.6908782359389494,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 70.0, 'hidden_dim2': 160.0, 'hidden_dim3': 70.0}.
# Trial trainable_func_9ddd2484 reported score=0.4810557639514659,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 90.0, 'hidden_dim2': 180.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_9e9b283a reported score=0.508340884751627,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 90.0, 'hidden_dim2': 180.0, 'hidden_dim3': 70.0}.
# Trial trainable_func_9fc64640 reported score=0.6321504878962092,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 90.0, 'hidden_dim2': 180.0, 'hidden_dim3': 80.0}.
# == Status ==
# Current time: 2022-07-18 13:15:05 (running for 00:01:18.59)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=8
# Bracket: Iter 8.000: 0.6237287626336986 | Iter 4.000: 0.5110228630105409
# Bracket: Iter 8.000: 0.4350674291567088
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 26/50 (1 PENDING, 4 RUNNING, 21 TERMINATED)
#
#
# Trial trainable_func_9ddd2484 reported score=0.4810557639514659,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 90.0, 'hidden_dim2': 180.0, 'hidden_dim3': 80.0}. This trial completed.
# Trial trainable_func_a0206e7c reported score=0.6908782359389494,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 70.0, 'hidden_dim2': 160.0, 'hidden_dim3': 70.0}.
# Trial trainable_func_a0e4de56 reported score=0.4285560923242083,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 70.0}.
# Trial trainable_func_9e9b283a reported score=0.508340884751627,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 90.0, 'hidden_dim2': 180.0, 'hidden_dim3': 70.0}. This trial completed.
# Trial trainable_func_9fc64640 reported score=0.6321504878962092,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 90.0, 'hidden_dim2': 180.0, 'hidden_dim3': 80.0}. This trial completed.
# Trial trainable_func_a0206e7c reported score=0.6908782359389494,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 70.0, 'hidden_dim2': 160.0, 'hidden_dim3': 70.0}. This trial completed.
# Trial trainable_func_a495ef04 reported score=0.32898559435795716,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 70.0}.
# Trial trainable_func_a5d3a88e reported score=0.6115844815083393,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 60.0}.
# == Status ==
# Current time: 2022-07-18 13:15:11 (running for 00:01:24.34)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=8
# Bracket: Iter 8.000: 0.6237287626336986 | Iter 4.000: 0.5110228630105409
# Bracket: Iter 8.000: 0.4946983243515464
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 30/50 (1 PENDING, 4 RUNNING, 25 TERMINATED)
#
#
# Trial trainable_func_a62e1e90 reported score=0.6159918903974935,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 60.0}.
# Trial trainable_func_a0e4de56 reported score=0.4285560923242083,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 70.0}.
# Trial trainable_func_a495ef04 reported score=0.32898559435795716,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 70.0}.
# Trial trainable_func_a5d3a88e reported score=0.6115844815083393,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 60.0}.
# == Status ==
# Current time: 2022-07-18 13:15:16 (running for 00:01:29.90)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=8
# Bracket: Iter 8.000: 0.6237287626336986 | Iter 4.000: 0.5110228630105409
# Bracket: Iter 8.000: 0.4946983243515464
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 30/50 (1 PENDING, 4 RUNNING, 25 TERMINATED)
#
#
# Trial trainable_func_a62e1e90 reported score=0.6159918903974935,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 60.0}.
# Trial trainable_func_a0e4de56 reported score=0.4285560923242083,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 70.0}. This trial completed.
# Trial trainable_func_a68a57e6 reported score=0.4660357791029297,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 70.0, 'hidden_dim2': 160.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_a495ef04 reported score=0.32898559435795716,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 70.0}.
# Trial trainable_func_a68a57e6 reported score=0.4660357791029297,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 70.0, 'hidden_dim2': 160.0, 'hidden_dim3': 120.0}. This trial completed.
# == Status ==
# Current time: 2022-07-18 13:15:22 (running for 00:01:35.55)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=10
# Bracket: Iter 8.000: 0.6237287626336986 | Iter 4.000: 0.5103469599139998
# Bracket: Iter 8.000: 0.4946983243515464
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 31/50 (1 PENDING, 4 RUNNING, 26 TERMINATED)
#
#
# Trial trainable_func_a5d3a88e reported score=0.6115844815083393,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 60.0}.
# Trial trainable_func_a62e1e90 reported score=0.6159918903974935,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 60.0}.
# Trial trainable_func_a495ef04 reported score=0.32898559435795716,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 70.0}. This trial completed.
# Trial trainable_func_abaeae52 reported score=0.434443235839175,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 70.0, 'hidden_dim2': 160.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_adf10b06 reported score=0.7323481116584565,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 130.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_a5d3a88e reported score=0.6115844815083393,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 60.0}. This trial completed.
# Trial trainable_func_a62e1e90 reported score=0.6159918903974935,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 60.0}. This trial completed.
# Trial trainable_func_ae5f0188 reported score=0.4509306777451938,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 170.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_af1a8e76 reported score=0.5793113924050632,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 130.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_abaeae52 reported score=0.434443235839175,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 70.0, 'hidden_dim2': 160.0, 'hidden_dim3': 120.0}. This trial completed.
# == Status ==
# Current time: 2022-07-18 13:15:27 (running for 00:01:40.56)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=11
# Bracket: Iter 8.000: 0.6237287626336986 | Iter 4.000: 0.5103469599139998
# Bracket: Iter 8.000: 0.4946983243515464
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 36/50 (1 PENDING, 4 RUNNING, 31 TERMINATED)
#
#
# Trial trainable_func_af568606 reported score=0.48254770658263313,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 170.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_adf10b06 reported score=0.7323481116584565,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 130.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_af568606 reported score=0.48254770658263313,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 170.0, 'hidden_dim3': 90.0}. This trial completed.
# Trial trainable_func_ae5f0188 reported score=0.4509306777451938,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 170.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_b05141cc reported score=0.5875533800660704,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 130.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_af1a8e76 reported score=0.5793113924050632,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 130.0, 'hidden_dim3': 90.0}.
# == Status ==
# Current time: 2022-07-18 13:15:32 (running for 00:01:45.58)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=12
# Bracket: Iter 8.000: 0.6421430802874102 | Iter 4.000: 0.5096710568174587
# Bracket: Iter 8.000: 0.4946983243515464
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 37/50 (1 PENDING, 4 RUNNING, 32 TERMINATED)
#
#
# Trial trainable_func_adf10b06 reported score=0.7323481116584565,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 130.0, 'hidden_dim3': 90.0}. This trial completed.
# Trial trainable_func_b298ea7a reported score=0.641974650051212,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 110.0, 'hidden_dim2': 130.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_ae5f0188 reported score=0.4509306777451938,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 170.0, 'hidden_dim3': 90.0}. This trial completed.
# Trial trainable_func_af1a8e76 reported score=0.5793113924050632,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 130.0, 'hidden_dim3': 90.0}. This trial completed.
# Trial trainable_func_b3fa0a84 reported score=0.5232260750609647,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 130.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_b506a680 reported score=0.5547613229064843,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 130.0, 'hidden_dim3': 110.0}.
# Trial trainable_func_b05141cc reported score=0.5875533800660704,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 130.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_b05141cc reported score=0.5875533800660704,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 130.0, 'hidden_dim3': 90.0}. This trial completed.
# == Status ==
# Current time: 2022-07-18 13:15:37 (running for 00:01:50.93)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=13
# Bracket: Iter 8.000: 0.6237287626336986 | Iter 4.000: 0.5103469599139998
# Bracket: Iter 8.000: 0.4946983243515464
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 41/50 (1 PENDING, 4 RUNNING, 36 TERMINATED)
#
#
# Trial trainable_func_b298ea7a reported score=0.641974650051212,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 110.0, 'hidden_dim2': 130.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_b52b96ca reported score=0.5496419270833333,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 80.0, 'hidden_dim2': 120.0, 'hidden_dim3': 110.0}.
# Trial trainable_func_b3fa0a84 reported score=0.5232260750609646,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 130.0, 'hidden_dim3': 90.0}.
# Trial trainable_func_b506a680 reported score=0.5547613229064843,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 130.0, 'hidden_dim3': 110.0}.
# Trial trainable_func_b506a680 reported score=0.5547613229064843,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 130.0, 'hidden_dim3': 110.0}. This trial completed.
# Trial trainable_func_b298ea7a reported score=0.641974650051212,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 110.0, 'hidden_dim2': 130.0, 'hidden_dim3': 90.0}. This trial completed.
# == Status ==
# Current time: 2022-07-18 13:15:43 (running for 00:01:56.04)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=14
# Bracket: Iter 8.000: 0.605314444979987 | Iter 4.000: 0.5110228630105409
# Bracket: Iter 8.000: 0.5157834799062959
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 43/50 (1 PENDING, 4 RUNNING, 38 TERMINATED)
#
#
# Trial trainable_func_b3fa0a84 reported score=0.5232260750609647,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 130.0, 'hidden_dim3': 90.0}. This trial completed.
# Trial trainable_func_b6e0b748 reported score=0.3245059753919818,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 80.0, 'hidden_dim2': 110.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_b98d2a4e reported score=0.3016353046594982,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 80.0, 'hidden_dim2': 110.0, 'hidden_dim3': 110.0}.
# Trial trainable_func_b52b96ca reported score=0.5496419270833333,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 80.0, 'hidden_dim2': 120.0, 'hidden_dim3': 110.0}.
# Trial trainable_func_b9c25138 reported score=0.5893636484915478,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 80.0, 'hidden_dim2': 90.0, 'hidden_dim3': 110.0}.
# == Status ==
# Current time: 2022-07-18 13:15:48 (running for 00:02:01.86)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=14
# Bracket: Iter 8.000: 0.605314444979987 | Iter 4.000: 0.5205112154478856
# Bracket: Iter 8.000: 0.5157834799062959
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 44/50 (1 PENDING, 4 RUNNING, 39 TERMINATED)
#
#
# Trial trainable_func_b6e0b748 reported score=0.3245059753919817,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 80.0, 'hidden_dim2': 110.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_b98d2a4e reported score=0.3016353046594982,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 80.0, 'hidden_dim2': 110.0, 'hidden_dim3': 110.0}.
# Trial trainable_func_b52b96ca reported score=0.5496419270833333,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 80.0, 'hidden_dim2': 120.0, 'hidden_dim3': 110.0}.
# Trial trainable_func_b9c25138 reported score=0.5893636484915478,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 80.0, 'hidden_dim2': 90.0, 'hidden_dim3': 110.0}.
# == Status ==
# Current time: 2022-07-18 13:15:54 (running for 00:02:07.17)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=14
# Bracket: Iter 8.000: 0.605314444979987 | Iter 4.000: 0.5205112154478856
# Bracket: Iter 8.000: 0.5157834799062959
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 44/50 (1 PENDING, 4 RUNNING, 39 TERMINATED)
#
#
# Trial trainable_func_b6e0b748 reported score=0.3245059753919818,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 80.0, 'hidden_dim2': 110.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_b98d2a4e reported score=0.3016353046594982,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 80.0, 'hidden_dim2': 110.0, 'hidden_dim3': 110.0}.
# Trial trainable_func_b52b96ca reported score=0.5496419270833333,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 80.0, 'hidden_dim2': 120.0, 'hidden_dim3': 110.0}. This trial completed.
# == Status ==
# ...
# Trial trainable_func_c6ea073e reported score=0.5670413815575106,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 140.0, 'hidden_dim3': 60.0}.
# Trial trainable_func_c7916a74 reported score=0.5331234056122449,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 140.0, 'hidden_dim3': 60.0}.
# Trial trainable_func_c802e186 reported score=0.5219941348973607,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 140.0, 'hidden_dim3': 60.0}.
# == Status ==
# Current time: 2022-07-18 13:16:20 (running for 00:02:33.13)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=19
# Bracket: Iter 8.000: 0.5893636484915478 | Iter 4.000: 0.5299995678852303
# Bracket: Iter 8.000: 0.508340884751627
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 49/50 (1 PENDING, 4 RUNNING, 44 TERMINATED)
#
#
# Trial trainable_func_c7916a74 reported score=0.5331234056122449,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 140.0, 'hidden_dim3': 60.0}. This trial completed.
# Trial trainable_func_ba8cf668 reported score=0.5238489109456852,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 80.0, 'hidden_dim2': 110.0, 'hidden_dim3': 110.0}.
# Trial trainable_func_ce573ac8 reported score=0.538786902844874,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 160.0, 'hidden_dim2': 140.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_c6ea073e reported score=0.5670413815575106,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 140.0, 'hidden_dim3': 60.0}. This trial completed.
# Trial trainable_func_c802e186 reported score=0.5219941348973607,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 140.0, 'hidden_dim3': 60.0}. This trial completed.
# Trial trainable_func_d05cdf26 reported score=0.6174975339555353,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 190.0, 'hidden_dim3': 70.0}.
# == Status ==
# Current time: 2022-07-18 13:16:25 (running for 00:02:38.52)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=21
# Bracket: Iter 8.000: 0.5887994713045974 | Iter 4.000: 0.5259968513912955
# Bracket: Iter 8.000: 0.5157834799062959
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 1.5/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 50/50 (3 RUNNING, 47 TERMINATED)
#
#
# Trial trainable_func_ba8cf668 reported score=0.5238489109456852,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 80.0, 'hidden_dim2': 110.0, 'hidden_dim3': 110.0}. This trial completed.
# Trial trainable_func_ce573ac8 reported score=0.538786902844874,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 160.0, 'hidden_dim2': 140.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_ce573ac8 reported score=0.538786902844874,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 160.0, 'hidden_dim2': 140.0, 'hidden_dim3': 50.0}. This trial completed.
# Trial trainable_func_d05cdf26 reported score=0.6174975339555353,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 190.0, 'hidden_dim3': 70.0}. This trial completed.
# == Status ==
# Current time: 2022-07-18 13:16:29 (running for 00:02:42.78)
# Memory usage on this node: 1.7/12.7 GiB
# Using AsyncHyperBand: num_stopped=22
# Bracket: Iter 8.000: 0.5887994713045974 | Iter 4.000: 0.5315614867487376
# Bracket: Iter 8.000: 0.5157834799062959
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.34 GiB heap, 0.0/3.67 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-18_13-13-47
# Number of trials: 50/50 (50 TERMINATED)
# +-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status     | loc              | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    score |   training_iteration |
# |-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_74fab87e | TERMINATED | 172.28.0.2:11000 | tanh    | relu   | relu   |            8 |            70 |           170 |           170 | 0.0009 | 0.40374  |                   10 |
# | trainable_func_751e9334 | TERMINATED | 172.28.0.2:11001 | relu    | relu   | relu   |           32 |           150 |           150 |           140 | 0.0009 | 0.236034 |                   10 |
# | trainable_func_752495d6 | TERMINATED | 172.28.0.2:11054 | relu    | tanh   | relu   |            8 |           120 |           100 |           160 | 0.001  | 0.312647 |                   10 |
# | trainable_func_752d36fa | TERMINATED | 172.28.0.2:11064 | tanh    | tanh   | relu   |            8 |           150 |            70 |            80 | 0.001  | 0.388582 |                    4 |
# | trainable_func_753942e2 | TERMINATED | 172.28.0.2:11001 | tanh    | tanh   | relu   |           32 |            80 |           170 |           160 | 0.0006 | 0.653755 |                   10 |
# | trainable_func_7e9c0db0 | TERMINATED | 172.28.0.2:11064 | selu    | relu   | relu   |           32 |            70 |           100 |           110 | 0.0006 | 0.348969 |                    4 |
# | trainable_func_8293cd40 | TERMINATED | 172.28.0.2:11001 | tanh    | relu   | tanh   |           16 |           110 |           150 |            50 | 0.0009 | 0.657059 |                   10 |
# | trainable_func_8437de70 | TERMINATED | 172.28.0.2:11064 | relu    | relu   | relu   |           16 |           170 |            60 |           170 | 0.001  | 0.605314 |                   10 |
# | trainable_func_84beffe0 | TERMINATED | 172.28.0.2:11000 | relu    | relu   | tanh   |           32 |           110 |            70 |           190 | 0.0008 | 0.435067 |                   10 |
# | trainable_func_892aa782 | TERMINATED | 172.28.0.2:11054 | relu    | tanh   | relu   |           16 |           200 |           120 |           140 | 0.0007 | 0.586875 |                   10 |
# | trainable_func_8bc0f3a2 | TERMINATED | 172.28.0.2:11001 | tanh    | tanh   | relu   |           32 |           110 |           180 |           130 | 0.0008 | 0.538081 |                   10 |
# | trainable_func_8d449580 | TERMINATED | 172.28.0.2:11064 | tanh    | tanh   | tanh   |           32 |            50 |           190 |            90 | 0.0008 | 0.684198 |                   10 |
# | trainable_func_8dca22fe | TERMINATED | 172.28.0.2:11000 | relu    | tanh   | selu   |            8 |           140 |           200 |           140 | 0.001  | 0.642143 |                   10 |
# | trainable_func_8ea119b2 | TERMINATED | 172.28.0.2:11064 | selu    | tanh   | tanh   |            8 |            50 |           130 |           190 | 0.0008 | 0.511023 |                    4 |
# | trainable_func_931155c0 | TERMINATED | 172.28.0.2:11001 | selu    | selu   | selu   |           32 |            50 |           200 |           100 | 0.0005 | 0.749422 |                   10 |
# | trainable_func_9357c622 | TERMINATED | 172.28.0.2:11054 | tanh    | selu   | tanh   |           16 |            50 |           200 |            50 | 0.0007 | 0.53     |                    4 |
# | trainable_func_95a16276 | TERMINATED | 172.28.0.2:11001 | tanh    | selu   | tanh   |           16 |            50 |           200 |            50 | 0.0007 | 0.588235 |                    8 |
# | trainable_func_98bf274a | TERMINATED | 172.28.0.2:11064 | selu    | selu   | selu   |           32 |            50 |           200 |           100 | 0.0005 | 0.482344 |                   10 |
# | trainable_func_99096652 | TERMINATED | 172.28.0.2:11054 | selu    | selu   | selu   |           32 |            50 |           200 |           100 | 0.0005 | 0.509671 |                    4 |
# | trainable_func_994b806e | TERMINATED | 172.28.0.2:11054 | selu    | selu   | selu   |           32 |            90 |           200 |           100 | 0.0005 | 0.311696 |                    4 |
# | trainable_func_9b883d0e | TERMINATED | 172.28.0.2:11054 | selu    | selu   | selu   |           32 |            90 |           190 |            80 | 0.0005 | 0.416842 |                    4 |
# | trainable_func_9ddd2484 | TERMINATED | 172.28.0.2:11064 | selu    | selu   | selu   |           32 |            90 |           180 |            80 | 0.0006 | 0.481056 |                   10 |
# | trainable_func_9e9b283a | TERMINATED | 172.28.0.2:11001 | selu    | selu   | selu   |           32 |            90 |           180 |            70 | 0.0006 | 0.508341 |                   10 |
# | trainable_func_9fc64640 | TERMINATED | 172.28.0.2:11054 | selu    | selu   | selu   |           32 |            90 |           180 |            80 | 0.0006 | 0.63215  |                   10 |
# | trainable_func_a0206e7c | TERMINATED | 172.28.0.2:11000 | selu    | selu   | selu   |           32 |            70 |           160 |            70 | 0.0006 | 0.690878 |                   10 |
# | trainable_func_a0e4de56 | TERMINATED | 172.28.0.2:11064 | tanh    | relu   | tanh   |           16 |            70 |           150 |            70 | 0.0009 | 0.428556 |                    8 |
# | trainable_func_a495ef04 | TERMINATED | 172.28.0.2:11001 | tanh    | relu   | tanh   |           16 |            70 |           150 |            70 | 0.0009 | 0.328986 |                   10 |
# | trainable_func_a5d3a88e | TERMINATED | 172.28.0.2:11054 | tanh    | relu   | tanh   |           16 |            70 |           150 |            60 | 0.0009 | 0.611584 |                   10 |
# | trainable_func_a62e1e90 | TERMINATED | 172.28.0.2:11000 | tanh    | relu   | tanh   |           16 |            70 |           150 |            60 | 0.0009 | 0.615992 |                   10 |
# | trainable_func_a68a57e6 | TERMINATED | 172.28.0.2:11064 | selu    | selu   | tanh   |           32 |            70 |           160 |           120 | 0.0007 | 0.466036 |                    4 |
# | trainable_func_abaeae52 | TERMINATED | 172.28.0.2:11064 | selu    | selu   | selu   |           32 |            70 |           160 |           120 | 0.0007 | 0.434443 |                    4 |
# | trainable_func_adf10b06 | TERMINATED | 172.28.0.2:11001 | selu    | selu   | selu   |           32 |            60 |           130 |            90 | 0.0005 | 0.732348 |                   10 |
# | trainable_func_ae5f0188 | TERMINATED | 172.28.0.2:11054 | selu    | selu   | selu   |           32 |            60 |           170 |            90 | 0.0005 | 0.450931 |                   10 |
# | trainable_func_af1a8e76 | TERMINATED | 172.28.0.2:11000 | selu    | selu   | selu   |           32 |            60 |           130 |            90 | 0.0005 | 0.579311 |                   10 |
# | trainable_func_af568606 | TERMINATED | 172.28.0.2:11064 | selu    | selu   | selu   |           32 |            60 |           170 |            90 | 0.0005 | 0.482548 |                    4 |
# | trainable_func_b05141cc | TERMINATED | 172.28.0.2:11064 | tanh    | tanh   | tanh   |           32 |            60 |           130 |            90 | 0.0008 | 0.587553 |                    8 |
# | trainable_func_b298ea7a | TERMINATED | 172.28.0.2:11001 | tanh    | tanh   | tanh   |           32 |           110 |           130 |            90 | 0.0008 | 0.641975 |                   10 |
# | trainable_func_b3fa0a84 | TERMINATED | 172.28.0.2:11054 | selu    | selu   | selu   |           32 |            60 |           130 |            90 | 0.0005 | 0.523226 |                   10 |
# | trainable_func_b506a680 | TERMINATED | 172.28.0.2:11000 | selu    | tanh   | selu   |           32 |            60 |           130 |           110 | 0.0006 | 0.554761 |                    8 |
# | trainable_func_b52b96ca | TERMINATED | 172.28.0.2:11064 | selu    | tanh   | selu   |            8 |            80 |           120 |           110 | 0.0006 | 0.549642 |                    8 |
# | trainable_func_b6e0b748 | TERMINATED | 172.28.0.2:11000 | selu    | tanh   | selu   |            8 |            80 |           110 |           100 | 0.0006 | 0.324506 |                    8 |
# | trainable_func_b98d2a4e | TERMINATED | 172.28.0.2:11001 | selu    | selu   | selu   |            8 |            80 |           110 |           110 | 0.0006 | 0.301635 |                    8 |
# | trainable_func_b9c25138 | TERMINATED | 172.28.0.2:11054 | selu    | selu   | selu   |            8 |            80 |            90 |           110 | 0.0006 | 0.589364 |                    8 |
# | trainable_func_ba8cf668 | TERMINATED | 172.28.0.2:11064 | selu    | selu   | selu   |            8 |            80 |           110 |           110 | 0.0006 | 0.523849 |                   10 |
# | trainable_func_c3b6bfee | TERMINATED | 172.28.0.2:11000 | relu    | selu   | selu   |            8 |           130 |           100 |            60 | 0.0006 | 0.512758 |                    4 |
# | trainable_func_c6ea073e | TERMINATED | 172.28.0.2:11001 | tanh    | relu   | tanh   |           16 |           130 |           140 |            60 | 0.001  | 0.567041 |                   10 |
# | trainable_func_c7916a74 | TERMINATED | 172.28.0.2:11054 | tanh    | relu   | tanh   |           16 |           130 |           140 |            60 | 0.001  | 0.533123 |                    8 |
# | trainable_func_c802e186 | TERMINATED | 172.28.0.2:11000 | relu    | relu   | relu   |           16 |           130 |           140 |            60 | 0.001  | 0.521994 |                    4 |
# | trainable_func_ce573ac8 | TERMINATED | 172.28.0.2:11054 | tanh    | relu   | relu   |           16 |           160 |           140 |            50 | 0.001  | 0.538787 |                    8 |
# | trainable_func_d05cdf26 | TERMINATED | 172.28.0.2:11001 | tanh    | relu   | relu   |           32 |           180 |           190 |            70 | 0.0008 | 0.617498 |                   10 |
# +-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# 2022-07-18 13:16:30,063	INFO tune.py:748 -- Total run time: 163.05 seconds (162.75 seconds for the tuning loop).
# Best trial config: {'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 32, 'hidden_dim1': 50.0, 'hidden_dim2': 200.0, 'hidden_dim3': 100.0}
# Best trial final validation score: 0.7494220344387756
# Best trial test set score: 0.7442094017094016
# Best trial test set score: None
